# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnunicodenormalizer
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22779 sha256=a8747cfda4c3b2ae677d5452f0decde9947b9b846ed0983fae7b117bf992fa27
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/e9/16732a619cbf5a63fdc9f6e2f9eb5fcf73fa023735237330e9
# Successfully built bnunicodenormalizer
# Installing collected packages: bnunicodenormalizer
# Successfully installed bnunicodenormalizer-0.1.6
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.1

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/others/for_now/sylhet/'

files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_50_audio_27.wav', 'rec_50_audio_25.wav', 'rec_50_small_audio_0.wav', 'rec_50_audio_30.wav', 'rec_51_audio_2.wav', 'rec_51_audio_6.wav', 'rec_51_audio_7.wav', 'rec_51_big_audio_1.wav', 'rec_51_audio_5.wav', 'rec_51_audio_1.wav', 'rec_51_audio_10.wav', 'rec_51_audio_11.wav', 'rec_51_audio_3.wav', 'rec_51_audio_8.wav', 'rec_51_audio_4.wav', 'rec_51_audio_0.wav', 'rec_51_audio_9.wav', 'rec_51_audio_21.wav', 'rec_51_audio_12.wav', 'rec_51_audio_17.wav', 'rec_51_audio_13.wav', 'rec_51_audio_14.wav', 'rec_51_audio_25.wav', 'rec_51_audio_22.wav', 'rec_51_audio_19.wav', 'rec_51_audio_20.wav', 'rec_51_audio_18.wav', 'rec_51_audio_27.wav', 'rec_51_audio_15.wav', 'rec_51_audio_26.wav', 'rec_51_audio_16.wav', 'rec_51_audio_23.wav', 'rec_51_small_audio_0.wav', 'rec_51_audio_24.wav', 'rec_52_audio_3.wav', 'rec_52_audio_8.wav', 'rec_52_audio_0.wav', 'rec_52_audio_6.wav', 'rec_52_big_audio_0.wav', 'rec_52_audio_2.wav', 'rec_52_audio_1.wav', 'rec_52_audio_5.wav', 'rec_52_audio_9.wav', 'rec_52_audio_4.wav', 'rec_52_audio_7.wav', 'rec_52_audio_18.wav', 'rec_52_audio_15.wav', 'rec_52_audio_29.wav', 'rec_52_audio_30.wav', 'rec_52_small_audio_0.wav', 'rec_52_audio_35.wav', 'rec_52_audio_19.wav', 'rec_52_audio_33.wav', 'rec_52_audio_28.wav', 'rec_52_audio_14.wav', 'rec_52_audio_12.wav', 'rec_52_audio_32.wav', 'rec_52_audio_16.wav', 'rec_52_audio_36.wav', 'rec_52_audio_22.wav', 'rec_52_audio_40.wav', 'rec_52_audio_26.wav', 'rec_52_audio_25.wav', 'rec_52_audio_38.wav', 'rec_52_audio_37.wav', 'rec_52_audio_34.wav', 'rec_52_audio_20.wav', 'rec_52_audio_31.wav', 'rec_52_audio_27.wav', 'rec_52_audio_41.wav', 'rec_52_audio_11.wav', 'rec_52_audio_24.wav', 'rec_52_audio_17.wav', 'rec_52_audio_23.wav', 'rec_52_audio_13.wav', 'rec_52_audio_21.wav', 'rec_52_audio_39.wav', 'rec_52_audio_10.wav', 'rec_52_small_audio_1.wav', 'rec_53_audio_0.wav', 'rec_53_audio_11.wav', 'rec_53_audio_8.wav', 'rec_53_audio_6.wav', 'rec_53_audio_4.wav', 'rec_53_audio_10.wav', 'rec_53_audio_9.wav', 'rec_53_audio_14.wav', 'rec_53_audio_13.wav', 'rec_53_audio_3.wav', 'rec_53_audio_5.wav', 'rec_53_audio_1.wav', 'rec_53_audio_7.wav', 'rec_53_audio_12.wav', 'rec_53_audio_2.wav', 'rec_53_audio_25.wav', 'rec_53_audio_32.wav', 'rec_53_audio_31.wav', 'rec_53_audio_24.wav', 'rec_53_audio_30.wav', 'rec_53_audio_22.wav', 'rec_53_audio_29.wav', 'rec_53_audio_17.wav', 'rec_53_audio_18.wav', 'rec_53_audio_23.wav', 'rec_53_audio_34.wav', 'rec_53_audio_21.wav', 'rec_53_audio_36.wav', 'rec_53_audio_19.wav', 'rec_53_audio_35.wav', 'rec_53_audio_26.wav', 'rec_53_audio_33.wav', 'rec_53_audio_16.wav', 'rec_53_audio_20.wav', 'rec_53_audio_28.wav', 'rec_53_audio_15.wav', 'rec_53_audio_27.wav', 'rec_54_audio_0.wav', 'rec_54_big_audio_0.wav', 'rec_54_audio_8.wav', 'rec_54_audio_27.wav', 'rec_54_audio_25.wav', 'rec_54_audio_10.wav', 'rec_54_audio_14.wav', 'rec_54_audio_16.wav', 'rec_54_audio_31.wav', 'rec_54_audio_21.wav', 'rec_54_audio_18.wav', 'rec_54_audio_17.wav', 'rec_54_audio_20.wav', 'rec_54_audio_9.wav', 'rec_54_audio_30.wav', 'rec_54_audio_12.wav', 'rec_54_audio_24.wav', 'rec_54_audio_23.wav', 'rec_54_audio_15.wav', 'rec_54_audio_1.wav', 'rec_54_audio_2.wav', 'rec_54_audio_22.wav', 'rec_54_audio_3.wav', 'rec_54_audio_29.wav', 'rec_54_audio_19.wav', 'rec_54_audio_28.wav', 'rec_54_audio_26.wav', 'rec_54_audio_7.wav', 'rec_54_audio_13.wav', 'rec_54_audio_11.wav', 'rec_54_audio_5.wav', 'rec_54_audio_6.wav', 'rec_54_audio_4.wav', 'rec_54_small_audio_0.wav', 'rec_55_audio_18.wav', 'rec_55_audio_23.wav', 'rec_55_small_audio_0.wav', 'rec_55_audio_3.wav', 'rec_55_audio_9.wav', 'rec_55_audio_1.wav', 'rec_55_audio_17.wav', 'rec_55_audio_7.wav', 'rec_55_audio_14.wav', 'rec_55_audio_15.wav', 'rec_55_audio_21.wav', 'rec_55_audio_10.wav', 'rec_55_audio_20.wav', 'rec_55_audio_2.wav', 'rec_55_audio_0.wav', 'rec_55_audio_5.wav', 'rec_55_audio_22.wav', 'rec_55_audio_4.wav', 'rec_55_audio_12.wav', 'rec_55_audio_11.wav', 'rec_55_audio_25.wav', 'rec_55_audio_19.wav', 'rec_55_audio_16.wav', 'rec_55_audio_24.wav', 'rec_5 ...
#
# 3005

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_50_audio_27.wav', 'কত মাসে কত আসে'],
#  ['rec_50_audio_25.wav', 'এটা আসলে বেশি লস হয়ে গেছে'],
#  ['rec_50_small_audio_0.wav', '<>'],
#  ['rec_50_audio_30.wav', 'স্টেবল এস আলম গ্রুপ চালাও'],
#  ['rec_51_audio_2.wav', 'গেম'],
#  ['rec_51_audio_6.wav', '<>'],
#  ['rec_51_audio_7.wav',
#   'জরায়ু অস্ট্রেলিয়া কাগজ পাতি জমা দেওয়া লাগবো প্রতিদিন আরম্ভ করা লাগবো আর ব্যাংকে রেডি করা লাগবে না'],
#  ['rec_51_big_audio_1.wav', '<>'],
#  ['rec_51_audio_5.wav', 'ঢাকার যাইতাম পারি'],
#  ['rec_51_audio_1.wav', '<>'],
#  ['rec_51_audio_10.wav',
#   'ব্যাংকক যেখানে লাগতো আগে 40000 কানাডিয়ান ডলার বানাইছে ইউনিভার্সিটি'],
#  ['rec_51_audio_11.wav', 'দেশটা কি যারা গেছেন'],
#  ['rec_51_audio_3.wav', '<>'],
#  ['rec_51_audio_8.wav',
#   'বিজি আর কিতা তোমরা লাগে কোন দেশে যাওয়ার ইচ্ছা তোমায় ভালোবাসি'],
#  ['rec_51_audio_4.wav',
#   'তখন আমার অন্য বাসা খুঁজে দাও রাখবো ওসব তার বিভিন্ন জিনিসপত্র আছে অনেক সময় সাপেক্ষ ব্যাপার'],
#  ['rec_51_audio_0.wav',
#   'ওতো আলহামদুলিল্লাহ তুমি তো দিনকাল তোমার আলহামদুলিল্লাহ'],
#  ['rec_51_audio_9.wav', 'স্কটল্যান্ড মডেল মার কোথায় অবস্থান করছি'],
#  ['rec_51_audio_21.wav', 'টুর দেওয়া দরকার'],
#  ['rec_51_audio_12.wav',
#   'ওইটার কারণে মনে কানাডা স্টুডেন্ট ভিসার লাগিয়ে অনেক নিয়মকানুন কঠিন যাওয়াটা অনেক চাপ হয়ে'],
#  ['rec_51_audio_17.wav',
#   'কোন কোশ্চেন কেমনে সলভ করা লাগে কোন টাইমের মধ্যে সলভ করা লাগে কোন পেশি জাগে পরে সলভ করা লাগে জিনিস গুলো জানা জরুরী ইংলিশ জানলেই হবে না এখানে নিজেরে নিজেরে কাম রাখিয়া এক্সাম ডেট সবচেয়ে বেশি স্ট্রেটিজি দেখাও'],
#  ['rec_51_audio_13.wav', '<>'],
#  ['rec_51_audio_14.wav',
#   'তো আমার আপাতত যেহেতু দেখলাম ফরজ বেশি বাড়ি গেছে তোর লাগি দেখলাম'],
#  ['rec_51_audio_25.wav',
#   'তার যত কুকর্ম আছে সব তো সাক্ষী আমি ঠিক আছে তার ভিডিও ফুটেজ লাগলে তুমি আমার লগে যোগাযোগ করুন'],
#  ['rec_51_audio_22.wav', '<>'],
#  ['rec_51_audio_19.wav',
#   'টিপস এন্ড ট্রিকস দেখার থাকি নিজে নিজে ট্রাই করতে যে নিজের কোনটা নিজের কোনটা সবচেয়ে বেশি ভালো হয় নিজের কাছে যেটা ভালো হয় পরীক্ষার জন্য টিপস এন্ড ট্রিকস সবার কাছে কাটে না নিজের কাছে যেটা ভালো মনে হয় এটাই সবচেয়ে বেস্ট সমস্যা হয় নিজের উপকার করা লাগে'],
#  ['rec_51_audio_20.wav',
#   'নিজেরা জিনিসগুলো ঘাটায় না তারা মানুষের উপরে থাকে না'],
#  ['rec_51_audio_18.wav',
#   'সো আই এল স্যার বলা যায় যে এটা আসলে এটা টাইম ম্যানেজমেন্ট এর একটা এক্সাম দেওয়া যায় তো এক্সাম এক্সাম আমার মোটামুটি ভালো আছি দুই মাসের মধ্যে প্রিপারেশন দিয়েছে'],
#  ['rec_51_audio_27.wav', 'তোমার আব্বা আম্মার আমার সালাম দিও'],
#  ['rec_51_audio_15.wav', 'হ্যালো'],
#  ['rec_51_audio_26.wav', 'আমি তার বিরুদ্ধে কে এইচডি'],
#  ['rec_51_audio_16.wav',
#   'ইংলিশের বেশি ক্লিয়ার থাকলে মাস দেড়েক প্রিপারেশন লইয়া একটা প্রিপারেশন নিলে আলহামদুলিল্লাহ অনেক জরুরী'],
#  ['rec_51_audio_23.wav', '<>'],
#  ['rec_51_small_audio_0.wav', 'এভাবে সময় দিতে হয় সময় দিতে হইবো'],
#  ['rec_51_audio_24.wav', '<>'],
#  ['rec_52_audio_3.wav',
#   'কিগো লন্ডন বইয়া বইয়া দেশকে মানুষ মারতে দেশর সম্পদ জ্বালাইতে কর লন্ডন বইয়া বইয়া কত বড় নেতা কত বড় গারিয়া ইন্ডিয়া লোন'],
#  ['rec_52_audio_8.wav', 'আন্দোলন করেন না'],
#  ['rec_52_audio_0.wav',
#   'বন্ধু কিতা অবস্থা নির্বাচন আর কিতা নির্বাচন তো যা সো শুধু শুধু জনগণের টাকা গুলো নষ্ট'],
#  ['rec_52_audio_6.wav', 'কুন্তা নাই তার মধ্যে এ বলাইয়া দেশের নেতা'],
#  ['rec_52_big_audio_0.wav',
#   'কিন্তু চরমভাবে হতাশ হয়েছে মানে সিনেমাটা তো আমি পইল আবার দিকটা ভালো হয়েছে আমার মন শুধু খুজতাছি তার ক্লাস সিক্স কোন সময় আমি ডর বিরানি যে কিছু ক্লাসিক জিনিস আছে ক্লাসিক ডায়লগ আছে অভিনেতার দুর্দান্ত অভিনয় আছে এই জিনিসগুলো পাইছি না'],
#  ['rec_52_audio_2.wav',
#   '1 ডলারের দাম 120 টাকার উপরে কি অবস্থায় ওলা টাকা নষ্ট আসলে কিতা কইতাম আর আলাদিন তো চলে আসবে না আসল কষ্ট যে ঔষধ সরকার'],
#  ['rec_52_audio_1.wav', 'নির্বাচন না করে ঘোষণা দিলেন'],
#  ['rec_52_audio_5.wav',
#   'চুরী ভবন নাম দিয়েছে আবাব ভবন ওলা একটা নেতার লাগি মানুষ জান রে'],
#  ['rec_52_audio_9.wav',
#   'এটা তো ভুল কারণে জালান না ও তো দেশের প্রতি মায়া থাকলে ঠিকমতো নির্বাচন দেওয়া একটা বিগত দিতে হয় না ও তোমার নি মায়াজাল সমান সমান'],
#  ['rec_52_audio_4.wav',
#   'আর কত বড় গদ্য বইলে মানুষের লন্ডনের সুরের কোথায় বড় মানে ফেসিনেশন তার চুরি করা লাগে এটা ভবন বানিয়েছে'],
#  ['rec_52_audio_7.wav', 'এখন ফায়দাটা হইছে কার আসলে আগুনটা দিয়া'],
#  ['rec_52_audio_18.wav',
#   'কিতা কইতাম গাধা হইলে নির্বাচন যত আগাই আর হরতাল তত কমে বলে নির্বাচনের দুই মাস আগে দিল সপ্তাহে 60 দিন হরতাল আর নির্বাচনের 10 দিন আগে যে সপ্তাহে একদিন হরতাল মানে ইতারে কইতাম কিতা'],
#  ['rec_52_audio_15.wav',
#   'এই কোন তৃতীয় পক্ষ যদি না হয় মানে আর লুহু লন্ডন প্রবাসী সুর এত ভরসা করতাম পাররা মুনা দেখা যাক লন্ডন প্রবাসী সুরার উপরে যদি'],
#  ['rec_52_audio_29.wav',
#   'এই ব্যাপারে তোর কিতা মনে হয় সিলেটের কেমন সুন্দর হয়েছে খুবই ভালা কাম করছে কোন সন্দেহ নাই প্রজেক্ট যদি নির্বাচনে লন্ডন প্রবাসী গাধায়'],
#  ['rec_52_audio_30.wav',
#   'ওসি টা ছাড়লো এখনই ওর সাগর কোন অস্তিত্ব আছে ডাংকি দেখছি দুইবার'],
#  ['rec_52_small_audio_0.wav',
#   'কিন্তু পিকে বা সানি এতোটুকু তো এক্সপ্রেস রাখছিলাম'],
#  ['rec_52_audio_35.wav',
#   'বাকি ক্যারেক্টার গুলারে একটা আছিল পাঞ্জাবি যে ক্যারেক্টার এগুলো আমার যোগাযোগ দিয়ে একটি আমার ভালো লাগছে না বাট আরেকটা বিক্রি কৌশল কয়লা বড় ভালো লাগছে দ্বিতীয়বার আরো ভালো লাগছে'],
#  ['rec_52_audio_19.wav',
#   'এর মধ্যে তারা নেতাকে এখন এগোতে লন্ডন প্রবাসী সুর আর দেশনেত্রী ভিডিও কলে কর্মসূচি দিন দেশের নেতা এখন পর্যন্ত সামনে নিতে পারছি না ডলার কোন কেয়ারও নাই তার প্রতি দল চলত না'],
#  ['rec_52_audio_33.wav',
#   'থ্রি ইডিয়ট দিছে বাদে আরো কিতা পিকে দিছে তার লোয়েস্ট কোনটা তার লোয়েস্ট যদি আমি পিকেও ধরি বা সানজু এক্সপেক্টেশন'],
#  ['rec_52_audio_28.wav', 'ভবন বানাইয়া চুরি করছে আখের গোসাই দিছে'],
#  ['rec_52_audio_14.wav',
#   'ওই চালটা খুব ভালো লাগছে তো এখন আর দেখা যায় আর একটা নাটক রচনা হইতে যার জনগণের টাকায় এই আরকি ওটাও সমস্যা হলে আমরা টাকাটা নষ্ট হয় টাকাটা মানে মান কমতে কমতে কমতে কমতে কোনখানে যে গিয়া'],
#  ['rec_52_audio_12.wav',
#   'নির্বাচনটা খুব ফাটাফাটি ওর এবং আমার যতটুকু মনে হয় সুরিও হইত না বেশিরভাগ আসনে স্বতন্ত্র প্রার্থীরা জিতব আমেরিকারে দেখা নিবো নির্বাচন তো হইছে জনগণও বুদ্ধি ও জনগণ তো ভোট দিয়েছে আওয়ামী লীগ তো আসছে স্বতন্ত্র জিতল তো আসলে আওয়ামী লীগ জিতছে কিন্তু বাইরে তো এখানেও'],
#  ['rec_52_audio_32.wav',
#   'পয়লা বার যখন আমি গেছি তখন আমি গেছি খুব হাই এক্সপেক্টেশন রাজকুমারী রানীর এটা ফিল সাথে আছে শাহরুখ খান বেশি কিছু একটা এক্সপেক্টেশন যে মানুষটা মুন্নাভাই দিছে'],
#  ['rec_52_audio_16.wav',
#   'মানে বিন্দুমাত্র ভরসা না তাকে হাসিনার উপর এক পারসেন্ট ভরসা আছে যেটা চেষ্টা করব এখন তো শুধু দেওয়ার সময় এই আরকি নির্বাচন পরবর্তী সহিংসতা বাড়বো নি'],
#  ['rec_52_audio_36.wav',
#   'পয়লা বারে আমি জানিনা কেন আমি গান গুলারে খুব একটা পাইছি না কিন্তু সেকেন্ড বার দেখে দেখছি আসলে গানগুলো খুব সুন্দর তো ওতো আমি 2 পার্সপেক্টিভ থাকি তোরে দুই এক্সপেরিয়েন্স করলাম'],
#  ['rec_52_audio_22.wav', '<>'],
#  ['rec_52_audio_40.wav',
#   'ক্লাসিক বলতে আমি বুঝাইলাম না আবার যতক্ষণ ক্লাসিক ফিল্ম ক্যাটাগরিতে না মানে একটা ধুমধুমার একশন টিপিকাল সাউন্ড একদম সাউন্ড এডিট বেস্ট ইউনিভার্সিটি'],
#  ['rec_52_audio_26.wav',
#   'আসলে নির্বাচন হলে কোন দিকে উৎসাহ উদ্দীপনা নাই কিছু জায়গার স্বতন্ত্র যেখানে সত্য উত্তেজনা আছে আর নাইলে কোন উত্তেজনা নাই ও বিএনপি যদি নির্বাচন হয় তো'],
#  ['rec_52_audio_25.wav',
#   'আমার মনে হয় না আমি মানে নাটকের ভোট দিতাম আমি করি শুধু একটা আন্দাজি চামড়ার উপরে একটা কালি লাগানো মনে মানেন না দাও'],
#  ['rec_52_audio_38.wav',
#   'শাহরুখের পাঠান পাঠান আমার আসলে অত হাইলি রেট কিছু লাগছে না এই পাঠানো হিট হওয়ার পিছনে আমি উল্টা সালমান খানের একটা বড় ভূমিকা দেখি কারণ তার যে ক্যামেরা পাঠানো সবচেয়ে'],
#  ['rec_52_audio_37.wav',
#   'ফলাবার আমি খুব হতাশ হয়েছি আর সেকেন্ড বার ভাল্লাগছে আমার মতে ডাংকি একটা গুড ফিল্ড বাট ডাংকি ইরানির ওষ্ঠে অবহেলা আমার রবিবার করতে করতে'],
#  ['rec_52_audio_34.wav',
#   'এবারের দ্বিতীয়বার আমি গেছি আমি জানতাম এটা সিট ফিল্ড যাই দেখতে হইবো কারণ ছোট ভাই বোনে দেখতো তারার লগে দেখতে হইবো সো গেলাম'],
#  ['rec_52_audio_20.wav',
#   'ব্যবসায়ীরা দল ব্যবসায়ীরা রক্ষা দিলে সমস্যা আছে হরতাল বন্ধ করা দরকার'],
#  ['rec_52_audio_31.wav', 'কয়লা বাড়ার অভি কোথায় সেকেন্ড বার অভিজ্ঞতা'],
#  ['rec_52_audio_27.wav',
#   'তাও তো কিছু আসন তারা পাইল না নির্বাচন তো এবার চুরি নগ্নভাবে চুরি করা তো সম্ভব নয় লেংটা ভাবে শুরু করা তো সম্ভব নয় তারা আইলো না লন্ডন প্রবাসী নেতা হওয়ার দরকার নাই'],
#  ['rec_52_audio_41.wav',
#   'বেস্ট ক্যাটাগরি ফিলম মজা লাগতো না খুবই সুন্দর এবং জাওয়ান এর বিশেষ করে নায়িকা যে নয়ন তারা এক্সিলেন্ট করছে'],
#  ['rec_52_audio_11.wav',
#   'আগুন নির্বাচনগুলোর মত যেন মানে নামে নির্বাচন না হয় তাহলে ওই যে নির্বাচন এবার নির্বাচনটা খুব সুন্দর একটা চাল চালাচ্ছে'],
#  ['rec_52_audio_24.wav',
#   'প্রবন্ধ এবার তোর নির্বাচনটা তো হইবো তোর এত ভোট দেয়ার এলিজিবিলিটি আছে তো তুই এখন মানে আছোস আমরা যে আসন ও তো একজন প্রার্থী আমি যতদূর জানি আর কারোর জন্য না'],
#  ['rec_52_audio_17.wav',
#   'আমার মনে হয় না মানে ভীতু টিমে ই টিমে আমি তোমাকে লুকাই যাই মানে কত বড়'],
#  ['rec_52_audio_23.wav',
#   'তরী অর্থনৈতিক ব্যাপারে কি তা মনে হয় অর্থনৈতিক ব্যাপারটা তো আমি মানে কইতাম পারতাম না কারণ এই ব্যাপারে জ্ঞান কম যেটা এটা জনগণের চোখে দেখলাম যে দেশের অবস্থা খুব বাদ কিন্তু আবার কি কথা ওটাও আমি জানি যে ইবাদত অবস্থায় সরকারে করছে যদি কেউ সামলাইতে পারি সরকারেও সামলাতে পারবো নাইলে কোনো আসা দেখলাম না'],
#  ['rec_52_audio_13.wav',
#   'সেই চালটা খুব ফ্যান্টাস্টিক আছিল আমার মতে বাইরের জনগণনা দেখলো যে নির্বাচন হয়েছে খুব সুন্দর এটা উৎসব করে মুখর পরিবেশ কি করে তৈরি হইবো নির্বাচনের সময় অলরেডি স্বতন্ত্র প্রার্থী মানুষের বলে বাড়িয়ে দিয়েছে ফুল নির্বাচন'],
#  ['rec_52_audio_21.wav',
#   'আওয়ামী লীগের একটা কথা হইলো গিয়া আওয়ামিলীগের লাগি মরার মানুষ আছে এত বছর পরেও আওয়ামী লীগের লগে মরার মানুষ আছে কিন্তু বিএনপির নাকি মরবো না'],
#  ['rec_52_audio_39.wav',
#   'আমার কাছে বিশেষ করে সবচেয়ে এট্রাক্টেড এবং সবচেয়ে এভোকেট সিন টাইগার বহুত দিন বাদে আইছে এই পাঠান টা চলছে মূলত সালমান খানদের টাইগার লিখেছি তা ক্রিয়েট করছি পাশাপাশি অবশ্যই স্পাই ইউনিভার্সিটি একটা তৈরি হয়েছে'],
#  ['rec_52_audio_10.wav',
#   'তোর কিতা মনে হয় এবার তো নিশ্চয়ই হলা প্রতিদ্বন্দ্বিতায় নির্বাচন করতো না একটু হলেও তো কমপিটিটিভ করব এটা মজার চালিয়ে দিয়েছে যে নির্বাচন আগের গুলোর মত'],
#  ['rec_52_small_audio_1.wav',
#   'এটা ওতো রে এটা আসলে ডিজার্ভ করে না ঠিক আছে আসল দিক কত মজা পাইছি না মোটামুটি কিন্তু জাওয়ান'],
#  ['rec_53_audio_0.wav', 'মামু কিতা অবস্থা'],
#  ['rec_53_audio_11.wav', '<>'],
#  ['rec_53_audio_8.wav', 'পদ্মা সেতু আর দুই তিনবার করা লাগে সকালের খেলা খেলা'],
#  ['rec_53_audio_6.wav', 'ইন্দো রোজা'],
#  ['rec_53_audio_4.wav', '<>'],
#  ['rec_53_audio_10.wav', 'কুয়াশা দেখা যাক'],
#  ['rec_53_audio_9.wav', 'ঠান্ডা ঠান্ডা'],
#  ['rec_53_audio_14.wav', 'পি দিয়ে লাভ নাই'],
#  ['rec_53_audio_13.wav', 'পাহাড় অঞ্চলে বিবেচনা সামনে নির্বাচন লাগে না'],
#  ['rec_53_audio_3.wav',
#   'সালফারের মাঝে মাঝে ক্রিকেট খেলতে পারলাম বিকালে ফোনটা খেলতে পারিনা'],
#  ['rec_53_audio_5.wav', 'মন নাই'],
#  ['rec_53_audio_1.wav', 'আপনার'],
#  ['rec_53_audio_7.wav', 'বিয়ে-শাদী হয়েছে'],
#  ['rec_53_audio_12.wav', 'মিনিস্ট্রি করা যায় না'],
#  ['rec_53_audio_2.wav', 'পারি বিছনা কান্দি আও সাদা পাথর যাইতে চাইছিলাম'],
#  ['rec_53_audio_25.wav', '<>'],
#  ['rec_53_audio_32.wav',
#   'তোমার কথাবার্তা এত লাগে আফসোস করা লাগে আলহামদুলিল্লাহ'],
#  ['rec_53_audio_31.wav', 'তুমি কিতা'],
#  ['rec_53_audio_24.wav', '<>'],
#  ['rec_53_audio_30.wav', '<>'],
#  ['rec_53_audio_22.wav', 'বেশি'],
#  ['rec_53_audio_29.wav', 'বিয়া সাদি কিতা আগে আগে করা উচিত'],
#  ['rec_53_audio_17.wav', 'খেলার খবর কি না মোবাইল টিপলে কম পড়ে কিনা'],
#  ['rec_53_audio_18.wav', '<>'],
#  ['rec_53_audio_23.wav',
#   'জলেশ্বর ইনজুরি হয় চালাই ফ্যামিলি না হলেও খেলিস না ও খেলা বাদ দিয়েছিলাম'],
#  ['rec_53_audio_34.wav',
#   'বিয়া করলে দেশেও না সমস্যা নাই মামু আমার ওদের সাথে ইচ্ছা আছে দেখা যাক'],
#  ['rec_53_audio_21.wav', 'আসো সবাই করা দরকার'],
#  ['rec_53_audio_36.wav', 'মামা তোমার সাজেশন লাগে ধন্যবাদ'],
#  ['rec_53_audio_19.wav', '<>'],
#  ['rec_53_audio_35.wav', '<>'],
#  ['rec_53_audio_26.wav', 'আস'],
#  ['rec_53_audio_33.wav',
#   'এখন সমস্যা নাই দোয়া করিও আল্লাহ সঠিক সময় করাইতাম না'],
#  ['rec_53_audio_16.wav', 'খেলাধুলার কিতা খবর নেই'],
#  ['rec_53_audio_20.wav', 'বোকাচোদা'],
#  ['rec_53_audio_28.wav', 'শুক্রবার অফ থাকে না ভালো আছেন'],
#  ['rec_53_audio_15.wav', 'তেরি বার নির্বাচন হয়ে আসলে ওটা আগ্রহ নেই'],
#  ['rec_53_audio_27.wav', '<>'],
#  ['rec_54_audio_0.wav', 'কিতা করলাম'],
#  ['rec_54_big_audio_0.wav',
#   'তাই সে সবসময় আমারে ক্যাপ্টেন মানায় তারা আমারে তাড়াতাড়ি ক্লাস টিচার রুম থেকে ওয়াটার বোতল আমার দেখতে ভালো লাগে তোমার ভালো লাগে জানি'],
#  ['rec_54_audio_8.wav',
#   'আচ্ছা এখন তো শীতকাল চলে নাকি তোমার ফেভারিট ওয়েদার কিডা আমার ফেভারিট ওয়েদার হয়েছে আইসক্রিম তোমার সবচেয়ে প্রিয় গান আমি কোন ফ্লেভারের আইসক্রিম ভালো'],
#  ['rec_54_audio_27.wav', 'তোমার সিলেটের মাঝে হয়ে যাইতে ইচ্ছা করছে যায়নি'],
#  ['rec_54_audio_25.wav', '<>'],
#  ['rec_54_audio_10.wav', 'দুইটাই আসল মা ফ্রেঞ্চ ফ্রাই ভালো লাগে না'],
#  ['rec_54_audio_14.wav',
#   'তোমার বাসা থেকে বেশি তোমার মায়া হবে নাবিলার লগে তোমার কেমন সম্পর্ক তোমার ছোট বোন'],
#  ['rec_54_audio_16.wav', 'সিং মাদার তোমার মারিনি'],
#  ['rec_54_audio_31.wav', 'মজা লাগছে'],
#  ['rec_54_audio_21.wav',
#   'আজকে তো দুইটা গান কিতা একটা লাভলি গান আর একটাই 14 ক্রিসমাস ক্রিসমাস কেন'],
#  ['rec_54_audio_18.wav', 'আবিদ নামের মানে'],
#  ['rec_54_audio_17.wav',
#   'আচারে বাসার বাকি সবর কিতা খবর তোমার ফাহাদের কিতা খবর তোমার বেস্ট মানুষ'],
#  ['rec_54_audio_20.wav', 'তুমি তো গান পছন্দ এখন কিতা খবর'],
#  ['rec_54_audio_9.wav', 'চকলেট আর ভেনিলা মিক্স করে'],
#  ['rec_54_audio_30.wav', 'একটা বারবির দাম 3000 টাকা দাম'],
#  ['rec_54_audio_12.wav',
#   'আমি ইউ ক্যালকাটা আমেরিকান গর্ত আমার সাউথ কোরিয়ান করে দাও বুঝলাম ইউনাইটেড কিংডম সাউথ কোরিয়া'],
#  ['rec_54_audio_24.wav', 'রাইবো নিতেছো বয়স কেমন'],
#  ['rec_54_audio_23.wav', 'ভেড়ার লগে মারতে কিতা মজা লাগে ইংলিশে'],
#  ['rec_54_audio_15.wav', 'মাঝে মাঝে ভালো লাগে মাঝে মাঝে এসেছে ভালো লাগেনা'],
#  ['rec_54_audio_1.wav', 'আর টিচার টিচার টিচার ছাড়া'],
#  ['rec_54_audio_2.wav', 'নাম কি তাহলে'],
#  ['rec_54_audio_22.wav', 'তোমার লন্ডন দরকার'],
#  ['rec_54_audio_3.wav',
#   'তোমার ফেভারিট টিচার কে ছাড়াও ভালো লাগে ইংলিশ রায় আর ইংলিশ টিচারের নাম লিখেছেন'],
#  ['rec_54_audio_29.wav', '<>'],
#  ['rec_54_audio_19.wav',
#   'তুমি তুমি তো তোমারে দেখিয়া কিন্তু আমি প্রথম ডরিমন দেখাইছিলাম তোমার এখন ফেভারিট কার্টুন'],
#  ['rec_54_audio_28.wav',
#   'সাদা পাতা ভালো লাগে তোমার এমনি কিতা পাহাড় পর্বত ভালো লাগেনা সাগর ভাল্লাগেনা'],
#  ['rec_54_audio_26.wav', 'স্কুলে পড়েন'],
#  ['rec_54_audio_7.wav', '<>'],
#  ['rec_54_audio_13.wav', 'তার জাতীয় ফুড ড্রাইভার লাগবে না'],
#  ['rec_54_audio_11.wav',
#   'স্পাইস পার্টি ফেভারিট কালার বেবি পিক কুন কুন দেশ গড়তে চাও'],
#  ['rec_54_audio_5.wav', '<>'],
#  ['rec_54_audio_6.wav', 'সৌরজগৎ সম্পর্কে তোমার ভালো লাগে জানিনা'],
#  ['rec_54_audio_4.wav', 'আচ্ছা নাও'],
#  ['rec_54_small_audio_0.wav',
#   'মিষ্টি খাইতে ভালো লাগে না আমার আমার জাল আর নুনতা জিনিস খাইতে ভালো লাগে এখন'],
#  ['rec_55_audio_18.wav',
#   'সাদা পাথর ভাল লাগে সাদা পাথর আর কি বেটার বিছনা কান্দি নাকি তোমার কোন কোন দেশে ঘুরার ড্রিম গানটি'],
#  ['rec_55_audio_23.wav',
#   'তো যে সময় বিচর কথা উঠলে সেন্টমার্টিনে বেস্ট কারণ কক্সবাজার ভুল হয়ে গেছে বেশি সুন্দর নীল পানি বেস্ট মানে এই সপ্তাহে দেখা যায় লাগে ফুল দুনিয়া তোমার নিচে আলাদা একটা ফিলিংস'],
#  ['rec_55_small_audio_0.wav', '<>'],
#  ['rec_55_audio_3.wav',
#   'টাইট স্কেলার কি তোমরা পরীক্ষা হবে ইন্টার পরীক্ষা জুন মাসে ইনশাআল্লাহ ইনশাআল্লাহ'],
#  ['rec_55_audio_9.wav',
#   'সুন্দর গাড়িয়া গেলে তো আরো মজা লাগে আমরা সুন্দর গাড়ি ও গেছিলাম যে সিনেমাটা দেখলাম'],
#  ['rec_55_audio_1.wav', '<>'],
#  ['rec_55_audio_17.wav',
#   'মানে বাইরে থেকে মানুষ এলে তারা মনে করে বাকা জায়গা আছে বাট আমরা মানে সব জায়গায় ঘুরে এসেছি তো আমার কাছে ভাল্লাগে বিছনা কান্দি ভালো লাগে আর'],
#  ['rec_55_audio_7.wav',
#   'শ্রীমঙ্গল আসলে যাওয়ার আগে ছিলাম না যে মানে কি লাভ হইবো আমি ভাবছিলাম যে হয়তো সিলেটেও তো সেই সাবা গানটা বাজান পশ্চিমবঙ্গ'],
#  ['rec_55_audio_14.wav',
#   'আমার কাছে ভালো লাগছে বেশি জাওয়ান কজ পাঠানোর স্টরি ঠিক আছিল মোটামুটি পাঠানোর'],
#  ['rec_55_audio_15.wav', 'স্টোরি লাইন ঘুরে ফিরে তার টেরোরিজম লইয়া ছিলেন'],
#  ['rec_55_audio_21.wav',
#   'আসলে দেখা যে সময় ফার্স্ট দেখেছি আমার এক্সপেক্টেশন আছে যে খুব সুন্দর মানে সপ্তাহ খুব সুন্দর খুব মজা করমু ঠিক আছে মজা করছি কিন্তু মানে আসলে সিলেট আর ঢাকার মাঝে মানে বহুৎ পার্থক্য'],
#  ['rec_55_audio_10.wav',
#   'আসলে ডাংকি লইয়া আমার যে এক্সপেক্টেশন আছে ফুলফিল করছে কারণ শাহরুখ খানের মুভি রিসেন্ট যে কয়েকটা আইছে এসব গুলো আছিল আর মেইনলি আমার একটা ভালো লাগছে যে তারা একটা ইনসিডেন্ট যে সুন্দর করে তুলে ধর'],
#  ['rec_55_audio_20.wav', 'ভিসা যাওয়ার কবিতা'],
#  ['rec_55_audio_2.wav',
#   'অন্য ভালো তো যাইতেই থাকা লাগে যাওয়া আসলে বেশি কষ্ট হয়ে যায় কারণ ক্যান্টনমেন্ট জার্নি করা লাগে টাইম হয়ে যায়'],
#  ['rec_55_audio_0.wav',
#   'আলহামদুলিল্লাহ তোমার কিতা অবস্থা কলেজে ফার্স্ট ইয়ারে ওটা বাদে খুবই ভালো লাগছে'],
#  ['rec_55_audio_5.wav',
#   'ফেভারিট ফুটবল প্লেয়ার স্পেসিফিক কিছু নয় কিন্তু মানে সব ফুটবল বালা লাগে যে মুড অন ফ্রী ফায়ার লাগে যে সময় তার কি খাবার পছন্দ করি'],
#  ['rec_55_audio_22.wav',
#   'বাংলাদেশ তোমার বাংলাদেশ ও আমার সেন্ট মার্টিন যাওয়ার ইচ্ছা আর সাজেক যাওয়ার বিচ ভালো লাগে আর পাহাড় ও ভালো লাগে আমি মানে কোনটা যে আলাদা করে সুজ করতে পারি না'],
#  ['rec_55_audio_4.wav',
#   'এইচএসসি কোন রকমের লাগবো কারণ একটা মেয়েটার ঘরে খুব বেশি আর এইচএসসি আমার আইসিটি লিয়া পড়তাম'],
#  ['rec_55_audio_12.wav',
#   'শাহরুখ খানের রোমান্টিক লাস্ট শাহরুখ খান আর মানে নায়িকাদের সময়'],
#  ['rec_55_audio_11.wav',
#   'এগজ্যাক্টলি কিতা হয় ধর মানে বিদেশ যাওয়ার সময় মানুষের যে খেলা কষ্ট করে যায় যে তারা লাইভ চ্যাট করা যায় এগুলো জায়েগি বাট কোন সময় দেখা যায় তারা লাইক হবে মানে হিলা জেলা তারা আশা করছিল'],
#  ['rec_55_audio_25.wav',
#   'সময় কাটতো না তো পাক্কা দিন এই জিনিসটা আমার ভালো লাগছে একলা একলা থাকতে থাকতে'],
#  ['rec_55_audio_19.wav',
#   'মেইনলি আমার ড্রিম কান্ট্রি হইলো গিয়া ফেলা আমি চাইছি যে সৌদি আরব যাইতাম হজ করতাম কেন সরি আমার খুব সুন্দর লাগছে'],
#  ['rec_55_audio_16.wav',
#   'তখন তোমার সিলেটে কোন কোন জায়গা তোমার ফেভারিট ও আসলে আগে মনে হয় তোমার জাগা বগুড়া বাকি আর এখন সব জায়গা ঘুরে রিসিভ লাগে এখন মানে ছেলেটা এখন কোন জাগাও'],
#  ['rec_55_audio_24.wav',
#   'ভাষাটা আসলে যে সময় ভাইয়া আসলে ভাইয়া থাকতে সব মানে ভালো মানে সময় কাটতো ভাইয়া মজা টজা করতা তাই এত বেশি ফাইজলামি করে তো ভালো ওই সময় কাটতে পারে ভাইয়া আমি ফিল করছি যে আমি খুব বেশি মানে লোনলি'],
#  ['rec_55_audio_8.wav',
#   'আসলে ওর কি বাস একটা প্লেস আর খুব বড় বড় বাগান সিলেটে তো একটু ছোট আর শ্রীমঙ্গল হয়ে গেল নাকি খুব বড় আর লাইক সাগরের লেখা নাকি বাঙালি একটা ফিলিং লাগে আর বিশ্বাস করি'],
#  ['rec_55_audio_6.wav',
#   'আর স্পেশালি হইলো গিয়া রেস্টুরেন্ট সোলার মাঝে মেড গুলো খানি বেশি মজা লাগে মানে ক্লাস পালা'],
#  ['rec_55_audio_13.wav', 'মানে নাই কার মানে বাঁচেনা মুভিটা খুব ভালো আছেন'],
#  ['rec_55_audio_27.wav',
#   'তুমি আসলে আমি তো নিজেও এখন বাসায় থাকি না ভাবির তো আসলে বিয়া বাদ দেওয়া বার্তা আমি কলেজে আর আমি বাসাতে থাকি না করলে রোজা কি একটু সময় থাকে আর এখন যেহেতু বন্ধ হবে সময় কাটায় তার লগে তাহলে একটু কম'],
#  ['rec_55_audio_28.wav',
#   'আর আমি কমিউনিকেট বালাবাড়ি তার লগে আমার লগে বালা মিশতে পারে কমিউনিকেট করতে পারে না'],
#  ['rec_55_audio_26.wav',
#   'যে বেশি আবার একলা লাগতো আস্তে আস্তে আল্টিমেটলি আর কি মানে হইতে হইতে দিন যাইতে যাইতে এখন ওই পাশে গেছে এখন তো আর পড়াশোনা বেশি বাড়ছে সো পড়াশোনাটা একদিন দিন'],
#  ['rec_56_audio_20.wav',
#   'কানাডা তোমার মিনিমাম গার্মেন্টস কোন মেয়ে হইল 12000 টাকা ঠিক আছে আমি অবশ্যই তারা রে ছোট করি আর না বাট সমস্যা হলে কি তা যে সমস্যা হলো 12000 টাকা তো পাইছে ঠিক আছে বাট এখন একটা কোশ্চেন আনতে পারে যে তারা দিনের 9 ঘণ্টা ইনকাম করে ওটা ইনকাম করে তারা কিন্তু এডিশনাল কিছু ইয়া আছে'],
#  ['rec_56_audio_7.wav',
#   'বিজনেস এনালাইসিস অথবা ডাটা এনালাইসিস কিতা এটার নাম ডাটা এনালাইসিস এর মাস্টার্স অথবা পিএইচডি করা যাইবো প্রজেক্টর ইফেক্টিভ বলতে যে এটা তো হলো এপ্লাইড এপ্লাইড ফিল্ডার'],
#  ['rec_56_audio_12.wav',
#   'আচ্ছা পড়াশোনা করে পড়াশোনা করে পরীক্ষা দে বিসিএস এর হয়তো তুই জানিস যে বিসিএস ও রইলো কিন্তু এটার নাম যে এক্সসেপ্ট টেন্স এটা কতটুকু লো ঠিক আছে বিসিএস আর একসেপ্ট টা কতটুকু'],
#  ['rec_56_audio_0.wav', 'কিনো'],
#  ['rec_56_audio_26.wav',
#   'ঠিক আছে সিলেটের ব্যাপারে ডিফারেন্ট কিতা যে অন্যান্য'],
#  ['rec_56_audio_11.wav',
#   'হ্যাঁ দেখা গেল তার লাইফের হইলে এটলিস্ট দুই থেকে তিন বছর ঈগল লাগে বালা টিকে ইনভেস্ট করা লাগে নট জাস্ট হেড অথবা তাই এটা এটার নাম যে ভার্সিটিতে পড়া অবস্থায় যে ইনভেস্ট করে টাইম ইলা নাই যে সময় পরীক্ষা টা দিব বিসিএস তো কয়েকটা ধাপে ধাপে পরীক্ষায় পয়লা প্রিলিমিনারি লাগে তো মানুষের ফার্স্ট ইয়ার সেকেন্ড ইন্ডিয়া থেকে পড়া শুরু করি ইন দ্যাট কেস দেখা যায় 60 বছর এটলিস্ট'],
#  ['rec_56_audio_29.wav',
#   'সো তুমি যেন দাও না কেন তুমি দেশে থাকো অথবা বাইরের দেশে থাকো তোমারতো দরকার আছে এটলিস্ট একটা ছিল তো দরকার আছে ওই যে তোমার রইলো কানাডা তত মানুষ যার আমার গ্রামের ব্যাটা তিনমাস চার মাস আগে ইয়াবার লাগে পরশুদিন তার ফ্যামিলি লইয়া গেছে'],
#  ['rec_56_audio_17.wav',
#   '20 হাজার টাকা দিয়ে এখন কিতা করা যায় বাংলাদেশ ঠিক আছে 20 হাজার টাকা দিতো কিচ্ছু করা যায় না তুমি একটা সিঙ্গেল মধ্যে থাকো তুমি তুমি যদি একটা সিঙ্গেল রুমে থাকো থাকিয়া যদি ধরো মোস্ট অফ দা স্টুডেন্ট দেখা যায় বেচেলার অবস্থা হতো আরকি থাকে মানে মেসে উঁচু থাকে'],
#  ['rec_56_audio_2.wav',
#   'তাই তাহলে আপনি তো আমার কোনায় মানে আশা করছিলাম তখন ভালো নয় এখন বুঝলাম না শেষ হয়ে যায় না দেশের বাইরে যাইতাম কেন বুঝলাম না'],
#  ['rec_56_audio_18.wav',
#   'তুমি যে সময় সিঙ্গেল থাকো বা ধরো তোমার খানি বাবদ ফাঁকা পাবো তোমার গেল কি হলো 10000 টাকা কিন্তু আমি সিলেটর অবস্থা তুমি ঢাকা তাহলে তো 10 কিতা 15000 টাকা লাগিয়ে দিব সো এখন আমি কি তার হইলে আমার থাকা খাওয়ার টাকা তোলার লাগে তো আমি জব'],
#  ['rec_56_audio_8.wav',
#   'আর্টিকেল হচ্ছে এটা মোটামুটি ভালো হয়েছে যাই হোক পিওর সাবজেক্টটা আসলে হলো যে পেপারের কোন বিকল্প নাই বাট এই জিনিসটা হলো রেস্টুরেন্ট সবচেয়ে বড় সমস্যা হলো স্টুডেন্ট'],
#  ['rec_56_audio_3.wav',
#   'মেইন প্রবলেমটা কিতা হইছে মেইন প্রবলেমটা হয়েছে যে আমরা থার্ড ইয়ার পর্যন্ত আর কি রিয়েলাইজ করতাম পারি না যে আপনার একচুয়ালি কোন চ্যাপ্টার লওয়া লাগবো মোস্তফা স্টুডেন্ট যারা আছে মানে বেশিরভাগ সময় তারা দেখা যায় না যারা খুব বেশি ডিটারমাইন্ড বাইরে যাওয়া'],
#  ['rec_56_audio_16.wav',
#   'বাট তার যে সময় হলো যে এটার নাম তোমার প্রেমের অথবা স্যালারি তার যে সময় স্টার্টিং এবং 20000 দিয়ে ঠিক আছে তার হয়তো ইনক্রিমেন্ট হইবো 6 মাস অথবা নাম 20000 হই'],
#  ['rec_56_audio_5.wav',
#   'কয়লা তারা দেখে এলো যে ভার্সিটি ভার্সিটির যে অথবা তাই এপ্লাই করতে হবে একাডেমিক এক্সিলেন্স যদি রিকোয়ারমেন্ট হতো তাহলে তো আর কোন সমস্যা আছে তোমার আছে স্কিলস আছে'],
#  ['rec_56_audio_14.wav',
#   'একজনরে যে সময় হলো চুস করব কি তা এই সময় হল তোমার স্কিল অথবা তোমার তুমি কতখান নলেজেবল এগুলো ফ্যাক্টর তোমার লাকটা ও ফ্যাক্টর সো এখন বাই চান্স তোমার লাগে যদি সেভারটা না করে তাহলে তো তোমার সমস্যা সো এই জিনিসটার বেশি চলে বিসিএস'],
#  ['rec_56_audio_10.wav',
#   'কিতা কইতাম ই কল করিয়া ব্যালেন্স করিয়া চলতে বহুৎ কষ্ট হয় আর একটা জিনিস হল যে সরকারি চাকরির যে প্রবলেম আছে সরকারি চাকরি'],
#  ['rec_56_audio_23.wav',
#   'এগুলো কি কোন ইয়ে থাকত না সো এই টাইমটা দিল মানুষের খুব বেশি প্রকট হয়ে যায় আর আর একটা জিনিস হল একটা মানুষ সবচেয়ে বেশি সবচেয়ে ভালো অবস্থানে কোন সময় থাকে'],
#  ['rec_56_audio_9.wav',
#   'প্যাটার্ন ট্রাস্ট ধরতে ধরতে দেখা যায় যে ফোরটি আর শেষ হয়ে যায় অথবা ফোর্থ ইয়ারের মাঝখানে যে পরিমাণ একটা প্রেসার থাকে একটা স্টুডেন্ট যে সময় এটা প্রেসারের মাঝে থাকে সো এই সময় হলো তার লাগে এই জিনিসটা হলো যে একাডেমিক প্রেসার আর সাইডে হইলো যে বাইরে যাওয়ার প্রেসার দুইটাই হলো'],
#  ['rec_56_audio_6.wav',
#   'জিয়ারি স্কুল আছে ইভেন রিসার্চ পেপার পাবলিশ করার একটা ফ্যাক্টর আছে সরি কিছু কিছু ক্ষেত্রে রিচার্জ পেপার খুব বেশি ইফেক্টিভ আবার কিছু কিছু ক্ষেত্রে ইফেক্টিভ যেমন যারা হইল যে বিজনেস এন্ড'],
#  ['rec_56_audio_25.wav',
#   'মানুষের হলো বাসাটা কি টাকাটা লোয়া আস্তে-আস্তে কমাইলে এখন ডিপেন্ডেন্সি একটা ব্যাপার আছে ঠিক আছে এখন মানসিকতা ও 20 হাজার টাকা স্যালারি লাগে অন্য কোন রাস্তা'],
#  ['rec_56_audio_24.wav',
#   'এট দা এইজ অফ দা এজ অফ বিটুইন 24 থেকে 28 শর্মা ঠিক আছে তোমার যদি 20 হাজার টাকা স্যালারি তুমি ইয়ে করো তো তুমি নিজে কি আর তুমি তোমার বাসা কোথায়'],
#  ['rec_56_audio_1.wav',
#   'মালা তোমার কিতা কিতা করতায় পরীক্ষা সেমিস্টার ফাইনাল মোটামুটি'],
#  ['rec_56_audio_13.wav',
#   'কিতা কইতাম আপনার একটা সময় লাগতো না নিজে এডমিশন টেস্ট আপনার চান্স পাই আমি বহুৎ হার্ড অথবা কিছু আছে পরীক্ষা দিলে আসন আছে 60000 ঠিক আছে সো মাত্র 1% 100 টা মানসম্মান'],
#  ['rec_56_audio_30.wav',
#   'ঠিক আছে কানাডা দিয়েছে 2000 টাকা হলে তোমার ইয়ে 2000 টাকা না 2000 কানাডিয়ান ডলার রইলো যে ঘর'],
#  ['rec_56_audio_19.wav',
#   'ঈদ জিনিসটা বাংলাদেশের প্রেক্ষাপটে স্টুডেন্ট তারার প্লাস হইল যে যারা হইল যে জব পিতা এটার নাম জব চারা দে তারা এই জিনিসটা আসলে বোঝা দরকার যে ফ্রেশের অত লোভ এজ থাকবো ইলা তো কিছু'],
#  ['rec_56_audio_28.wav',
#   'আমি হলাম যে এই বেটি রইলো এ আছে কিন্তু এটার নাম সিটিজেনশিপ আছে মানুষ জানত সমস্যা হইলো কিতা যে তুমি যে দেশে তুমি বোঝা হিসেবে থাকবে তোমার কোন স্কিল নাই সো তুমি আমার মাঝে গেম'],
#  ['rec_56_audio_15.wav',
#   'কাইন্দা তোমারিয়ে রিস্কি এন্ড একটা মানুষের যদি ধরো কুইক কুইক হলো জানি এস্টাবলিশ করতেছে খুব কষ্ট করে সিভিল ইঞ্জিনিয়ারিং'],
#  ['rec_56_audio_27.wav',
#   'অন্যান্য ইয়াদ কি তার নাম অন্যান্য বিভাগ ও দেখা যায় হইল যে মানুষের যে আমি ইন্টার পাশ না মানে বিএসসি কমপ্লিট করা বাদে আমি পড়ার উদ্দেশ্যে যাইমু তালা পড়াশোনা করেও সিলেটের ব্যাপার হলো আমারে যদি 60 বছর'],
#  ['rec_56_audio_4.wav',
#   'তারা কি তাহলে যে থার্ড ইয়ারের আগ পর্যন্ত তারা জাস্ট খালি একাডেমিক পড়াটা পড়াটা ফোকাস করে আর থার্ড ইয়ারের বাদে এলো তারা বাইরের কান্ট্রির যাওয়ার লাগি চেষ্টা করে শরীর চেষ্টা করলে স্টেপ আছে যেমন'],
#  ['rec_56_audio_22.wav',
#   'এটাতো কিন্তু এক্সট্রা আবার খাটায় যেমন আটটা নয়টা থেকে শুরু হয় 6:00 টায় 5 টা অথবা শেষ হইল বাট দেখা যাবে এক্সট্রা খামলা কাটাইব অথবা কাম করছো'],
#  ['rec_56_audio_21.wav',
#   'উপরে ইনকাম ও কিছু আছে ঠিক আছে আবার কাম করে ইনকাম আছে বাট একটা স্টুডেন্ট তার দিন রাতে করিয়া এক্স ভিডিও যদি মাত্র 20 হাজার টাকা ইনকাম করলে নাম প্রাইভেট প্রাইভেট কোম্পানি কিন্তু'],
#  ['rec_56_audio_33.wav',
#   'এসো আমার স্কুলটা আছে আমি থাকতাম আমার কামটা আমি করতে পারলে আমার হইল যে আমি মুড দেন এবার এই অথবা একটা ভালো সেলারি দিয়ে চলতে পারব যে আমি থাকবো আর যদি বাইরে যাওয়ার ধান্দা থাকে না'],
#  ['rec_56_audio_31.wav',
#   'কামলা যেত মানে যেহেতু কেসে খাম করবো তো কেসে কাম করলে বেশি হলে কত টাকা লাগবে আড়াইহাজার 3000 ডলার তিনটা বাচ্চা চলবো কিনা আফটার রেজাল্ট কানাডা তো আমি জানি ইউকে যাই আর'],
#  ['rec_56_audio_34.wav',
#   'আচ্ছা বুঝলাম আমরা যাওয়ার সমস্যা বুঝলাম আমরা তো জানি তোমার সিজিপিএ 3.8 আছে তোমারই তো সমস্যা হতো না এখন তো আমরা জানি তুমি ফুটবল ফুটবল ফুটবল ফুটবল ফুটবল খেলো এখন তো এইবার তখন আমি একটা টুর্নামেন্ট খেলা'],
#  ['rec_56_audio_38.wav',
#   'তোমার যদি আন্ডারস্ট্যান্ডিং না থাকে তুমি যদি অন ফয়লা খেলিলা কোন একটা পার্সোনাল লগে যে পার্সোনাল লগে তোমার আলাদা করে একচুয়ালি'],
#  ['rec_56_audio_35.wav', '<>'],
#  ['rec_56_audio_32.wav',
#   'মানুষ মেইনলি যার বাট এই জিনিসটা একচুয়ালি বোঝা দরকার যে তুমি কি এখনো কিতা করবা তোমার হইল যে মেইন পারপাস টা কি তখন তোমার যদি পারপাস না থাকে কোন কিছুর তাহলে তো আর হইতো না ঠিক আছে তো এই জিনিসটা কেউ যদি ডিটারমাইন্ড করে দিতে পারে'],
#  ['rec_56_audio_39.wav', 'বন্ডিং নয় অথবা তুমি আগে খেয়েছ নাকি'],
#  ['rec_56_audio_36.wav',
#   'একটি মহিলা সোহানা খেলা উচিত এবং ডাউনলোড দেখাও গেছে সামনে'],
#  ['rec_56_audio_40.wav', 'আমার তো এলো ভেরি আছে কিপিং করছি ঠিক আছে'],
#  ['rec_56_audio_37.wav', '<>'],
#  ['rec_57_audio_15.wav',
#   'ডাটা সাইন্স এর একটা বড় একটা চান্স চাইছি আপনার 2009 বছরেও আছে একাডেমি নাম একাডেমী একেবারে ঘোড়া থাকি'],
#  ['rec_57_audio_9.wav', 'আরো তো আমরা তো বা বুঝন আমি সব ডিপার্টমেন্ট এর'],
#  ['rec_57_audio_12.wav', 'আমি তো জানি পোলাপান 3.84 পরীক্ষা'],
#  ['rec_57_audio_5.wav', 'ওতো শুনলাম তো এক বছর আসলে প্রথমদিকে কিতা করে'],
#  ['rec_57_audio_0.wav',
#   'আরাফাত কিতা অবস্থা ঠিক আছে তোমার বুধবারের রওনা দিয়ে বৃহস্পতিবারে ভাইরে ভাই তোর ঠান্ডা মানে বাস কিতা কইতাম'],
#  ['rec_57_audio_3.wav',
#   'সিলেট আর উত্তরবঙ্গের থান্ডার কোম্পানির উত্তরবঙ্গ দুনিয়া ঠান্ডা ঠান্ডা'],
#  ['rec_57_audio_17.wav',
#   'আরো হৃদয়ে বলতে কি করবে আগে থার্ড ইয়ার উট কিছু করছে সম্পর্কে'],
#  ['rec_57_audio_18.wav',
#   'রিকিয়া এর বাদে যেন তুমি অথেন্টিক ডাটা অথেন্টিক কিছু পাওয়া তো লইয়া বিভিন্ন সফটওয়্যার তো তোমার পাইথন দিয়ে ভর্তা করা যায় আর মাইক্রোসফট এক্সেল ও আছে সব সময় ইনফ্রেস করে'],
#  ['rec_57_audio_8.wav', 'টাটা টাটা জুয়া'],
#  ['rec_57_audio_13.wav',
#   'না আসলে জেদ উঠবে না সে ও তো আসলে টপার মতো হয়ে গেছে'],
#  ['rec_57_audio_7.wav', 'ডাটা সেন্সর মুজতাহিদ সফটওয়্যার'],
#  ['rec_57_audio_4.wav', '<>'],
#  ['rec_57_audio_1.wav',
#   'হুডি হুডি লাগাইছি ঠান্ডা তো জায়গা মাছ কাছে আমি মনে হয়েছে আর তো ঠান্ডায় জরুর উঠিয়া ও আইলাম কোনমতে বৃহস্পতিবার'],
#  ['rec_57_audio_6.wav',
#   'ডাটা নিয়ে কিছু আছে ইঞ্জিনিয়ারিং ইকনোমিকস মেটেরিয়ালস কিছু আছে মেকানিক্স কথা তো দেখি কোন লাইনে যাওয়া যায় এখন একটা ফ্লো শুরু হয়েছে ডাটা নিয়ে বড় ভাই হবে'],
#  ['rec_57_audio_10.wav',
#   'তোমারে তো দেখলাম সেমিস্টার আমি কিতা করছি শুরু থেকে নোট করলে কিন্তু লাভ হয় নিজে'],
#  ['rec_57_audio_19.wav',
#   'এক্সেল একটু ভালা করি আপাতত প্রাইমারি লাগবে কিতা করা যায় না'],
#  ['rec_57_audio_14.wav', 'এখন জিনিসটা হইছে কি'],
#  ['rec_57_audio_2.wav', 'মনটন হারা ছুটি নেই'],
#  ['rec_57_audio_11.wav', '<>'],
#  ['rec_57_audio_16.wav',
#   'স্ট্যাটিসটিকস থেকে শুরু করি পাওয়ার স্কেল পাওয়ার বিয়াই পাইথন সপ্তাহে প্রজেক্ট আনছিলাম করতাম কিন্তু বড় ভাই এখন হয়েছে এখন'],
#  ['rec_57_audio_31.wav', '<>'],
#  ['rec_57_audio_27.wav', 'শেষ করিয়া রিয়া অর্ধেক শেষ হয়ে যাবো'],
#  ['rec_57_audio_22.wav', 'যদি আবার ইউসি হলো বাসায় গেলাম'],
#  ['rec_57_audio_30.wav',
#   'যদি আমরা সিলেট থেকে যেতাম পাঠিয়ে দিলাম 5000 টাকার হোটেল 800 টাকায় 15 হাজার টাকার নোটের রাষ্ট্রপতি'],
#  ['rec_57_audio_21.wav',
#   'তাপ দিতে গেল এবার কিম বালা কোন সালে তাড়াতাড়ি কিনছে সব ফিট হইলো আরো কিতা কিনছে জন্য যে গোল খাই'],
#  ['rec_57_audio_39.wav',
#   'ইনকিউবেটর আছে গবেষণা করে গবেষণা করার তথ্য মন্ত্রণালয় আইসিটি ডিভিশন আছে সব বাংলাদেশের'],
#  ['rec_57_audio_35.wav', 'আমরা এখন সিলেটে আছি'],
#  ['rec_57_audio_24.wav', '<>'],
#  ['rec_57_audio_36.wav', 'ভারত'],
#  ['rec_57_audio_32.wav', 'পুরা মাসুর বারবিকিউ খাইলাম যদিও মাছটা বাঁধ আছে'],
#  ['rec_57_audio_23.wav', '<>'],
#  ['rec_57_audio_37.wav',
#   'বিশাল রাস্তা গাড়ি-ঘোড়া হোম ক্লিন তোমার মজা লাগবে ও আর কি তোমার বন্ধু ফান্ডিং পাইল কিনা বাংলাদেশের'],
#  ['rec_57_audio_45.wav',
#   'ম্যাক্সিমাম কোন সেন্টার নরমাল দিব একমাত্র নরমাল ভার্সিটি টার্গেট হয়েছে'],
#  ['rec_57_audio_20.wav',
#   'একাডেমিক বক্তা জানলাম আমরা তো জানি ফুটবল তোমার বাক্যে জুলিয়া জমা আছে এখন থেকে বার্সেলোনা কিতা খবর কিছু থেকে'],
#  ['rec_57_audio_25.wav', 'আর কিতা খবর নাই'],
#  ['rec_57_audio_29.wav',
#   'রাখছি তো কক্সবাজার দুই দিন সেই মাটি নিয়ে আসবেন তাও খরচ কিন্তু সাড়ে আট বা নয়া লেগেছে'],
#  ['rec_57_audio_42.wav',
#   'আমি যেটা বলছি আমি যেমন কঠিন জিনিস লইয়া বেশি পড়ি না আমি তাকে কিন্তু ছাপা হয় দেখি যে আমার লোগোর যারা বন্ধু-বান্ধব সিসিটি চান্স হয়েছে'],
#  ['rec_57_audio_40.wav',
#   '50000 50000 50 হাজার টাকা কিতা করবো সাইকেল কিনব স্ক্যানিং করবো ইঞ্জিনিয়ার যত টাকা হবে'],
#  ['rec_57_audio_34.wav',
#   'কম খরচ সুন্দর শহর খাওয়া-দাওয়া আছে একটু মজা কি দরকার নাই'],
#  ['rec_57_audio_41.wav',
#   'এখন এডমিশন এডমিশন এডমিশন দিতে চায় তার প্রতি তোমার সাজেশন কিতা চাও'],
#  ['rec_57_audio_33.wav',
#   'তার এমনিতে রাজশাহীর দিনকাল কিলা যাতে ঠান্ডা ওয়েদার'],
#  ['rec_57_audio_26.wav',
#   'আর কিতা করতাম আজকে দেখি আজকে তো মনে হয় দাওয়াত আছে কিন্তু হয়নি যে জায়গাতে এক বছরে সেমিস্টার শেষ 11 মাসের শেষ করি আর একটা'],
#  ['rec_57_audio_38.wav', 'পিতা তোমার অন্তর ব্যানার্জি কোম্পানি'],
#  ['rec_57_audio_44.wav',
#   'আরেকদিকে অর্গানিক স্কিপ করি কিন্তু যেটা পড়া লাগবো ভালো করে পড়া লাগবো আর এক্সাম হল মাথা ঠান্ডা না অত কঠিন লিমিট আছে কঠিন'],
#  ['rec_57_audio_43.wav',
#   'আরেক গিয়ে দেখা যায় হে তোমার শর্ট সিলেবাসের বাড়ি কিচ্ছু পারে না কিন্তু তারা খাইছো কিনা তারা টেকনিক্যালি পড়ছে তারা তোমার কঠিন কঠিন জিজ্ঞেস করছে'],
#  ['rec_57_audio_28.wav',
#   'সেই লাগলো আসলে আর অক্সিজেন আছে তো মোটামুটি সব তোমারে প্রাইস কম আছি'],
#  ['rec_58_audio_5.wav',
#   'সামনে খুব ভালা কিছু একটা করতে পারব যদি চলতে থাকে তো পড়ালেখার ক্ষেত্রে অনেকেই আমারে কিছু সাজেস্ট করছে যে সময় যেটা পরমু লিখিয়া লিখে পড়া ট্রাই করতে কিন্তু যেহেতু আমরা সিলেবাস'],
#  ['rec_58_audio_10.wav',
#   'তারপরে উঠিয়া একটু ফোন টিপাই ফোনও টাইম নেই এর বাদে আমি নিজে খাওয়া-দাওয়া করি নিজের হাতে নিজে বানাই আমি যেহেতু সপ্তাহে খাইতে পারি না এর লাগি আমার লাগি ডেইলি হানি হইল গিয়া আমি সিরিয়াল আর মিল্ক'],
#  ['rec_58_audio_0.wav',
#   'আচ্ছা সো আমারে যে কয়েকটা টপিক দেয়া হয়েছে তার মাঝে আমি সবার আগে মারতাম সাইফ পড়ালেখা নিয়ে তো পড়ালেখা নেই পাঁচটা ফল আজকে আমি একটা এক্সপেরিয়েন্স শেয়ার করতে চাই রাম আমার পড়ালেখা রিলেটেড যেটা হলো আজকে আমার এক্সাম আছে'],
#  ['rec_58_audio_12.wav',
#   '35 মিনিট আমার লাগি যায় পড়তে দিন কাজল লাগিয়ে রেডি হইতে হইতে তারপর আমি বাড়ি যাই যদি বাসে আই তাইলে বাস আমার বাসার জালালাবাদ পয়েন্ট ও থাকে আর যদি বাসে নাই তাইলে হইল গিয়া আমার তিনবার গাড়ি ভাঙ্গিয়া ওয়ালাকে'],
#  ['rec_58_audio_6.wav',
#   'কিন্তু আমরা সিলেবাস যেহেতু খুব বেশি বড় তাকে সেমিস্টার এর লাগি দেখা যায় যে লেখালেখি অপরাধ গেলে সপ্তাহে এফেক্টিভলি পড়া যায় না চেষ্টা করা একটাও ভালো করে পড়ায় কিন্তু যেগুলো টা ছড়ায় না এগুলা টোটালি ইতানি আইডিয়া থাকে'],
#  ['rec_58_audio_17.wav',
#   'তারপর তো ক্লাস শেষ করিয়া আমি কোন সময় কোন কোন সময় এলো গিয়ে একটু ক্যাম্পাসে ফুচকা মারি তারপরে বাসায় যাই কিন্তু যে সময় আর কি আগে আগে ছুটি হয়ে যায় এসময় আর ক্যাম্পাসে খাওয়া দাওয়া করা লাগে না ডিরেক্ট বাসার জায়গা'],
#  ['rec_58_audio_13.wav',
#   'ফাস্টে হইল গিয়া বাসা থাকি আমি রিক্সা নিয়ে আম্বরখানা পয়েন্ট ও যাই আম্বরখানা পয়েন্ট থেকে বালেশ্বর আমার বাদে অন্য একটা রিক্সা দিয়ে আমি ডিরেক্ট ক্যাম্পাস হয় তৈলা নাই তে একটু সমস্যা হয়'],
#  ['rec_58_audio_4.wav',
#   'আর্মি টাইম মত হয় না ফাইনালে গিয়া অনেক প্যারা খাওয়া লাগে বাট তাও আমি চেষ্টা করি যে ঠিকঠাক মতো করার আর এই সাবজেক্ট আমার অনেক বেশি প্রিয় আমার প্যাশন থেকে আমি আইছি ইনশাল্লাহ আমি মনে করি যে'],
#  ['rec_58_audio_2.wav',
#   'যাতে একটু বুঝি বুঝিয়া পড়ার আর এত টাইম টারে বালা হরি ইউটিলাইজ করার ট্রাই করি কিন্তু সব সময় উঠে না সব সময় দেখা যায় যে পরীক্ষার আগে অনেক স্ট্রাগল ফেইস করা লাগে'],
#  ['rec_58_audio_9.wav',
#   'ডেইলি রুটিন স্টার্ট হতে হলে পহেলা থাকি স্টার্ট করা যাক আমি ঘুম থেকে উঠি খুবই সকালে খুবই সকালে যেমন ফজর বাদে পাও ওরকম টাইমে ঘুম থেকে উঠার বাদে সবার আগে নামাজ পড়ি'],
#  ['rec_58_audio_16.wav',
#   'ক্যাম্পাস ও কিছু হালকা পাতলা খাইলেই আমি ভাত খাইতে পছন্দ করি না বাইরে কারণ এটা হাইজেনিক কুয়েতে বানায় না আর আমার কাছে টেস্ট লাগে না এর লাগি আমি ক্যাম্পাসে কোন সময় ভাত খাই না আমি অন্য কিছু চাউমিন বা ড্রাই যে কোন কিছু খাইলেই লাঞ্চার'],
#  ['rec_58_audio_14.wav',
#   'আবাসে আইলে কত প্যারা হয় না কিন্তু বাসের টাইম সমস্যা হলে কি বাসের টাইম একটাই বাসের খুব বেশি এভেলেবেল না এর লাগি সব সময় বাসাইতে পারি না আচ্ছা যাই হোক তারপরে ক্লাস করি'],
#  ['rec_58_audio_8.wav',
#   'ইনশাআল্লাহ আর ও 2nd আমি যে টপিক নিয়ে মাথু তাহলে আমার ডেইলি রুটিন'],
#  ['rec_58_audio_15.wav',
#   'ক্লাস টাইমে ছুটি হয় কিন্তু ম্যাক্সিমাম ক্ষেত্রে দেখা গেছে যে হাইয়েস্ট চারটা পর্যন্ত ক্লাস হয় এর পরে ক্লাস থাকে না আর কোন কোন সময় এর আগেও ক্লাস শেষ হয়ে যায় তো যদি বেশি সময় ক্লাস থাকে তাইলে হইতেছে যে আমি'],
#  ['rec_58_audio_11.wav',
#   'সিরিয়াল প্রত্যেকদিন ব্রেকফাস্ট তারপরে আমি আস্তে আস্তে রেডিও যদি ক্লাস থাকে ক্লাসে যাওয়া লাগে তো পাসওয়ার্ড লাগিয়ে রেডি হইতে আমার এত টাইম লাগে আধা ঘন্টা'],
#  ['rec_58_audio_1.wav',
#   'এটাই হল গিয়া মাইক্রো অর্গানিজম স মানে কিছু জীবাণু নিয়ে তো যেহেতু আমার কোর্স অনেকটা মুখস্তবিদ্যা রিলেটেড এর লাগি আমার একটু কষ্ট হয় কারণ আমার মুখস্তবিদ্যার পাওয়ার খুব বেশি নাই তাও আমি চেষ্টা করি'],
#  ['rec_58_audio_3.wav',
#   'তো আমি যেন পড়ি আমরা ফাইনালের আগে দুইটা মিটার দেওয়া লাগে দেন ফাইনাল দেয়া লাগে তো পড়ালেখা করা কেন আসলেই কঠিন কারণ মিটার মেয়ে ফুল সিলেবাস খবর'],
#  ['rec_58_audio_7.wav',
#   'তো এটা একটা বড় সমস্যা আমার লাগি ওভারঅল কইতে গেলে আমার আর পড়ালেখার বেশিদিন নাই আমি প্লেন করিয়া রাখছি যে আমি আর এম এস বাদে আর করতাম না তো ফুলিয়ার দুই আড়াই বছরের ভিতরে সপ্তাহ শেষ হয়ে যাই'],
#  ['rec_58_audio_21.wav',
#   'এক্সাম থাকুক আর না থাকুক হালকা পাতলা কিছু টপিক দেখিয়ে রাখি যেটা কঠিন লাগে অথবা আর এক্সাম তাহলে তো আরো বেশি পড়া লাগবো বাট এক্সাম না থাকলে হালকা পাতলা দুইটা টপিক দেখিয়া রাখি'],
#  ['rec_58_audio_23.wav',
#   'আমি খুব তাড়াতাড়ি ঘুমানোর আগে রেডি হয়ে যায় না আমার যদিও ইনসাব নিয়ে সমস্যা আছে কিন্তু আমি ট্রাই করি যে যত আর্লি পসিবল বেটো যাওয়া যায় আমি তো আর লিপি বল বেড়ে যায়'],
#  ['rec_58_audio_33.wav',
#   'আমি এত এখনকার বাচ্চা করা লাগবো আমারে অন্য কোন সেকেন্ড কিছু দিয়ে বুঝানো যাইত না কিছু করলেও আমি কিছু মানতাম আমি চেষ্টা করছি একটাও করা লাগবো তারপরে আমার ছোটবেলার'],
#  ['rec_58_audio_19.wav',
#   'তারপরে আস্তে আস্তে একটু সময় রেস্ট নেই যাতে হরিয়া আমার একটু এনার্জি নেই কোন সময় ঘুমাই না আমি রাইট ছাড়া কোন সময় ঘুমাতে পারিনা আমি ওই লাগি হালকা একটু যেটা কি একটু 45'],
#  ['rec_58_audio_34.wav',
#   'মেমোরি আছে যেমন আমি বুধবার কুত্তার দৌড় খাইছি আল্লাহ বাঁচাইছে আমারে কোন বার কামড় দিছে না তারপরে একদিন লাগিয়া আমারে একটা গরু দৌড়ানি দিছিল আমি পানি তরমুজের ছবি গেছিলাম আর আমার এখানে বড় কাজিন সামনে আসলে দেখে আমারে বাঁচাইছে'],
#  ['rec_58_audio_36.wav',
#   'আর অনেকে প্রাইমারি স্কুল পাশ করিয়া স্কুল ছেড়ে গ্যাস লাগি যদি আমি নিজেও স্কুল চেঞ্জ করি গেছিলাম কিন্তু তাও আমার যে একজন বেস্ট ফ্রেন্ড আসলা তারা এখন পর্যন্ত 10 মিনিট ওভার সো দ্যা'],
#  ['rec_58_audio_25.wav',
#   'তার লাগি আমার রাস্তায় খুব বেশি দরকার হয় তো ওই লগে আমার ডেইলি রুটিন আমি যদি আমার আগের ডেইলি রুটিন এর লগে কম্পেয়ার করি তাইলে অনেক অমিল আছে কারণ আগে আমি দেরিতে ঘুমাতে যাইতাম দেরিতে ঘুম থেকে উঠতাম'],
#  ['rec_58_audio_32.wav',
#   'ছোটবেলা থেকে আমি খুবই ফাজিল টাইপের আসলাম আমারে সামলা নিয়ে খুবই মুশকিল আছিল আমারে যে যে সামলাইতে সব বিরক্ত হতো স্পেশালি আমি আম্মুরে অনেক সাজাইতাম আমার সাথে ইংরেজিতে'],
#  ['rec_58_audio_24.wav',
#   'বেরো গিয়া ঘুম লাগে না অনেক সময় আমি ফোনটি পাই আর ঘুম লাগতে লাগতে একটু লেট হয় বাট ট্রাই করি ঘুমানোর অন্য বাইরে আর পড়তে একদিন সকালে উঠা লাগে আর আমি সারাদিন'],
#  ['rec_58_audio_22.wav',
#   'তারপরে আমি এশার নামাজের এশার নামাজ পড়ি এশার নামাজ পড়িয়া আমি ডিনার তাড়াতাড়ি করি নাই ডিনার করিয়া আবার ঘুমাই'],
#  ['rec_58_audio_31.wav',
#   'যদি আমার বাসার পিছনে বাউন্ডারি এসেছিল খেলার লাগি ও তো সারাদিন বাইরে থাকতাম আমি আমার বড় ভাই আর আমার ছোট বোন আমরাও তিন ভাই বোন তো ওলাহান টাইম তাইতো'],
#  ['rec_58_audio_18.wav',
#   'হায়দার বাসের গাড়ি তো বাসায় যাওয়ার বাদে আসরের নামাজ পড়া লাগে আসরের নামাজ পড়ি লাঞ্চ না করা তাহলে লাঞ্চ করি নাই'],
#  ['rec_58_audio_27.wav',
#   'সপ্তাহে একটি ইমপ্রুভমেন্ট হয় এর লাগি আমি ট্রাই করছিলাম যে একটু সোহাল ঘুমাইয়া সহাল ওঠার অভ্যাস টা তো দেখলাম যে এতে আমি অনেক ফায়দা পাইছি তো হোলি আমি এলান সবসময় রাখতে পারমু'],
#  ['rec_58_audio_35.wav',
#   'নাইলে দিন আমার কিছু একটা হয়ে গেল নি আর আমার স্কুলও খুব ভালা ভালা ফ্রেন্ডস আছিল চাইল্ডহুড এখন আমার এই ফ্রেন্ডস তারার লগে আমার যোগাযোগ নাই নাই হইলেও হয় অনেক বিদেশ'],
#  ['rec_58_audio_20.wav',
#   'ওটাই আমার রেস্ট তারপরে মাগরিবের সময় ডিরেক্ট নামাজের কফি বা চা ও তার কিছু খাই হালকা নাস্তা করি হরিয়া হইলে আমার পড়তে হয় না'],
#  ['rec_58_audio_28.wav', 'অভাসা ধরিয়া ডাকতে পারি না থার্ড আমি যে টপিক নিয়ে'],
#  ['rec_58_audio_29.wav',
#   'এটা নিয়ে মাথা অনেক বেশি মজার অনেক স্মৃতি আছে ছোটবেলার জেতা শেয়ার করা শেয়ার করলে অনেক মজার মজা লাগবে তো ছোটবেলায় থাকি তো আমি জন্মগত সিলেটি আমি'],
#  ['rec_58_audio_30.wav',
#   'বড়ই সিজি জন্ম সবই আমার সিলেট তো আমার বাসায় যেহেতু শহরও আমি আর আমার নানা বাড়ি দাদা বাড়ি দুইটাই গ্রাম্য কিন্তু আমরা একদমই গ্রামেও যাইতাম না এর লাগি হইতে গেলে আমি মোটামুটি একটা বন্দি একটা জায়গার মাঝে বড়'],
#  ['rec_58_audio_26.wav',
#   'তো আমার লাইফে কোন ফ্লো আছিল না আমি বুঝতাম না আমি সময়ের কোন বরকত বার করতে পারতাম না আমার কাছে লাগতো যে টাইম এমনি জাগগে আমি কিছু করতে পারলাম না বাট আলহামদুলিল্লাহ এরপরে আমি একটু রিয়েলাইজ করলাম যে লাইফে কিছু চেঞ্জ জানলে সবটা'],
#  ['rec_59_audio_8.wav',
#   'কয়লা এক দুই বছর এড্রেস করতে একচুয়ালি আমার অনেক কষ্ট হইছে আমার মনে হতো যে কি পরিমান কষ্ট একচুয়ালি ঢাকার পর এখন জিনিসটা'],
#  ['rec_59_audio_9.wav', 'এটা হইলো গিয়া খুব পেনফুলি কালার সিনেমা'],
#  ['rec_59_audio_2.wav', 'তাই এত দেখা গেল ডাকাত আমি কিন্তু পারবো না'],
#  ['rec_59_audio_4.wav',
#   'দুই-তিন উইক অফ লাগান বিছনা নিজের রুম নিজের বাথরুম স্পেশালি আমি যখন বাসায় যাই এখনো আমার বাথরুমে গেলে আমি কত সময় এখন আমি মিস করি একচুয়ালি এন্ড দিস না নিজের বাথরুমের মধ্যে ফিলিংস কোন জায়গা থেকে'],
#  ['rec_59_audio_7.wav', 'একচুয়াল'],
#  ['rec_59_audio_5.wav',
#   'এই যে প্রথমদিকে প্রথমদিকে সেম আমার হইত প্রায় 2-3 মাস একচুয়ালি বিশেষ করে সকালবেলা সকালে প্রচুর কষ্ট হতো না সকালবেলা সেট করা আছে এলার্ম টোন টা সেট করা আছে অত স্যাড একটা এলার্ম টোন আমার এখানে লাগতো'],
#  ['rec_59_audio_6.wav', 'আমার নিজেরও মনে আছে এই এলার্ম টা আমারও সেট'],
#  ['rec_59_audio_3.wav',
#   'পাস দিন কিছু সাসপেন্স লাগছিলো সেই একটা নতুন লাইফ লিডার নাম্বার ঠান্ডা ঠান্ডা লাগছে কয়লা'],
#  ['rec_59_audio_0.wav',
#   'আমার মনে হয় পাঁচ বছর একচুয়ালি মানে ঢাকা লেখেনি আপনার মাথা হয়েছে যেহেতু আমরা সারাজীবন লাইক প্রথম কলেজ লাইফ পর্যন্ত সিলেট ও'],
#  ['rec_59_audio_1.wav', 'বাসা থেকে বারবার সুযোগ নেই'],
#  ['rec_59_audio_10.wav',
#   'বাজেট ম্যানেজমেন্টের ছেলে আমার থেকে মাহির বেটার এখনো বেটার আমি এখনো পারিনা আমি যাই পাই টাকা দেখা যায় যে একচুয়ালি আমার শেষ হয়ে গেছে'],
#  ['rec_59_audio_36.wav', 'জুনিয়র সবগুলা আমরা আন্ডারে তারপরে প্রোগ্রাম হলো'],
#  ['rec_59_small_audio_0.wav', 'শেষ'],
#  ['rec_59_audio_38.wav', 'এসময় যে আমরা 71 72 রেজাল্ট অফ বিশাল বিশাল'],
#  ['rec_59_audio_40.wav',
#   'সিএনজির জিনিস পড়াশোনা করেন একচুয়ালি প্রপার পরে ইন্টারনাল লাইফটা কি শুরু হইবো প্রফেশনাল লাইভ ঠিক আছে অন্যান্য ডিপার্টমেন্ট বা কিতা আছে'],
#  ['rec_59_audio_32.wav',
#   'ধানমন্ডি বানায় এটা খুব বেশি বড় একটা কমপ্লিমেন্ট বাংলাদেশের বানায় খুব কম'],
#  ['rec_59_audio_20.wav',
#   'ও 23 তারিখ হয়েছে মাটির যদি আমি হিসাব করি আমি কিন্তু আর একটা দোকান আছে বিসমিল্লাহ পাওয়া'],
#  ['rec_59_audio_39.wav',
#   'স্কুল-কলেজ ইউনিভার্সিটি সবগুলা একটা সিমিলার সিমিলারিটি আছে যে এটা বিগ গ্রুপ অফ পি'],
#  ['rec_59_audio_34.wav', '<>'],
#  ['rec_59_audio_30.wav', 'ধানমন্ডিতে বেশি'],
#  ['rec_59_audio_11.wav',
#   'সেন জিনিসের একচুয়ালি এখনো বাজে ম্যানেজমেন্ট এখনো শিখতে পারছি না অবশ্যই একটা কারণ খানি ঢাকার সানি লিওনের পুরান ঢাকার ধানমন্ডি আপনার কাছে অ্যাক্সেসিবিলিটি'],
#  ['rec_59_audio_17.wav', 'সময় এগুলো প্রাইস আছিল 120 টাকা 120 টাকা আছে 29'],
#  ['rec_59_audio_13.wav', 'শুরুর দিকে আসলাম'],
#  ['rec_59_audio_35.wav', 'কমপ্লিট মানেটি ভার্সেস'],
#  ['rec_59_audio_25.wav', 'আমি এরিয়ার ভালোবাসি'],
#  ['rec_59_audio_31.wav',
#   'ধানমন্ডি পিজা পার্ক আছে ঢাকার বেস্ট পিজ্জা পিজ্জা বাটনে অবশ্যই অবশ্যই জিসাস ক্রাইস্ট বলে কোন দোকান নেই'],
#  ['rec_59_audio_21.wav',
#   'বাট আমি যদি বিসমিল্লাহ দিয়ে পেট ভরতে হয় আমি বিসমিল্লাহ দিয়ে আমি দেখছি আমি পুরা পেতাম পেট ভরিয়া যদি খাই আমার 300 + মাস্ট যায় একটা চাপের কিছু হয়না বিসমিল্লাহ'],
#  ['rec_59_audio_29.wav',
#   'রেন টোটাল আমি দুপুর 2 টা থেকে রাত 8 টা পর্যন্ত নাজিরা বাজার সম্পর্ক'],
#  ['rec_59_audio_26.wav', '<>'],
#  ['rec_59_audio_41.wav',
#   'তারাক তুলনায় কইমু কম্পারেটিভলি ডিফেন্সে যে ডাক্তারি লাইনে থাকলে তোমাকে সারাজীবন পড়া লাগবে না'],
#  ['rec_59_audio_14.wav',
#   'তখন এক ছেলে আমি বোখারীর ভ্যালুটা বুঝছি না তো খাইছি মজা লাগছে এরপর আস্তে আস্তে যখন কয়েকবার খাইলাম খাওয়ার পর এক ছেলে আমি বুখারীর স্যালাইন লাগবে'],
#  ['rec_59_audio_12.wav',
#   'পুরান ঢাকা ধানমন্ডি উত্তরা ধানমন্ডি পুরান ঢাকা সিনা'],
#  ['rec_59_audio_16.wav',
#   'টাওয়ার চাপ আমি বুখারী গেলে একটু ছাড়া আর কিছু খাই না ইভেন আমি এরিয়ার গেলে আমি বুখারী ছাড়া আর কিছু তো যাইতে আমার মনটা অনেক ভালো লাগে'],
#  ['rec_59_audio_18.wav',
#   'এখন এলো গিয়া সিমটা আছে 220 220 টাকা 100 টাকা দাম সম্ভাবনা'],
#  ['rec_59_audio_19.wav',
#   'রানার মা ছেলেকে 220 আর সিনারি লেগে বুকে লেগে আড়াইশো তো আগে খাইছি দেখি সেইম জিনিস যদি 220 টাকা লাগে অবশ্যই তার খেলা ভালো লাগবে না'],
#  ['rec_59_audio_28.wav', '2 ঘন্টা'],
#  ['rec_59_audio_23.wav',
#   'দিদি আমি কম্পেয়ার করি একচুয়ালি মানে বর্থ হিসাব করলে আমার কাছে মনে হয় জিনিসটা বালা নেই দেন অবশ্যই ইয়ে আলু'],
#  ['rec_59_audio_42.wav', 'আজকে আলোচনা'],
#  ['rec_59_audio_37.wav', 'প্রোগ্রাম আছে আপনার লগে কাম করছে'],
#  ['rec_59_audio_27.wav',
#   'ইব্রাহিম আমি একদিন দুপুরে আসলাম আরেক জায়গায় খাইছি পাঁচটা দুপুরে খাইয়া পড়ে আইছি আমি হাজী বিরানি খাইছি তারপর আমি হানিফ বিরিয়ানি খাইছি তারপরে আমি বিউটি লাচ্ছি লাচ্ছি খাইছি ফালুদা খাইছি'],
#  ['rec_59_audio_22.wav',
#   'আমি যদি সেইম অ্যামাউন্ট সেইম টাকা দিয়া যদি আমি বিসমিল্লাহ খাই আমার ফ্রেন্ড ভরে না জিনিসটা কিন্তু একটা বড় একটা ফ্যাক্টর এই জিনিস আমারও এক সময় মনে হয়'],
#  ['rec_59_audio_15.wav', 'আইফেল আউট অফ লাভ উইথ'],
#  ['rec_59_audio_33.wav', 'হারিস ইন্ডিয়াতে বাংলাদেশের'],
#  ['rec_59_audio_24.wav',
#   'তাহলে আমারও তো ভালো লাগতো না আমার বুখারীর আলু টাই খুব ভালো লাগে হানিফ বিরিয়ানি আছে হানিফ বিরিয়ানি ফাস্ট টাইম বিরিয়ানি আমি খাইছি'],
#  ['rec_60_audio_0.wav',
#   'সালামুআলাইকুম ভাই সাগর আমি হইলাম ইন্ডিয়াজ এখন আমি আমার আত্মকাহিনী যতক্ষন পারা যায় একটু বর্ণনা করুন আমার কাহিনীটা শুরু হইলো'],
#  ['rec_60_audio_2.wav',
#   'অ্যানিভার্সারি আরো মানে চৌদ্দগুষ্টি সেপ্টেম্বর ইভেন্ট ফুল বালা দিক দিয়ে খারাপ দিক দিয়া বছর যখন সেপ্টেম্বর আয়তন'],
#  ['rec_60_audio_22.wav',
#   'নিরিবিলি আছে থার্ড ইয়ার ওঠার পর তাকে ডেভেলপমেন্ট লইয়া ইন্টারেস্ট জাগলো ডেভেলপমেন্ট'],
#  ['rec_60_audio_3.wav', 'ডর ডর লাগে কিতা না হয়ে যায় 99 সালে জন্ম হইছে'],
#  ['rec_60_audio_25.wav',
#   'মার্টিন পেডিং এই জায়গা আমার কথা এই তথ্য ভালো লাগছে না এত ইচ্ছা করে না সো মেনি ফাংশনাল জিনিসগুলো আমাদের প্রোগ্রামিং কিছু নলেজ'],
#  ['rec_60_audio_13.wav',
#   'সব রিলেটিভ বলতে হবে না ভার্সিটিতে শুরুতে একটু কোডিংয়ের লাইনে যাওয়ার ইচ্ছা ছিল'],
#  ['rec_60_audio_20.wav', '<>'],
#  ['rec_60_audio_17.wav',
#   'এসিএম হলে কানেক্টেড হয়েছে সোহান থেকে এরকম জার্নি শুরু হইলো গুড ফর'],
#  ['rec_60_audio_26.wav',
#   'আর এর পরে ডেভেলপমেন্ট লিখলাম তো এরপরে দোকানে আসলাম দেখি'],
#  ['rec_60_audio_8.wav',
#   'এসএসসির আলহামদুলিল্লাহ জিপিএ 5 পেয়েছি আল্লাহর রহমতে এর পরে ভর্তি হইতাম কলেজের এমসি কলেজে ভর্তি হইতাম না'],
#  ['rec_60_audio_21.wav',
#   'হৃদয় বাইদার রাস্তা একলগে করতাম ভালো লাগতো বাগবাড়ি মাঝে মাঝে পরিবেশটা ভালো লাগতো যাওয়ার সময়'],
#  ['rec_60_audio_12.wav',
#   'পাগল নাম থাকে না করোনা দিয়া না আসলে এটা সবার ক্ষেত্রে ভার্সিটির স্টার্টিং এ লাগানো হয় আর এর পর থেকে আস্তে আস্তে যত সময় যায়'],
#  ['rec_60_audio_28.wav', 'পার্মানেন্ট হতে চাইলে জুনিয়র'],
#  ['rec_60_audio_10.wav',
#   'এরপরে এখন থেকেই চিঠি দিলাম লিডিং ইউনিভার্সিটি 60 বছর খুব ভালো কাটছে যদি আমার স্নান করার লাগ'],
#  ['rec_60_audio_6.wav',
#   'বাংলা ভালো একটা স্কুল আছে সব বৃদ্ধিতে গেলাম এর পর থেকে বার্ড'],
#  ['rec_60_audio_24.wav',
#   'ফেইস বানাইলাম সিএসএস খুব একটা ভালো লাগছে না আমার বাট মেইনলি ফাংশন ফাংশনালিটি গুলা ভালো লাগছে ফাংশনাল জিনিসগুলো করতে ভালো লাগে'],
#  ['rec_60_audio_30.wav',
#   'জুনিয়র বলতে আর কে বয়সের দিক দিয়া আমি আসলাম সবগুলো ফ্রেন্ডলি করে লাগতো না'],
#  ['rec_60_audio_29.wav',
#   'হিসেবে হারাইলাম ওয়ার্কিং এনভারমেন্ট টা ভালো লাগছে না লাগছে নাকি আমার কলি সিনিয়র জুনিয়র জুনিয়র টা আমি ভালোবাসতাম লাইক'],
#  ['rec_60_audio_27.wav',
#   'অডিও একটা ভালো জব তারে 31 ট্রেন হিসেবে হারাইলাম 2 মাশাল্লাহ এখন আসলাম সেই নি জাস্ট অফিসের নাম করতাম না বাট ছাড়া কিছু গাইড দিতে ও গাইড ফলোয়ার'],
#  ['rec_60_audio_14.wav',
#   'লিডিং ইউনিভার্সিটি সাবজেক্ট হারান এসএসসি টাইম থেকে কম্পিউটার লাইনে যাওয়ার ইচ্ছা আছে এরপরে এইচটিএমএল সিএসএস দেখ'],
#  ['rec_60_audio_11.wav',
#   'এক দেড় বছর গেছি গা তো হইতে গেলে করণা আগ পর্যন্ত বালা হাঁটছে এটা সবার বালা খাটে এরপরে যত সময় যায়'],
#  ['rec_60_audio_7.wav',
#   'আসলাম গ্লোবাল ক্লাস টু থেকে পিএসসি জেএসসি এসএসসি রিসিভ করো স্কুল লাইফ খাটাইছে এর পরে এলো আমার কলেজ'],
#  ['rec_60_audio_5.wav',
#   'জামেদ ভর্তি হয়েছে কেজি আর ওয়ান পুরা কম্পিউটার থেকে জামে মসজিদ'],
#  ['rec_60_audio_19.wav',
#   'রাজ্যসভা পর্যন্ত টিম কোন টেস্ট ফুরিয়ে গেছি আরকি একটা আলাদা ভাষা ইসলামরা কিছু সিনিয়র আমরা'],
#  ['rec_60_audio_23.wav',
#   'স্টার্ট করলাম আইডিয়া কিছু একটা আছে ফোনটা কি জাভাস্ক্রিপ্ট জাভা স্ক্রিপ্ট লিখলাম লেন্ডিং'],
#  ['rec_60_audio_9.wav',
#   'বাচ্চা ছেলে আমি এমসি কলেজে পড়তাম তো এপ্লাই করেছিলাম 420 নদী'],
#  ['rec_60_audio_18.wav',
#   'বেশিরভাগ গল্পের ভার্সিটির এশিয়া টিম কনটেস্ট টিম কনটেস্ট করতাম টিমমেট লাস্টের দিকে লাস্টের দিকে'],
#  ['rec_60_audio_4.wav',
#   'স্কুল-কলেজ শুরু হয়েছে স্কুল শুরু হয়েছে শাহজালাল জামিয়া জামিয়া আমার আম্মা হইলো গিয়া জামিয়া টিচার দাও'],
#  ['rec_60_audio_1.wav',
#   'আমার জন্ম হয়েছে কেউ 1999 সালের 20 সেপ্টেম্বর সেপ্টেম্বর নিজের একটা আমরা গুষ্টির মাঝে একটা ইভেন্ট ভুল এটা মাস জন্ম'],
#  ['rec_60_audio_16.wav',
#   'এরপর থেকে লিডিং এ ভর্তি হইয়া নিজে থেকে কিছু প্রবলেম সলভ হয়ে গেছে অফিশিয়াল এসি মত দিন বেশি শুরুতেই আসলাম না নিজে থেকে কিছু করিয়া'],
#  ['rec_60_audio_15.wav',
#   'প্রোগ্রামিং নিয়ে আপনার ইচ্ছা ছিল রানিং করার ইচ্ছা আছে লাগে অন্য জায়গা থেকে রিডিং বসেছি'],
#  ['rec_60_audio_31.wav',
#   'দেড় দুই বছর হয়ে গেল এখন আর ভার্সিটিতে শেষ হয়ে গেল আর আমার বিদেশ যাওয়ার সময় হয়ে গেল ফ্যামিলি লিয়া এখন বর্তমানে আমেরিকা'],
#  ['rec_60_audio_34.wav',
#   'দুই-তিন সপ্তাহ আগে মানে বিদেশ যাওয়ার দুই তিন সপ্তাহ আগে অফিস ছাড়ি দিয়েছি'],
#  ['rec_60_audio_40.wav',
#   'সবথেকে বেশি আমার এবং আবার বেশি দিন হইছে না তিন সপ্তাহ হয়েছে এখন ক্রিসমাসের হলিডে চলে যাই'],
#  ['rec_60_audio_32.wav',
#   'সজ যাওয়ার আগে অফিসে আসার সময় খুব কষ্ট হয়েছে এখানে কষ্ট হয়েছে বলতে কলিকতার আইডি'],
#  ['rec_60_audio_33.wav',
#   'রাজ্যের ফেয়ারওয়েল দিছে আমারে যাওয়ার আগে তার মানে কল্পনার বাইরে আছি আমিও তো মায়া পাইছি খুব ভালো লাগছে'],
#  ['rec_60_audio_38.wav',
#   'দেশকে মিস করলাম এখন আর সবথেকে আমার হ্যাভেন গ্রুপে হ্যাভেন গ্রুপগুলো আমার ফুটবল গ্রুপের ক্যামেরা ফুটবল খেলায় জার্মানি সব থেকে বেশি মিস করো আমার ফুটবল গ্রুপে মানে'],
#  ['rec_60_audio_37.wav',
#   'ঠাকুর বেটা কালকের ভয় যেন অফিস সাহাদি ছাড়ার পরে মোটামুটি জয় কতদিন দেশে আসলাম কালকে আর দেশের'],
#  ['rec_60_audio_35.wav',
#   'ফ্রী ফায়ার ক্রিসমাস ফ্রী রাখতাম বিকাল হইলেও বন্ধুরা সময় হইলে পালকি নিয়ে যাবে সব কাজ রাফিদ আমি আমরা কইতাম আড্ডা দিতাম বিদেশেই যাতা মিস'],
#  ['rec_60_audio_36.wav', 'এরপরে আমি ফুটবল খেলা দিতাম'],
#  ['rec_60_small_audio_0.wav', 'স্যাটেলাইট সেন্টার'],
#  ['rec_60_audio_39.wav',
#   '2 ঘন্টা সেরা 2 ঘন্টা 3 দিন থাকতো সেরা 2 ঘন্টা অনেকদিন দুনিয়ার কোন চিন্তা নাই কোন টেনশন নাই কোন ডিপ্রেশন নাই দুই ঘণ্টা ওরা সেরা 2 ঘন্টা আছে'],
#  ['rec_61_audio_15.wav',
# ...
#   'তোমার ফাঁকাটা একটু ফাঁকা বই বই আসছি এখন থেকে আবার গেছি একটা ফ্রেন্ড'],
#  ['rec_74_audio_20.wav', 'তুমি যে আমার নাম ট্রাভেল চ্যানেলটি'],
#  ['rec_74_audio_24.wav', '<>'],
#  ['rec_74_audio_31.wav', '<>'],
#  ['rec_74_audio_23.wav',
#   'আজকেও ফ্রেন্ড থাকে যে তোমার অনেক টাইম দিবো যে তোমারে লোকাল গাইড হিসেবে পারব উত্তরটা পড়তে আর উত্তরও ছোট ছোট ম্যাজিক আছে তুই যদি অন্য একটা কিছু কাজ থাকে'],
#  ['rec_74_audio_15.wav', '<>'],
#  ['rec_75_audio_3.wav',
#   'তো আমি মারতে থাকো আরকি ন্যাচারালি আপনি যেটা মনে হয় আর কথা কইলাম আরকি কিতা তাহলে আমাকে যায়'],
#  ['rec_75_audio_6.wav',
#   'হইসিল যে বন্ধুটা দিয়ে তোর ওটা একটা সাইকেল কিনতে পারোস তুই মাঝে আমি একটা দেখলাম একটা লাল ধরন সাইকেল আছে সাইকেলে মেয়েরা কোন সময় চালাইছি না'],
#  ['rec_75_audio_5.wav',
#   'আমি সাইক্লিং শুরু করছি 2014 2014 লাস্ট স্কুলে থাকতে আমার বন্ধু রিফাতে আমারে হয়েছে'],
#  ['rec_75_audio_8.wav',
#   'সেদিন খুব আমি বাসা থেকে বারাইছি হোটেলে ফাস্ট পেপার গিয়ার সাইকেল সেকেন্ড ডবল এমটিভি মানে নরমাল সাইকেল নেই'],
#  ['rec_75_audio_2.wav',
#   'রেকর্ড করলাম 5 মিনিট মারতে তো আমার জান বাড়াই দিব আসলে আমি অন্য হোম বাটন চেষ্টা করলাম আরকি ভিন্ন ভিন্ন টপিক নেই আমার এক মিনিটও মারতে পারবো না অনলি'],
#  ['rec_75_audio_4.wav',
#   'আমি সাইকেল করি গেমিং করি একটা কোশ্চেন নিয়ে তাহলে খুবই ভালো হইলে আমার মনে হয় কোন পয়েন্ট টোন থাকলে ভাল লাগলে আমি পয়েন্ট ধরিয়া মারতাম পারলাম না'],
#  ['rec_75_audio_11.wav',
#   'ফিলোসফিক্যাল মাতৃ দিবস কোন সময় একলা একটা বাসা থেকে একটু দূরে গেলে মনে'],
#  ['rec_75_audio_10.wav', 'কেন মনে আছে বাজে'],
#  ['rec_75_audio_7.wav', 'কিনে আনছিলাম'],
#  ['rec_75_audio_12.wav',
#   'পকেটে 20 টাকা আজকে বৃষ্টি হলে মৌলভীবাজার গেছিলাম আর কিতা ও যেরকম কথা ছিল'],
#  ['rec_75_audio_0.wav',
#   'তো সকালবেলা ঘুম থেকে উঠছি ঘুম থেকে উঠিয়া বাক্যটা খুললাম'],
#  ['rec_75_audio_1.wav',
#   'কথা ছিল এখানে আমি করছি না আসলে আমার বন্ধু রাফিদা হইছে লিয়ে একটা 10 মিনিটের ক্লিপ দিতাম তারে অডিও ক্লিপ সিলেটি মাতার ন্যাচারাল দিয়ে রান্না নাতি আমি সব সময় ও যে আমি এখন'],
#  ['rec_75_audio_9.wav', 'সাইকেলে বানাইছি বাড়াইয়া হইছে'],
#  ['rec_75_audio_21.wav',
#   'সমস্যা হয়েছে সাইকেলের একেতো রোড বালা নাই আর একটা জিনিস আছে গিয়া সাইক্লিং বাংলাদেশের জেলার আইছে এই বাটে আমারটা আসলে ঠিক হয়েছে না'],
#  ['rec_75_audio_22.wav', 'একটা কোম্পানি আনছে সাইকেল'],
#  ['rec_75_audio_15.wav', 'বাসার টানে আরকি সময় কেমন করে জানি'],
#  ['rec_75_audio_20.wav', 'কিশোরগঞ্জ আর কিতা কইতাম অনেকে আবার বাংলাদেশের'],
#  ['rec_75_audio_19.wav',
#   'বালা লাগে আর কি প্যাডেল মারতে ভালো লাগে না আমার বন্ধুর লগে'],
#  ['rec_75_audio_25.wav',
#   'মানুষের একটা সুন্দর সাইকেল একটু অন্যরকম দেখতে গিয়ার আছে মানুষের শালা আমি শুরু করছি'],
#  ['rec_75_audio_28.wav',
#   'আর কিতা কইতাম রিসেন্টলি আমি আর একটা জিনিস আমার খুব ভালো লাগে গত কয়েক বছর ধরে তোমার কফি কফি মানে ডিনার কফি আরকি'],
#  ['rec_75_audio_27.wav', 'এটা আসলে কইয়া লাভ নাই'],
#  ['rec_75_audio_17.wav',
#   '2021 থেকে 2021 জানুয়ারি থেকে সাইটিং শুরু করছি আবার তো সালের কিছু নাই আসলে কইতাম না'],
#  ['rec_75_audio_13.wav',
#   'একলা কোন জায়গাতে যাইবা বাসা থেকে বাড়াইয়া বাঁকা দূরে 60 কিলোমিটার 70 কিলোমিটার রাস্তা'],
#  ['rec_75_audio_23.wav',
#   'তারা যে সাইকেল আনছে এটা এমটিভি সাইকেল হন এমটিভি সাইকেল এর কাহিনী'],
#  ['rec_75_small_audio_0.wav', 'সকাল কোথায় মাঝে'],
#  ['rec_75_audio_14.wav',
#   'একটা টাইমে গিয়া খুব এগজস্টিং লাগে রাইটার একেবারে লাস্টে তোমার যদি মানে ফিটনেস এলাম বালানো থাকলে আমার পার্সোনাল এক্সপেরিয়েন্স এগিয়ে আমি মানে রাইট থেকে আবার সময়'],
#  ['rec_75_audio_18.wav', 'মাই ছবি আমাকে ভালো লাগে না'],
#  ['rec_75_audio_16.wav',
#   'শত্রু সেটিং করছি এভাবে বিভিন্ন কারণে শেষ হওয়ার লাস্ট'],
#  ['rec_75_audio_26.wav', 'সাইকেলিং কালচারটা আসলে বাংলাদেশের লগে গেছে না'],
#  ['rec_75_audio_24.wav',
#   'চালাইতে চা বাগানের ভিতরে আরবিতে অফরোড চালাই তাই আরকি দূরে হইয়া মানে এই কোম্পানিটা সাইকেল'],
#  ['rec_76_audio_3.wav',
#   'বালা বালা এক্সপেরিয়েন্স হইতাছে সবার কাছ থেকে বিভিন্ন জিনিস জানারও অপরচুনিটি হইতাছে তারপর স্টুডেন্টের সাথে ক্লাস নেওয়া আসলে অন্য একটা এক্সপেরিয়েন্স'],
#  ['rec_76_audio_2.wav',
#   'অনলাইন জব বাসার বইয়া বইয়া আরাম আছে বাট ওই রকম যে একটা এনভায়রনমেন্ট যেটা ওই এক্সপেরিয়েন্স তো আমাদের তো যে সময় কেন জব পাইলাম এখানে আইলাম একটা ওয়ার্কিং এনভায়রনমেন্ট পাইতেছি সবার সাথে ডেইলি'],
#  ['rec_76_audio_0.wav',
#   'সো তুমি তো এখন টিচিং আসো আবার জবা করছো দুইটার মাঝে ডিফারেন্স কিতা আর তোমার পিনিয়ন অনুযায়ী যেহেতু কোনটা ব্যাটারি টিচিং এর মাঝে আবার কি ইচ্ছা আছে গ্রাজুয়েশনের পরে তো'],
#  ['rec_76_audio_1.wav',
#   'কোন অপারেশনটি পাইছি নাই জব করতাম তো ওইটাই কন্টিনিউ করছি আরকি গ্রেজুয়েশন এর পরেও তো ওইটা অনলাইন জবা সিট তো এখানে যে আমরা 627 আওয়ার সারকে কাম করা লাগ'],
#  ['rec_76_audio_14.wav',
#   'ফাইনাল বাদে যে সময় প্রজেক্ট আছে তো প্রজেক্ট এর আগে কোন ক্লাস হইত না ফেল লগে দেখা হইতো না মা হয়তো না আমরা যারা আছি জয়েন করছে'],
#  ['rec_76_audio_29.wav',
#   'এইচএস এর তখন আমি চেক করে উঠিয়া ঘুমাচ্ছিলাম ঘুম থেকে উঠিয়া হইতাম রেজাল্ট রেজাল্ট'],
#  ['rec_76_audio_12.wav',
#   'সফলা যদি না আমি একটু নার্ভাস আসতাম কিন্তু আচার নর্মাল কনভারসেশন বা তুমি হরি মাতায় তার স্টুডেন্টস রে আপনি হোলি মাথায় ধরতাম একটা জিনিস আমি খুব বেশি হার্ড লাগছে এটা স্টুডেন্ট আমার স্পেসিফিক কিছু টপিক হলে আমি বুঝতাম যে আচ্ছা'],
#  ['rec_76_small_audio_0.wav',
#   'এলাহা চাইতাম অতদূর আছেন কলেজ নতুন-নতুন এক্সপেরিয়েন্স হলো'],
#  ['rec_76_audio_19.wav', 'কিছু কিছু মানুষের লগে একটু মজা করতে করতে'],
#  ['rec_76_audio_21.wav',
#   'তো লাস্টে 9 জন আর দশটা উইক বাকি আছে আমরা 10 উইকেট প্ল্যান করলাম বিভিন্ন জায়গায় যাওয়া বা বিভিন্ন রেস্টুরেন্টে যাওয়া আর ওই লেগে সবে হয়েছিল'],
#  ['rec_76_audio_15.wav',
#   'মানে কাইন্ড অফ স্ট্রেস থাকে না অত বেশি যত বেশি আমি এক্সপেক্ট করছিলাম দেখা যাচ্ছে খুব শ্রেষ্ট ক্লাস লইয়া তখন দেখা যাবে মানে সামনে থেকে একটু খাইয়া'],
#  ['rec_76_audio_25.wav',
#   'ঘোরাঘুরি সবচেয়ে একলা একলা যাইতাম নিজের স্বাধীনতা হইতে গেলে ফাইল ইসলাম কিন্তু ফোন পাইছিলাম না ফোনের লাগে আমার মার কাছে যাওয়া লাগত আবার টাইম মতো ফোন জমা দেওয়া লাগতো তারপরে কিতা কলেজের সময় আইলো কলেজেও গেলাম'],
#  ['rec_76_audio_18.wav',
#   'নূরুল ইসলাম বলতে আমার কিছু জানা ছিল না যে কার লগে মারতাম না মাতাম কারণ আমরা এই পার্টিকুলার ইউনিভার্সিটি যে কোন ইউনিভার্সিটিতে সব ধরনের মানুষ হয় সব ধরনের মানুষ হয় আর সব জায়গা থেকে মানুষ আমি ফলাফল আমার লগে মারতাম না মারতাম এই গান বুঝছি'],
#  ['rec_76_audio_9.wav',
#   'দুইনাম্বার রাতে আব্বা সকালে সকালে সাড়ে চারটার দিকে সোজা'],
#  ['rec_76_audio_31.wav',
#   'খাওয়া-দাওয়া করছি সিলেটের কোনা কোনা করছি যদিও আমার এরিয়া বোকা আর অন্য কোন সাইটে নাই কলেজ হয়তো আমার মনে হলো যদি কলেজ হওয়া যায়'],
#  ['rec_76_audio_24.wav',
#   'স্টুডেন্ট লাইফ ফর ইউনিভার্সিটি তোমার স্কুল আর কলেজ লাইফ সম্পর্কে কিছু একটা শেয়ার করো আমার স্কুল লাইফ কলেজ লাইফ দুইটা খুব ভালা গেছে স্কুল লাইফ আমার আম্মা সব জায়গায় লগে লগে কিন্তু লাইনটা কি আমি সব জায়গাতে খেলা চাই আমার ফেরেশতারা লোকেশন'],
#  ['rec_76_audio_6.wav',
#   'সো এক মাসের লাগিয়ে কিছু চিন্তা করছিনা আমরা গ্রাজুয়েশন কমপ্লিট করা বাদ দাও রমজান আছে রমজান শুদ্ধ হয়ে যায় রোজা আছে রোজা মাসে আমি কিছু করছি না আমি জাস্ট খাইছি দেখছি আর আমি করছি'],
#  ['rec_76_audio_20.wav',
#   'কোভিদ টাওয়ার বাদে হইলো গিয়া খুব সপ্তাহ খিলান জানিনা যারা স্কুল ফ্রেন্ড আছিল ইউনিভার্সিটি আন্ডার সেকশন এর মাঝে 9 জনের আমরা ফিমেল গ্রুপ আছেন এবং মজা হচ্ছে না'],
#  ['rec_76_audio_16.wav',
#   'সম্রাট রেস কিছুটা হইল কমে যায় আর একটা জিনিস হয়েছে কি আমরা সেই মেয়ে ম্যাক্সিমাম মানে আমরা যারা জয়েন করছি আমরা একে আরেকজনের হেল্প করা আমি হেল্প পাই না ধরো আচ্ছা এটা কিতা করতাম যে যেটা জানে এর জন্য আরেকজন'],
#  ['rec_76_audio_26.wav',
#   'কলেজে উঠলে রঙিন চশমা চোখে লাগে ওকে লাগাইছে রঙিন চশমা ফাস্ট ইয়ার ঘোরাঘুরি করছি পরীক্ষা বাদ হয়েছে কতটা বাদ নাই কিন্তু মেথর অবস্থা বাদ হয়ে গেছে তখন'],
#  ['rec_76_audio_17.wav',
#   'কয়েক বছর সবচেয়ে বড় মানে বালা জিনিস হইলো গিয়া যে আমরা একজন আরেকজনের হেল্প ফায়ার আর যদি স্টুডেন্ট অবস্থায় এক্সপেরিয়েন্স কই ইকানো স্টুডেন্ট অবস্থায়'],
#  ['rec_76_small_audio_1.wav', 'তুই তাকে তিনবার আমার'],
#  ['rec_76_audio_4.wav',
#   'আমি যদি হই যে আগের জবার ওখানে জমির মেঝে আসলে এই জোকটা বেস্ট আগে যেটা ওয়েব ডেভেলপমেন্টের কাম করতো না কারো সাথে কোন ইন্ট্রোডাকশন এরকম কিছু আছে কোন সোশালিজেশন কিছু আছে না জাস্ট তুমি বইয়া বইয়া কর রায়'],
#  ['rec_76_audio_27.wav',
#   'তখন স্যারের বাসা চেঞ্জ করছি ভাষা ছাড়া রাখছি কিন্তু পারছিলাম কিন্তু কলেজে খুব মজা হয়েছে বলতে আমরা'],
#  ['rec_76_audio_10.wav',
#   'ইনো আমার বাদে মানে পুরা বুঝা গেছে স্টুডেন্ট টিচার মানে এক্সপেরিয়েন্সের আমরা টিচার এখন আমরা কোন দিকে আস'],
#  ['rec_76_audio_22.wav', 'ইগো হইল গিয়া আমার ইউনিভার্সিটিতে'],
#  ['rec_76_audio_5.wav',
#   'প্রতিজ্ঞা নেওয়ার পরে এরকম অনেক এক্সপেরিয়েন্স হইতাছে আর ভালো লাগেনা আমি আগে কোনো ট্রাই করছি না ইউনিভার্সিটি শেষ হয়েছে বা দুইদিন থেকে মাস্টার্স শরীর'],
#  ['rec_76_audio_13.wav',
#   'কবরের জীবন এক্সাম অফ হাসপাতাল বাট এখন আগে 10% পড়া লাগলে এখন 50% পড়া লাগে মানে স্টুডেন্টস আপনার লাগে আর একটা পেস্ট জিনিস আমার লাইফে যদি আমরা লাস্ট ইয়ারও আমরা অত বেশি ক্লাস'],
#  ['rec_76_small_audio_2.wav', 'তো কলেজে আমরা আমি তো মানুষ কলেজে আসলাম'],
#  ['rec_76_audio_32.wav', 'আমি জিন্দাবাদ'],
#  ['rec_76_audio_11.wav', 'এক সপ্তাহের ভিতরে তুমি জয়েন করো'],
#  ['rec_76_audio_30.wav',
#   'অটো এক্সাইটমেন্ট আমি আমার বিছানা থেকে উঠছি ওটার লগেও আমার ফোন আসেন আমার ড্রয়ারের উপরে ঠাস করে আমার ফোন নিয়েছে আমার ডিসপ্লে পোড়া বানিয়েছে আমার ফোনে আছেন আর একটা জিনিস হল আমি'],
#  ['rec_76_audio_33.wav', 'আমার ফ্রেন্ডসরা জিন্দাবাদ খুব গরম'],
#  ['rec_76_audio_28.wav',
#   'স্ক্রিনশট মারতে পারে আর আমার ফোনের মধ্যে স্ক্রিনশট মারার কোন ফাংশন আছে না আমার কাছে দুইটা পাঁচ থেকে ছয় মাস আছে খুব এক্সাইটমেন্ট আমার কাজিনুর রেজাল্ট'],
#  ['rec_76_audio_7.wav',
#   'রোজা বাদে আমার যেহেতু প্ল্যান আছে বাইরে মাস্টার্স করার ভর্তি হয়ে গিয়েছিলাম ডাক্তার ডাক্তার নায়ক এখানে ডাক্তার বা কিছু'],
#  ['rec_76_audio_8.wav',
#   'ভালো দেখা গেল যে একদিনে বইয়া যাকাত বইয়া 10 মিনিটের একটা সিভি পাঠিয়ে পাঠিয়েছি না যে আমি সিভি পাঠিয়েছি দুই রাইত খুব পড়াশোনা করছি'],
#  ['rec_76_audio_23.wav',
#   'তুই এটা খুবই ভালো এক্সপেরিয়েন্স এখন খুবই খারাপ লাগে যে তারা লগে আমার হয়েছে না এখন গেল আমরা দুজন টিচার আমার যদি হইয়া থাকে তখন আমরা স্টুডেন্ট ইউনিভার্সিটি তো তোমার'],
#  ['rec_76_audio_36.wav', 'পুলা গুলির আওয়াজ'],
#  ['rec_76_audio_39.wav', 'ও আল্লাহ হাফেজ কই দিলেন অতটুক'],
#  ['rec_76_audio_34.wav', 'লাচ্ছির দোকান আছে'],
#  ['rec_76_audio_38.wav',
#   'যদি আমরা শুরু করছিলাম যে আমরা যে 10 মিনিটের টাইম ও চাইল্ডহুড এক্সপেরিয়েন্স শেয়ার করমু এই জায়গাটা আমরা দুইজনে টিচিং এক্সপেরিয়েন্স শেয়ার করছি তাদের জন্য তো আমি পুরা স্টুডেন্ট টিচার স্টুডেন্টদের কম্বিনেশন ওর একটা কনভারসেশন হইলো আই গেস'],
#  ['rec_76_audio_35.wav',
#   'এগুলো আমি এখনো মনে করি আমার খুবই ভালো লাগে কিন্তু মারামারি হয় কিন্তু আমার সামনে'],
#  ['rec_76_audio_37.wav', '<>'],
#  ['rec_77_audio_1.wav', 'আল্লাহর প্রমিস এটা কি ইসলামিক গজল শুনবো'],
#  ['rec_77_audio_2.wav',
#   'বাচ্চা এর মাঝে একজন হলো আলেম বাকি 24 জন হলে জালেম এখন একজনের সব যদি নেন 24 জনের লাগব আপনার চেষ্টা করছেন চেষ্টা করছেন'],
#  ['rec_77_audio_3.wav', 'আপনারে আল্লাহ দায়িত্বশীল চেষ্টা করুন'],
#  ['rec_77_audio_0.wav', 'এখন'],
#  ['rec_77_audio_24.wav',
#   'আমার ফ্যামিলি ওজন কইলাম আমি যে সময় তুমি যে শুনো না নেই'],
#  ['rec_77_audio_12.wav', '<>'],
#  ['rec_77_audio_11.wav', '<>'],
#  ['rec_77_audio_16.wav', 'আগে যে সময় আসছে সাত ভাই চম্পা চাই না'],
#  ['rec_77_audio_10.wav', 'সরি সরি'],
#  ['rec_77_audio_13.wav', 'বিশাল আরো বেশি দরকার নেই'],
#  ['rec_77_audio_4.wav', 'আল্লাহর প্রমিস তুমি এখন আল্লাহর প্রমিস দেখতে চাই'],
#  ['rec_77_audio_7.wav', 'তিনজন যে বউ মনে করেন না'],
#  ['rec_77_audio_25.wav', 'ডিপেন্ড করে মানুষ বালানি আমার ওজন মানুষ পালাবে'],
#  ['rec_77_audio_14.wav', 'আই'],
#  ['rec_77_audio_5.wav', '<>'],
#  ['rec_77_audio_23.wav', 'ইকন সফটওয়্যার'],
#  ['rec_77_audio_15.wav', 'পড়ো তুমি দেখো হয়নি'],
#  ['rec_77_audio_17.wav', 'প্রাতিষ্ঠানিক লেখাপড়া দেখান'],
#  ['rec_52_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_52_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_51_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_55_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_0_chunk_2.wav', '<>'],
#  ['rec_63_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_51_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_63_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_55_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_5_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_7_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_2.wav', '<>'],
#  ['rec_68_big_audio_6_chunk_2.wav', '<>'],
#  ['rec_68_big_audio_6_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_4.wav', '<>'],
#  ['rec_68_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_3.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_4_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_6_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_6.wav', '<>'],
#  ['rec_68_big_audio_5_chunk_3.wav', '<>'],
#  ['rec_68_big_audio_5_chunk_0.wav', '<>'],
#  ['rec_68_big_audio_4_chunk_2.wav', '<>'],
#  ['rec_68_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_4_chunk_1.wav', '<>'],
#  ['rec_68_big_audio_5_chunk_2.wav', '<>'],
#  ['rec_69_big_audio_0_chunk_5.wav', '<>'],
#  ['rec_68_big_audio_7_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_3_chunk_2.wav', '<>'],
#  ['rec_69_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_5_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_4_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_1_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_5_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_1_chunk_3.wav', '<>'],
#  ['rec_72_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_69_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_4_chunk_0.wav', '<>'],
#  ['rec_69_big_audio_1_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_7_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_3.wav', '<>'],
#  ['rec_72_big_audio_6_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_7_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_5_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_7_chunk_3.wav', '<>'],
#  ['rec_72_big_audio_7_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_5_chunk_1.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_4.wav', '<>'],
#  ['rec_72_big_audio_5_chunk_2.wav', '<>'],
#  ['rec_72_big_audio_6_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_7_chunk_4.wav', '<>'],
#  ['rec_72_big_audio_6_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_73_big_audio_4_chunk_4.wav', '<>'],
#  ['rec_73_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_73_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_73_big_audio_0_chunk_4.wav', '<>'],
#  ['rec_73_big_audio_0_chunk_2.wav', '<>'],
#  ['rec_73_big_audio_4_chunk_1.wav', '<>'],
#  ['rec_73_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_6.wav', '<>'],
#  ['rec_73_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_73_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_73_big_audio_1_chunk_2.wav', '<>'],
#  ['rec_73_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_73_big_audio_4_chunk_2.wav', '<>'],
#  ['rec_73_big_audio_4_chunk_0.wav', '<>'],
#  ['rec_73_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_73_big_audio_1_chunk_3.wav', '<>'],
#  ['rec_73_big_audio_4_chunk_3.wav', '<>'],
#  ['rec_72_big_audio_8_chunk_5.wav', '<>'],
#  ['rec_73_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_73_big_audio_0_chunk_3.wav', '<>'],
#  ['rec_73_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_74_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_76_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_74_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_1_chunk_2.wav', '<>'],
#  ['rec_74_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_76_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_74_big_audio_0_chunk_3.wav', '<>'],
#  ['rec_74_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_74_big_audio_0_chunk_2.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 3005

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["contents"] = content

# %%
df
# Out:
#                    External_ID Contents  \
# 0          rec_50_audio_27.wav      NaN
# 1          rec_50_audio_25.wav      NaN
# 2     rec_50_small_audio_0.wav      NaN
# 3          rec_50_audio_30.wav      NaN
# 4           rec_51_audio_2.wav      NaN
# ...                        ...      ...
# 3000        rec_01_audio_3.wav      NaN
# 3001        rec_01_audio_0.wav      NaN
# 3002        rec_01_audio_2.wav      NaN
# 3003        rec_01_audio_1.wav      NaN
# 3004        rec_01_audio_6.wav      NaN
#
#                                                contents
# 0                                        কত মাসে কত আসে
# 1                            এটা আসলে বেশি লস হয়ে গেছে
# 2                                                    <>
# 3                             স্টেবল এস আলম গ্রুপ চালাও
# 4                                                   গেম
# ...                                                 ...
# 3000  ফরিয়া তারপরে বিকাল টাইমে উঠলাম নামাজ টামাজ পড...
# 3001  শুনছেন আপনার বাসার সবাই বা দেশের কি রকম পরিস্থ...
# 3002          কেন আমি কোন বালা কিভাবে ডিউটি ডিউটি করবেন
# 3003  ভিডিও গাড়ি ডিউটি টু বাড়ির সবকিছু ভালো আছে সব...
# 3004  ডিউটিটা করতে খুব ভাল লাগে সবকিছু মিলিয়ে খুব ভালো
#
# [3005 rows x 3 columns]

# %%
len(df)
# Out:
# 3005

# %%
df.to_excel("/content/drive/MyDrive/local_speech/others/benchmarks_codes_and_models/1. google-asr-inferences/1.9: sylhet-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
