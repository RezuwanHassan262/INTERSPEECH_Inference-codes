# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
# !pip install bnunicodenormalizer
# !pip install SpeechRecognition
# Out:
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bnunicodenormalizer
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22779 sha256=c8e26b27b833e09696260a722c7db83ab6875988be0bf610b0176a2ae74cf419
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/e9/16732a619cbf5a63fdc9f6e2f9eb5fcf73fa023735237330e9
# Successfully built bnunicodenormalizer
# Installing collected packages: bnunicodenormalizer
# Successfully installed bnunicodenormalizer-0.1.6
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.1

# %%
import speech_recognition as sr
from bnunicodenormalizer import Normalizer
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()
norm=Normalizer()

# %%
def infer(AUDIO_FILE):
    # use the audio file as the audio source
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text = r.recognize_google(audio, language ='bn-BD')
    text = str(text)
    return text
#     words=text.split()
#     text=[norm(w)["normalized"] for w in words]
#     return " ".join(text)

# %%
data_dir = '/content/drive/MyDrive/local_speech/Barishal/chunks/all/'

# %%
files = os.listdir(data_dir)
print(files)
print()
print(len(files))
# Out:
# ['rec_01_audio_59.wav', 'rec_01_audio_70.wav', 'rec_01_audio_66.wav', 'rec_01_audio_62.wav', 'rec_01_audio_68.wav', 'rec_01_audio_73.wav', 'rec_01_audio_71.wav', 'rec_01_audio_69.wav', 'rec_01_audio_60.wav', 'rec_01_audio_72.wav', 'rec_01_audio_61.wav', 'rec_01_audio_64.wav', 'rec_01_audio_75.wav', 'rec_01_audio_84.wav', 'rec_01_audio_77.wav', 'rec_01_audio_88.wav', 'rec_01_audio_82.wav', 'rec_01_audio_85.wav', 'rec_01_audio_80.wav', 'rec_01_audio_87.wav', 'rec_01_audio_78.wav', 'rec_01_audio_83.wav', 'rec_01_audio_81.wav', 'rec_01_audio_74.wav', 'rec_01_audio_89.wav', 'rec_01_audio_76.wav', 'rec_01_audio_79.wav', 'rec_01_audio_86.wav', 'rec_01_audio_92.wav', 'rec_01_audio_96.wav', 'rec_01_audio_94.wav', 'rec_01_audio_95.wav', 'rec_01_small_audio_0.wav', 'rec_01_audio_91.wav', 'rec_01_audio_98.wav', 'rec_01_audio_99.wav', 'rec_01_audio_93.wav', 'rec_01_audio_90.wav', 'rec_01_audio_97.wav', 'rec_02_audio_1.wav', 'rec_02_audio_2.wav', 'rec_02_audio_5.wav', 'rec_02_audio_3.wav', 'rec_02_audio_4.wav', 'rec_02_audio_0.wav', 'rec_02_audio_19.wav', 'rec_02_audio_14.wav', 'rec_02_audio_17.wav', 'rec_02_audio_10.wav', 'rec_02_audio_15.wav', 'rec_02_audio_13.wav', 'rec_02_audio_22.wav', 'rec_02_audio_8.wav', 'rec_02_audio_16.wav', 'rec_02_audio_20.wav', 'rec_02_audio_9.wav', 'rec_02_audio_7.wav', 'rec_02_audio_12.wav', 'rec_02_audio_11.wav', 'rec_02_audio_6.wav', 'rec_02_audio_18.wav', 'rec_02_audio_21.wav', 'rec_02_audio_30.wav', 'rec_02_audio_27.wav', 'rec_02_audio_23.wav', 'rec_02_audio_28.wav', 'rec_02_audio_26.wav', 'rec_02_audio_31.wav', 'rec_02_audio_29.wav', 'rec_02_audio_34.wav', 'rec_02_audio_36.wav', 'rec_02_audio_25.wav', 'rec_02_audio_24.wav', 'rec_02_audio_32.wav', 'rec_02_audio_35.wav', 'rec_02_audio_33.wav', 'rec_02_audio_37.wav', 'rec_03_small_audio_0.wav', 'rec_03_audio_5.wav', 'rec_03_audio_6.wav', 'rec_03_small_audio_1.wav', 'rec_03_audio_4.wav', 'rec_03_audio_2.wav', 'rec_03_audio_0.wav', 'rec_03_audio_1.wav', 'rec_03_big_audio_1.wav', 'rec_03_audio_3.wav', 'rec_03_big_audio_0.wav', 'rec_03_audio_13.wav', 'rec_03_audio_10.wav', 'rec_03_audio_9.wav', 'rec_03_audio_12.wav', 'rec_03_audio_18.wav', 'rec_03_audio_20.wav', 'rec_03_audio_19.wav', 'rec_03_audio_21.wav', 'rec_03_small_audio_2.wav', 'rec_03_audio_16.wav', 'rec_03_audio_17.wav', 'rec_03_audio_22.wav', 'rec_03_audio_7.wav', 'rec_03_audio_23.wav', 'rec_03_audio_14.wav', 'rec_03_audio_15.wav', 'rec_03_audio_8.wav', 'rec_03_audio_11.wav', 'rec_03_audio_35.wav', 'rec_03_audio_32.wav', 'rec_03_audio_34.wav', 'rec_03_audio_29.wav', 'rec_03_audio_27.wav', 'rec_03_audio_30.wav', 'rec_03_audio_38.wav', 'rec_03_audio_37.wav', 'rec_03_audio_26.wav', 'rec_03_audio_31.wav', 'rec_03_audio_39.wav', 'rec_03_audio_25.wav', 'rec_03_audio_40.wav', 'rec_03_audio_33.wav', 'rec_03_audio_36.wav', 'rec_03_audio_24.wav', 'rec_03_audio_28.wav', 'rec_03_audio_46.wav', 'rec_03_audio_51.wav', 'rec_03_audio_42.wav', 'rec_03_audio_44.wav', 'rec_03_audio_41.wav', 'rec_03_audio_47.wav', 'rec_03_audio_50.wav', 'rec_03_audio_48.wav', 'rec_03_audio_53.wav', 'rec_03_audio_52.wav', 'rec_03_audio_45.wav', 'rec_03_audio_43.wav', 'rec_03_small_audio_3.wav', 'rec_03_audio_49.wav', 'rec_03_audio_60.wav', 'rec_03_audio_58.wav', 'rec_03_audio_57.wav', 'rec_03_audio_61.wav', 'rec_03_audio_55.wav', 'rec_03_audio_62.wav', 'rec_03_audio_56.wav', 'rec_03_audio_54.wav', 'rec_03_audio_59.wav', 'rec_03_small_audio_4.wav', 'rec_03_audio_63.wav', 'rec_04_audio_6.wav', 'rec_04_audio_3.wav', 'rec_04_audio_12.wav', 'rec_04_audio_0.wav', 'rec_04_audio_9.wav', 'rec_04_audio_11.wav', 'rec_04_audio_5.wav', 'rec_04_audio_7.wav', 'rec_04_audio_4.wav', 'rec_04_audio_8.wav', 'rec_04_audio_13.wav', 'rec_04_audio_1.wav', 'rec_04_audio_10.wav', 'rec_04_audio_2.wav', 'rec_04_audio_36.wav', 'rec_04_audio_19.wav', 'rec_04_audio_33.wav', 'rec_04_audio_30.wav', 'rec_04_audio_34.wav', 'rec_04_audio_17.wav', 'rec_04_audio_28.wav', 'rec_04_audio_29.wav', 'rec_04_audio_23.wav', 'rec_04_audio_31.wav', 'rec_04_audio_32.wav', 'rec_04_audio_ ...
#
# 1062

# %%
info = []

for i in files:
    aud =  f"{data_dir}{i}"
    audDuo = []
    audDuo.append(i)
    try:
        pred=infer(aud)
        audDuo.append(pred)
    except Exception as e:
        audDuo.append("<>")
        #print(e)

    info.append(audDuo)

# %%
info
# Out:
# [['rec_01_audio_59.wav', 'আমি মনে হয় তোকে বলছিলাম'],
#  ['rec_01_audio_70.wav',
#   'সর্বশেষে সব মিলিয়ে যোগ করলে দেখা যায় আমারও আমিও 100 ও 100 বাট এখন হবে না ভাই'],
#  ['rec_01_audio_66.wav',
#   'যে এই ছেলেটার রেজাল্ট খারাপ বা এই ছেলেটা স্কিলফুল না এই ছেলেটার এদিকে অভিজ্ঞতা নাই এটা যদি অনেকে বলে মানুষ মানুষ মানুষ মানুষকে জাস করে ডিরেক্টরকে ছোট বানায় ফেলায় সমাজ থেকে শুরু করে সবকিছু'],
#  ['rec_01_audio_62.wav',
#   'আসলে কাজ কি আমি কিভাবে করলে যাইতে পারবো কে কিভাবে কিরকম ভাবে হয়েছে এটা আমার জানা দরকার নেই আমি যদি আমার কাজটা ঠিকমতো করতে পারে এটি আমার জন্য আমি আমার কাজে আমি অলসতা সময় না করেও করি না বাট বের করছে'],
#  ['rec_01_audio_68.wav',
#   'সবদিক দিয়ে মনে করো এখন 100 মানে কি হয়তো আমি আমার সাথে আমার জন্য দেখছি ভাই সে তোমার লেখাপড়া খারাপ হলেও গলাটা অনেক সুন্দর অনেক সুন্দর গান করে ঠিক আছে আমি দেখলাম'],
#  ['rec_01_audio_73.wav',
#   'বাগানে ফল হবে না নিজের বাগানের নিজেরই পরিচর্যা করা লাগবে না'],
#  ['rec_01_audio_71.wav',
#   'অথচ আমার যা আছে আমি যেটা ভালো পারি যেটা শিখতে পারবো যেটা আমার ইন্টারেস্ট আছে সামনে চললে আমি ভালো জায়গায় যাইতে পারবো না'],
#  ['rec_01_audio_69.wav', 'আমাদের সবারই কম বেশি থাকবে ঠিক আছে কোন দেশে থাকবে'],
#  ['rec_01_audio_60.wav',
#   'নিজের কাছে খারাপ লাগছিল বাট আগে এখন আর কোন খারাপ লাগে না যে ও একটা ভালো জায়গা আছে ও একটা জিনিস হার্ডওয়ার পরছে আল্লাহকে একটা এই জিনিস এই উপলক্ষে আল্লাহতালা ওকে ভালো জানেন এই জিনিসটি সবকিছু আমি চিন্তাভাবনা করে'],
#  ['rec_01_audio_72.wav', 'তাহলে তো আমার'],
#  ['rec_01_audio_61.wav',
#   'এখন জিনিসটা ডিফারেন্ট করে ফেলেছি যে আমি সব সময় নিজের দিকটা দেখি এখন আর মানুষকে নিয়ে ভাবি না আগে একটা সময় মানুষকে'],
#  ['rec_01_audio_64.wav',
#   'আমার ক্ষেত্রে আমার ক্ষেত্রে আমি কারো ছোট নিজেকে ছোট দেখিনি কিন্তু সে টাইম দিয়েছে সে কষ্ট করছে সে ভালো জায়গায় পাইছে আমি দেই নাই আমি বলিনি আমি অন্য কিছু নিয়ে ছিলাম আমি আমি পারিনি এইটাই কথা এখন আমি যদি বলি'],
#  ['rec_01_audio_75.wav',
#   'করছিলাম আমার এই স্কিল যেটা আমরা এখন করতেসি সি প্লাস প্লাস যা বা যাই আছে ওয়েবের সাথে এটা সম্পর্কটা একটু ডিফারেন্ট এবং ছিল যদি না পারো তাহলে করে নিতে পারবে ওয়েবে আমি বলি'],
#  ['rec_01_audio_84.wav',
#   'আমি পড়ে আছি এর জন্য আগে থেকে কমপ্লিট করতে হবে একটা ল্যাঙ্গুয়েজ ভালোভাবে কমপ্লিট করে তারপর ওই ল্যাঙ্গুয়েজ সব প্রবলেম সলভিং করতে হবে তুই যত প্রবলেম সলভিং করবে তোর মাথায় তো অত লজিক বিল্ট হবে'],
#  ['rec_01_audio_77.wav', 'ঠিক আছে'],
#  ['rec_01_audio_88.wav',
#   'আমরা একটা কাছে কতটা এফিশিয়েন্ট ভাবে করতে পারবো কতটা সোজাভাবে করতে পারবো না কম সময় করতে পারব ইফিসিয়েন্ট ভাবে করতে পারবো'],
#  ['rec_01_audio_82.wav',
#   'রিয়েক্টর যখন তুমি সিলেক্ট করলা তখন আচল তুমি কন্টেন ডেভলপার হয়ে তুমি আস্তে আস্তে কিন্তু ফুলস্টপ ডেভলপারের ভিতরে তুমি চলে যেতে পারতেছিনা ফোকাস করতে পারতাছে এবং জাভাস্ক্রিপ্টের কিন্তু তোমার ইএসপি যেটা আপডেট ভার্সন এটা শিখলে তোমার হয়েছিল'],
#  ['rec_01_audio_85.wav',
#   'তুই তত তোমাকে আরো তোর বেশি আরো ট্রেইনার গুলো ঘুরবে তার বেশি বুঝবে আমি রোবটের ইঞ্জিনিয়ারিং এ যেতে চাই কারণ আমার কাছ থেকে কিসের জন্য আমরা টেকনোলজি স্কুল জীবনযাপন সহজ করার জন্য'],
#  ['rec_01_audio_80.wav',
#   'ওটার উপর একটা সফটওয়্যার তোমার 2 জিবি নিয়ে নেয় 2 জিবি ও জায়গাটা নিয়ে নাই কিন্তু সেল জিনিসটা যদি তুমি আরো ইজিলি এবং আরো স্পিড যদি ভালো চাও মানে তুমি এটা যদি আরো ভালো কিছু চাও তাহলে এখন আমরা ওয়েব যদি করি যদি'],
#  ['rec_01_audio_87.wav',
#   'মানুষের জীবনযাপন সোজা হবে মানুষের একটা কাজকে মানুষের এই যে আমরা যে দুনিয়ায় বাস করি এখানে'],
#  ['rec_01_audio_78.wav', 'ভালো হ্যাকার হতে পারে'],
#  ['rec_01_audio_83.wav',
#   'অনিক তো তোমার সামনে যে ল্যাঙ্গুয়েজ গুলো না অনেকটা তোমার কভার করবে অনেকটা এরকম হবে আমিও ছিল এতো কিছু ভালো কিছু জানিনা বাট আমার ইচ্ছা সেটা নিয়ে ছয় মাস টাইম দেওয়ার 6 মাস টাইম দিয়ে দেখি জিনিসটা কি হয় কারণ স্কিলফুল আমার হতে হলে আমার সব ধরনের প্রোগ্রামিং ল্যাঙ্গুয়েজ লাগবে'],
#  ['rec_01_audio_81.wav',
#   'ডাবলুডাবলু ফেসবুক লিখে যদি আমরা এই করি আমরা সেম সেম ওয়ার্ডগুলো সেম নিউজ সবগুলো আমরা পেয়ে যাচ্ছি ওয়েবে এখন ওয়েব ছাড়া কিন্তু বিকল্প কিছুই নাই তুমি যদি একজন ভালো হয়ে 3.0% করতে পার'],
#  ['rec_01_audio_74.wav',
#   'ঈদের পর থেকে হচ্ছে হল ইনশাল্লাহ ই করবো যে ওয়েবের দিকে একটু শিফট হবে বাকিটা আল্লাহতালা কতদূর কি আগে ওয়েবে ডেভলপমেন্ট এর আগে আমি মনে করি আমি একটু কথা বলি ডেভলপমেন্ট ডেভলপমেন্ট নিয়ে আগে একটু'],
#  ['rec_01_audio_89.wav',
#   'বিজ্ঞান বিজ্ঞান হতে বিশেষভাবে অর্জিত জ্ঞান ঠিক আছে আমি আগে বলছিলাম আমাদের জীবনযাপন এবং সোজা করার জন্য যতটা কাজটি করতে পারি'],
#  ['rec_01_audio_76.wav',
#   'তোরে এইচটিএমএল সিএসএস জাভাস্ক্রিপ্ট তুই যদি তারপর বুঝতাম যেটা হলো সিএসএস সিএসএস এর একটা ফ্রেমওয়ার্ক এগুলো সুবিধা আছে তোর যদি এগুলা বুঝতে পারো'],
#  ['rec_01_audio_79.wav',
#   'যে যত আপনার ই করতে পারবে না দিন যত যাচ্ছে টেকনোলজিস্ট কত আপডেট হচ্ছে এখন যেমন তুমি একটা ফেসবুক ইউজ করতেছো ফেসবুক ইউজ করলে ফোনে দেখা গেছে যে'],
#  ['rec_01_audio_86.wav',
#   'যতদিন যাবে আমরা আমাদের দিব না কাজ সূর্য করার জন্য টেকনোলজি ইউজ করো এখন সামনের দুনিয়াটা হবে কি রোবটিক্স বা অটোমেশন অটোমেটিক হবে সব পরিবর্তন করবে'],
#  ['rec_01_audio_92.wav',
#   'শোনো শোনো এই জায়গায় একটু আমারে ভুল বোঝার আগে তুমি একটু আমার একটু আগে আমারে জিজ্ঞেস করো আমাকে ফোন দিছে ফোন দেওয়ার পর বলতেছে দেখো আমি তো কোথাও চান্স পাই নাই তোমার কত পারসেন্ট ওয়েবার আছে এরকম তখন আমারে বলছে কি চল আমরা একদিন বন্ধুরে বের হই'],
#  ['rec_01_audio_96.wav',
#   'আমাকে তখন আমাকে তখন ও আমায় বলতেছে বন্ধু কি অবস্থা কম টাকার ভিতরে ইউনিভার্সিটি কোথায় আছে আমি বলছি কম টাকার ভিতরে বলতে বলতেছি ভাই আমাদের তো এরকম খরচ আর তখন বলছে যে এখানে প্রাইভেট পড়ানোর কোন বই আছে কিনা এবার আমি বলছি তাহলে তোমার ধানমন্ডি'],
#  ['rec_01_audio_94.wav', 'কিরকম'],
#  ['rec_01_audio_95.wav',
#   'বুঝছি ঠিক আছে এখন বুঝছি হঠাৎ ফোন দিছে আমি তখন দুপুর আড়াইটা বাজে আমি তখন ঘুমাই আমি আবারও আমি আবারো সিওর হয়েছি'],
#  ['rec_01_small_audio_0.wav', 'স্কুল'],
#  ['rec_01_audio_91.wav',
#   'আরে সুমন ভাই তুই একটা জিনিস করে বললো ঠিক আছে তুই আমারে দাওয়াত না দিয়ে আরাফের মাধ্যমে'],
#  ['rec_01_audio_98.wav',
#   'জুবায়ের আছে তো তুই এখানে তুই আমারে বলবি আমি চিন্তা করছি তুই আমারে বলবে তোর কথা বলতে বলছে'],
#  ['rec_01_audio_99.wav', '<>'],
#  ['rec_01_audio_93.wav',
#   'তুই এত জুবায়ের আছ আমি আছি তুমি আমাকে জানাও তোর স্কুলের ফ্রেন্ড ও আমার কলেজ চলছে'],
#  ['rec_01_audio_90.wav',
#   'এর জন্য কিন্তু আমরা সায়েন্সের ইউজ করি না কোথায় কি করে'],
#  ['rec_01_audio_97.wav',
#   'বাসা বাড়ি এড়িয়ে বাসা নিতে হবে এরকম আমার সাথে প্রায় 20 মিনিটের মত কথা বললো তখন আমি ওরে সব কিছু খুলে বললাম তখন বলছে যে বন্ধু চল আমরা একদিন বেরোই কলেজে বসে ইফতার করে বের হওয়া সমস্যা নাই এখন আমি বলছি যে দুবারের সাথে কথা'],
#  ['rec_02_audio_1.wav',
#   'আমার পছন্দের শখ হল জ্ঞান হল না সকালে বিকালে রাইতে দুপুরে সন্ধ্যায় সব সময় গানগুলি'],
#  ['rec_02_audio_2.wav',
#   'আমি সকল ধরনের কানুন খালি বলিউডের হিন্দি গান টলিউডের বাংলা গান ভারতীয় বাংলা গান শুনি না'],
#  ['rec_02_audio_5.wav',
#   'ব্লোইং ইন দা ওয়েট এই গানের গায়কের নাম হয়েছে মোটামুটি ভালো লাগে না'],
#  ['rec_02_audio_3.wav',
#   'একবারে ভালো লাগে না এই গান গুলা আমি বেশিরভাগ সময় আমি'],
#  ['rec_02_audio_4.wav',
#   'ইংরেজি গান শোনাও ইংরেজি গান শুনতে আমার অনেক ভালো লাগে আমার পছন্দের ইংরেজি গান হচ্ছে'],
#  ['rec_02_audio_0.wav',
#   'মুন্না মুখিয়া সাধমান সৌমিক মোর আইডি হলো 024 23100 53 4142 7 মুই এখন আমার শখ নিয়ে কথা কমু'],
#  ['rec_02_audio_19.wav',
#   'এই সব গান শুনা ছাড়া আমার মুভি দেখতে অনেক ভালো লাগে মুভি দেখাও আমার অনেক বড় একটা সব মুভি দেখতে বেশি ভালো লাগে মুভির মধ্যে আমি'],
#  ['rec_02_audio_14.wav',
#   'এই প্যান্ডেল গান খুব ভালো লাগে সারা বেলা বন্ধ জানালা ক্যাফেটেরিয়া ক্যাফেটেরিয়া সারাবেলা বন্ধ জানালা'],
#  ['rec_02_audio_17.wav',
#   'একক প্রথম যে গানটা আমি শুনছি সেটার নাম হচ্ছে পাতার গান আমি একটা পাতার ছবি আঁকি পাতাটা গাছ হয়ে যায় গাজা মাথার সবুজ কচি পাতা কাজটাকে ছাতা মনে হয় কি সুন্দর লিরিক্স'],
#  ['rec_02_audio_10.wav',
#   'এভাটার কা নাম্বার খুবই ভালো লাগে গানের মধ্যে আমার যেসব জনরা আছে গানের জন্য'],
#  ['rec_02_audio_15.wav',
#   'উড়ছে ঘুড়ি ইচ্ছে ঘুড়ি তারপর এইসব গান ভালো লাগে এছাড়া আরো কিছু ব্যান্ড আছে সেই ব্যান্ডগুলোর কেন আমার এক কারে ভালো লাগে'],
#  ['rec_02_audio_13.wav',
#   'হুইচ এ মাইকেল জ্যাকসন একটা জ্যাকসনের গান বাংলা গান বাংলা গানের মধ্যে শিরোনামহীন নামে একখান ব্যান্ড আছে'],
#  ['rec_02_audio_22.wav',
#   'হলিউডের মুভির মধ্যে বেশি ভালো লাগে বেনেডিক নাম্বার ব্যাচের অভিনয় ড্যানিয়েল ডেল উইসের অভিনয় আর এলার্ম এর অভিনয় খুব ভালো লাগে'],
#  ['rec_02_audio_8.wav',
#   'এই তিন খান গান আমার বেশি ভালো লাগে এছাড়া আরো অনেক গায়ক আছে এর মধ্যে একজন হইলো কি আর রোবট প্যান্ট'],
#  ['rec_02_audio_16.wav',
#   'তারমধ্যে একটা হইছে জহির খানের গান গুলো এত সুন্দর এত সুন্দর এই গানগুলা খুললে খালি মনের মধ্যে খালি গান গাই শুনতে ইচ্ছা করে শুনতে ইচ্ছা করে হুনতে ইচ্ছা'],
#  ['rec_02_audio_20.wav',
#   'টলিউডের মুভি ও দেখিনা বলিউডের মুখ দিয়ে দেখি না ডাকলে ইউটিউব এর মুভি ও দেখিনা একটা মুভি দেখছি এইটার নাম হচ্ছে'],
#  ['rec_02_audio_9.wav',
#   'লেটস জেপেলিন নামের একটা গানের প্রথম ভোকালিস্ট এই বেটার কানে এত সুন্দর গলা এত সুন্দর যে কি আর কমু'],
#  ['rec_02_audio_7.wav',
#   'এই গায়কের গান গুলার মধ্যে সবচেয়ে বেশি ভালো লাগে ষ্টার ম্যান'],
#  ['rec_02_audio_12.wav',
#   'ক্লাসিক রক স্যালো আরো যেসব গান আছে তার মধ্যে আরেকটা হচ্ছে পপ জনরা পবনের গান অনেক ভালো লাগে এই দুজনের মধ্যে সবচেয়ে ভালো জেনারেটর গান লাগে'],
#  ['rec_02_audio_11.wav',
#   'ঝরনা যতগুলো আছে এর মধ্যে বেশি ভালো লাগে কেলাসিক রক এছাড়া সাইকেল মোটামুটি ভালো লাগে কিন্তু বেশি ভালো লাগে ক্লাসিক ক্লাসিক গান'],
#  ['rec_02_audio_6.wav',
#   'সাদিকা নামের আরো বেশি ভালো লাগে একজনের নামে একজন ইংরেজি গায়ক এই গায়কের'],
#  ['rec_02_audio_18.wav',
#   'শুনতে শুনতে অসাধারণ লাগে গান শুনতে আমার অনেক ভালো লাগে বেশিরভাগ ভালো লাগে যেসব গানের গিটারের টুংটাং টুংটাং বেশি'],
#  ['rec_02_audio_21.wav',
#   'চঞ্চল চৌধুরী ব্যাটারি কি ভালো অভিনয় করে মানে এত ভালো অভিনয় করে যে কি আর কমু অভিনয় খালি দেখতেই মন চায় খালি দেখতেই মন চায় খালি দেখতেই মন চায় আমি বেশি ভাগ সময়ই হলিডে মুভি দেখি'],
#  ['rec_02_audio_30.wav',
#   'অ্যানিমেশন মুভি অ্যানিমেশন মুভি আমার ভালো লাগে আমার লেটেস্ট দেখে অ্যানিমেশন মুভির নাম হচ্ছে গিয়া সোল্ড সোল মুভি আমার খুব ভালো লাগে একটা মানুষ মইরা যাই তার সোলার'],
#  ['rec_02_audio_27.wav',
#   'সেই সময় দেখি এছাড়া দেখার মত সময় হয়নি একটা মুভি একদিনে দেখি না তিন-চারবার বইসা দেখি 30-40 মিনিট করে বসে বসে দেখি'],
#  ['rec_02_audio_23.wav',
#   'ড্যানিয়েল টেনিস এর প্রথম দেখা মুভি টা হচ্ছে সে দেয়ালটি ব্লাড আর লিওনার্দো ক্যাপ্টেন হয়েছে টাইটানিক মুভির নায়ক এর মুভি ও আমার ভালো লাগে'],
#  ['rec_02_audio_28.wav',
#   'নবীর জন্মের মধ্যে আমার বেশি ভালো লাগে সাইকোলজিকাল থ্রিলার একশন কমেডি না একশন কমেডি ভালো লাগেনা একশন ভালো লাগে একশন মুভি'],
#  ['rec_02_audio_26.wav',
#   'মুভি দেহ মে দেখতে চাই খালি দেখতে ইচ্ছে করে খালি দেখতে ইচ্ছে করে কিন্তু বেশিরভাগ সময় তো পাই না বললেই আমি মুভি এর লেগে আমি মুভি যে আমি একটু সময় পাই সুযোগ পাই'],
#  ['rec_02_audio_31.wav',
#   'আফটার অর্থে দেখা যায় সেইটা নিয়ে হচ্ছে মুভির কাহিনী মুভি দেখা ছাড়াও আমার আরেকটা কাজ করতে খুব ভাল লাগে সেইটা হইতেছে গিয়া বই পড়তে ভালো লাগে'],
#  ['rec_02_audio_29.wav', 'একশন মুভি এছাড়া ভাল্লাগে'],
#  ['rec_02_audio_34.wav',
#   'নেকড়ের কি নিউক্লিয়ার খুলতে চাই নেকড়ে আর গাছপালা বরফ পাঁচ ছাদ দিতো গাছপালা'],
#  ['rec_02_audio_36.wav',
#   'হুমায়ূন আহমেদ স্যারের বই আমার বেশি ভালো লাগে কেননা মুভি দেখা আর বই পড়া ছাড়া আমার বেশিরভাগ কোন হবি টবি নেই তাই আজকের মত এখানেই শেষ'],
#  ['rec_02_audio_25.wav',
#   'এই বেটার মুভি দেখা শুরু করছি এরপর দিয়াই খালি বেটাকে মুভি দেখি'],
#  ['rec_02_audio_24.wav',
#   'প্রথম দেখা মুভি না সেটা মুভির মত একটা জিনিস সেটা হচ্ছে গিয়া শার্লক সিরিজ সেই সিরিজ দেখতে আমার অসাধারণ লাগছিল এরপর থেকে এই ব্যাটার মুভি দেখা শুরু করছি আমি'],
#  ['rec_02_audio_32.wav',
#   'আমার বই পড়তে অনেক ভালো লাগে আমার লেটেস্ট পরে বইটার নাম হচ্ছে গিয়া হোয়াইট ফ্রেন্ড লেখক এর নাম হচ্ছে কি আর জ্যাক লন্ডন'],
#  ['rec_02_audio_35.wav',
#   'একটা সুন্দর শুনছেন একটা গল্পের বই বাংলাদেশী লেখকের বই ও পড়ি হুমায়ূন আহমেদের বই আমার খুব ভালো লাগে জাফর ইকবাল স্যারের বইও অনেক ভালো লাগে তাই অত বেশি পড়ি'],
#  ['rec_02_audio_33.wav',
#   'লন্ডনের বই যে কি সুন্দর পড়লে খালি মনে হয় যে আমি ওই দেশের হিমবাহের মধ্যে চলে গেছি ঠান্ডা একটা পরিবেশ খালি বরফ আর বরফ আর খালি চাই না'],
#  ['rec_02_audio_37.wav',
#   'এই প্রেজেন্টেশন এ ও এলস ম্যামের এল সাবজেক্ট এর মিম লেকচারার ম্যাম এর অধীনে করা সবাই ভালো থাকবেন সুস্থ থাকবেন ইনশাল্লাহ আবার দেখা হবে কথা হবে আসসালামুয়ালাইকুম'],
#  ['rec_03_small_audio_0.wav', '<>'],
#  ['rec_03_audio_5.wav', '<>'],
#  ['rec_03_audio_6.wav',
#   'ক্লিনিকে ঢুকছিল গাঁজাখোর দারোয়ান কই দিদি একটু সাবধানে থাইকেন মুই যে কি ভয় পাই না'],
#  ['rec_03_small_audio_1.wav', '<>'],
#  ['rec_03_audio_4.wav', '<>'],
#  ['rec_03_audio_2.wav', '<>'],
#  ['rec_03_audio_0.wav', '<>'],
#  ['rec_03_audio_1.wav', 'মারবে'],
#  ['rec_03_big_audio_1.wav', '<>'],
#  ['rec_03_audio_3.wav', 'মাছ ধরি মাছ'],
#  ['rec_03_big_audio_0.wav', '<>'],
#  ['rec_03_audio_13.wav', '<>'],
#  ['rec_03_audio_10.wav', '<>'],
#  ['rec_03_audio_9.wav', '<>'],
#  ['rec_03_audio_12.wav', '<>'],
#  ['rec_03_audio_18.wav', 'তুই কি করে বুঝবে না'],
#  ['rec_03_audio_20.wav', '<>'],
#  ['rec_03_audio_19.wav', '<>'],
#  ['rec_03_audio_21.wav', '<>'],
#  ['rec_03_small_audio_2.wav', '<>'],
#  ['rec_03_audio_16.wav', '<>'],
#  ['rec_03_audio_17.wav', '<>'],
#  ['rec_03_audio_22.wav', '<>'],
#  ['rec_03_audio_7.wav', '<>'],
#  ['rec_03_audio_23.wav', '<>'],
#  ['rec_03_audio_14.wav', '<>'],
#  ['rec_03_audio_15.wav', 'কি যে শুরু করছো'],
#  ['rec_03_audio_8.wav', '<>'],
#  ['rec_03_audio_11.wav', '<>'],
#  ['rec_03_audio_35.wav', 'মারামারি করা হয় মারামারি'],
#  ['rec_03_audio_32.wav', 'তোর বাবার অপমনে'],
#  ['rec_03_audio_34.wav', 'ডায়লগ কম কম কম কম কম কম দিবি অভিনয় করবি না কও'],
#  ['rec_03_audio_29.wav', '<>'],
#  ['rec_03_audio_27.wav', '<>'],
#  ['rec_03_audio_30.wav', '<>'],
#  ['rec_03_audio_38.wav', 'হ্যালো হ্যালো'],
#  ['rec_03_audio_37.wav', '<>'],
#  ['rec_03_audio_26.wav', '<>'],
#  ['rec_03_audio_31.wav', '<>'],
#  ['rec_03_audio_39.wav', '<>'],
#  ['rec_03_audio_25.wav', '<>'],
#  ['rec_03_audio_40.wav', '<>'],
#  ['rec_03_audio_33.wav', '<>'],
#  ['rec_03_audio_36.wav', '<>'],
#  ['rec_03_audio_24.wav', '<>'],
#  ['rec_03_audio_28.wav', '<>'],
#  ['rec_03_audio_46.wav', '<>'],
#  ['rec_03_audio_51.wav', 'বড় বেশি দামি না আমাকে গল্প শোনাও'],
#  ['rec_03_audio_42.wav', '<>'],
#  ['rec_03_audio_44.wav', '<>'],
#  ['rec_03_audio_41.wav', '<>'],
#  ['rec_03_audio_47.wav', '<>'],
#  ['rec_03_audio_50.wav', '<>'],
#  ['rec_03_audio_48.wav', '<>'],
#  ['rec_03_audio_53.wav', '<>'],
#  ['rec_03_audio_52.wav', 'ভাই তোর এত ফাকিং ফাকিং'],
#  ['rec_03_audio_45.wav', 'বৈশাখ বুঝি'],
#  ['rec_03_audio_43.wav', '<>'],
#  ['rec_03_small_audio_3.wav', '<>'],
#  ['rec_03_audio_49.wav', '<>'],
#  ['rec_03_audio_60.wav', '<>'],
#  ['rec_03_audio_58.wav', '<>'],
#  ['rec_03_audio_57.wav', '<>'],
#  ['rec_03_audio_61.wav', '<>'],
#  ['rec_03_audio_55.wav', 'আমরা কি'],
#  ['rec_03_audio_62.wav', 'কিল্লিগা'],
#  ['rec_03_audio_56.wav', '<>'],
#  ['rec_03_audio_54.wav', '<>'],
#  ['rec_03_audio_59.wav', '<>'],
#  ['rec_03_small_audio_4.wav', '<>'],
#  ['rec_03_audio_63.wav', '<>'],
#  ['rec_04_audio_6.wav', '<>'],
#  ['rec_04_audio_3.wav', 'মাধবীর গৌতম মোরে ধ্বংস করে দিয়েছে'],
#  ['rec_04_audio_12.wav', '<>'],
#  ['rec_04_audio_0.wav',
#   'তাহলে এগুলো তো ওই যে সুবর্ণা বা মাধবী হারায় তো করতে পারে'],
#  ['rec_04_audio_9.wav', 'ড্রিম প্যাকেটটা দাও'],
#  ['rec_04_audio_11.wav', '<>'],
#  ['rec_04_audio_5.wav',
#   'এ মান সম্মান যাবানা প্লান করো যে ঝগড়া একবারে শেষ করে দিমু ঝগড়া শেষ না করে ঝগড়া বাজায় আর কিছু না'],
#  ['rec_04_audio_7.wav', 'ভয়ে তো কথা কয়না'],
#  ['rec_04_audio_4.wav', 'মান-সম্মান যাবে না'],
#  ['rec_04_audio_8.wav', 'বিয়াই'],
#  ['rec_04_audio_13.wav', 'আমারে জন্মদিন'],
#  ['rec_04_audio_1.wav', '<>'],
#  ['rec_04_audio_10.wav', 'শংকর দপ্তর'],
#  ['rec_04_audio_2.wav',
#   'বল সমস্যা রয়েছে ভালো না তোমার বাপেও তো ভালো না তোমার বাপের ভালো হইলে তো সব ভালো হতো'],
#  ['rec_04_audio_36.wav', '<>'],
#  ['rec_04_audio_19.wav', 'ভালো না'],
#  ['rec_04_audio_33.wav', '<>'],
#  ['rec_04_audio_30.wav', 'এলো কাহিনী'],
#  ['rec_04_audio_34.wav', '<>'],
#  ['rec_04_audio_17.wav', '<>'],
#  ['rec_04_audio_28.wav', '<>'],
#  ['rec_04_audio_29.wav', 'সমস্যা মিনিটে মরি লাগছে না'],
#  ['rec_04_audio_23.wav', 'এর থেকে বড় মতন ভূমিকা নিয়ে আমি কাম করি না'],
#  ['rec_04_audio_31.wav', '<>'],
#  ['rec_04_audio_32.wav', '<>'],
#  ['rec_04_audio_37.wav', '<>'],
#  ['rec_04_audio_14.wav', 'ভুতের গল্প তাহলে কইছি না'],
#  ['rec_04_audio_25.wav',
#   'পলাশ কি কও আর মোরা যে এই যে ফল আসে ওপেনলি কথাবার্তা এই কথা আজ পর্যন্ত কেউ কইতে পারবে না'],
#  ['rec_04_audio_16.wav', '<>'],
#  ['rec_04_audio_35.wav', 'ভিডিও না'],
#  ['rec_04_audio_21.wav',
#   'না হয় মরে পড়াইছিল মেট্রিক পরীক্ষা দেওয়ার আগে আগে কয় মাস অংক করছিলাম'],
#  ['rec_04_audio_22.wav', '<>'],
#  ['rec_04_audio_20.wav', 'তাই এরকম না সেরম মুই আবার পড়তে যাইতাম হে সময়'],
#  ['rec_04_audio_18.wav', '<>'],
#  ['rec_04_audio_26.wav',
#   'এই বিতলে খাওয়াইতে লে ভালোই দিতেও পারবে না কেউ ভালো হইবে না'],
#  ['rec_04_audio_24.wav', 'শুয়োরের বাচ্চা দেখান'],
#  ['rec_04_audio_15.wav', 'বুঝছি গাথা'],
#  ['rec_04_audio_27.wav', 'মাড়ি দেওয়া লাগবে না মোর একঘন্টা রেকর্ড করা লাগবে'],
#  ['rec_04_small_audio_0.wav', '<>'],
#  ['rec_04_audio_54.wav', '<>'],
#  ['rec_04_audio_51.wav', '<>'],
#  ['rec_04_audio_48.wav', '<>'],
#  ['rec_04_audio_57.wav', 'পান খাওয়ার টু'],
#  ['rec_04_audio_41.wav', 'বাংলা'],
#  ['rec_04_audio_44.wav', '<>'],
#  ['rec_04_audio_53.wav', '<>'],
#  ['rec_04_audio_40.wav', 'বিশ্রী বের করা লাগে'],
#  ['rec_04_audio_39.wav', '<>'],
#  ['rec_04_audio_56.wav', 'সবিতা'],
#  ['rec_04_audio_46.wav', 'ঠিক আছে'],
#  ['rec_04_audio_38.wav', '<>'],
#  ['rec_04_audio_55.wav', 'বাথরুমে'],
#  ['rec_04_small_audio_1.wav', '<>'],
#  ['rec_04_audio_43.wav', 'হাই দিনের ওই ছিলাম না তোদের আজানের সমস্যা নেই'],
#  ['rec_04_audio_52.wav', 'ধরছি'],
#  ['rec_04_audio_45.wav', '<>'],
#  ['rec_04_audio_49.wav', '<>'],
#  ['rec_04_audio_47.wav', '<>'],
#  ['rec_04_audio_50.wav', 'কালকে বৃষ্টি হয়েছে'],
#  ['rec_04_audio_42.wav', '<>'],
#  ['rec_04_audio_62.wav', '<>'],
#  ['rec_04_audio_60.wav', '<>'],
#  ['rec_04_small_audio_3.wav', 'তো আবার কি করুম ভাই'],
#  ['rec_04_audio_67.wav', '<>'],
#  ['rec_04_audio_58.wav', '<>'],
#  ['rec_04_audio_65.wav', '<>'],
#  ['rec_04_audio_59.wav', '<>'],
#  ['rec_04_small_audio_4.wav', 'কোন রতন'],
#  ['rec_04_audio_64.wav', 'হ্যাঁ কবে'],
#  ['rec_04_audio_66.wav', '<>'],
#  ['rec_04_small_audio_2.wav', '<>'],
#  ['rec_04_audio_61.wav', 'এখন বুঝি'],
#  ['rec_04_audio_78.wav', '<>'],
#  ['rec_04_audio_77.wav', 'মাইয়াগো রাস্তায় বড় হয়ে যাবেন'],
#  ['rec_04_audio_70.wav', '<>'],
#  ['rec_04_audio_76.wav', 'করতে পারি'],
#  ['rec_04_audio_71.wav', 'বাঁশ বাগানের হইনি'],
#  ['rec_04_audio_72.wav', '<>'],
#  ['rec_04_audio_75.wav', '<>'],
#  ['rec_04_audio_74.wav', '<>'],
#  ['rec_04_audio_73.wav', '<>'],
#  ['rec_04_audio_69.wav', '<>'],
#  ['rec_04_audio_79.wav', '<>'],
#  ['rec_04_audio_68.wav', 'হ্যাঁ'],
#  ['rec_05_audio_3.wav', '<>'],
#  ['rec_05_audio_5.wav', 'আইডি কার্ড'],
#  ['rec_05_small_audio_0.wav', 'কোন সমস্যা হবে না'],
#  ['rec_05_audio_6.wav', 'এগুলো আবার কমলার রস দিয়ে ঘুরতে নেন আপনারা'],
#  ['rec_05_audio_10.wav', '<>'],
#  ['rec_05_audio_2.wav', '<>'],
#  ['rec_05_audio_7.wav', '<>'],
#  ['rec_05_audio_0.wav', 'আমি বললাম প্রধান প্রধান'],
#  ['rec_05_audio_9.wav', 'ছোট ছোট লাগে'],
#  ['rec_05_audio_1.wav', '<>'],
#  ['rec_05_audio_4.wav', 'কি করতেছেন'],
#  ['rec_05_audio_8.wav', '<>'],
#  ['rec_05_big_audio_1.wav', 'গান বাঙালি'],
#  ['rec_05_big_audio_0.wav', '<>'],
#  ['rec_05_small_audio_3.wav', 'আব্বু আবার কয় পাপা'],
#  ['rec_05_audio_18.wav', 'এখানে কে কে আছে উপস্থিত এই মুহূর্তে দেখাইতেছি'],
#  ['rec_05_audio_16.wav', 'আদা বাটা রসুন বাটা দেখাও'],
#  ['rec_05_audio_24.wav',
#   'চিকেন শিক্ষা বা ম্যারিনেট করা হয়ে গেছে আমাকে প্রধান খুব কাকু আইসা পড়তেছে'],
#  ['rec_05_audio_25.wav', 'এইযে এইযে 10 মিনিট লাগবে'],
#  ['rec_05_small_audio_2.wav', 'হ্যাঁ দিয়ে দেন'],
#  ['rec_05_audio_14.wav', '<>'],
#  ['rec_05_audio_21.wav', 'সারা মনি'],
#  ['rec_05_audio_13.wav', 'মুখে গরুর দুধ দুধ এককালে কয়দিন আগে বিয়ে হয়েছে'],
#  ['rec_05_audio_23.wav', 'এই ম'],
#  ['rec_05_audio_20.wav', '<>'],
#  ['rec_05_small_audio_1.wav', '<>'],
#  ['rec_05_audio_26.wav', 'ওকি তুই বাবা বাবা'],
#  ['rec_05_audio_15.wav', '<>'],
#  ['rec_05_audio_11.wav', 'কয়লা জেলে গেছে'],
#  ['rec_05_audio_17.wav', 'ফরমালিন নাই ফরমালিন ছাড়া মোবাইল'],
#  ['rec_05_audio_19.wav', 'এই হলো আমার ফুফু'],
#  ['rec_05_audio_22.wav', 'রোশনি রোশনি এ সালাম দিয়ে যাই'],
#  ['rec_05_audio_12.wav', 'মসলা মাস পর নাকি কোন সমস্যা নেই'],
#  ['rec_06_audio_5.wav', '<>'],
#  ['rec_06_audio_3.wav', '<>'],
#  ['rec_06_audio_4.wav', '<>'],
#  ['rec_06_audio_0.wav', 'বাড়ি'],
#  ['rec_06_audio_1.wav', '<>'],
#  ['rec_06_small_audio_1.wav', '<>'],
#  ['rec_06_audio_2.wav', '<>'],
#  ['rec_06_small_audio_0.wav', '<>'],
#  ['rec_06_audio_6.wav', '<>'],
#  ['rec_06_audio_7.wav', '<>'],
#  ['rec_07_audio_6.wav', '<>'],
#  ['rec_07_audio_7.wav', '<>'],
#  ['rec_07_audio_3.wav', '<>'],
#  ['rec_07_audio_5.wav', '<>'],
#  ['rec_07_audio_2.wav', '<>'],
#  ['rec_07_audio_0.wav', '<>'],
#  ['rec_07_audio_4.wav', '<>'],
#  ['rec_07_audio_9.wav', 'মুই ভাত খামু মুই পড়েন'],
#  ['rec_07_audio_11.wav', '<>'],
#  ['rec_07_audio_10.wav', '<>'],
#  ['rec_07_audio_8.wav', 'এ ভাত খাওয়া মামু পরের পুতি লিগা গল্প করতে করতে'],
#  ['rec_07_audio_1.wav', '<>'],
#  ['rec_08_small_audio_0.wav', '<>'],
#  ['rec_10_small_audio_0.wav', '<>'],
#  ['rec_10_audio_5.wav', 'সোমবার পারলে কি আর কিছু কিছু জিনিস'],
#  ['rec_10_audio_6.wav', 'অর্জুন করা লাগে'],
#  ['rec_10_audio_0.wav', '<>'],
#  ['rec_10_audio_1.wav', '<>'],
#  ['rec_10_audio_3.wav', '<>'],
#  ['rec_10_big_audio_0.wav', 'তোমার বিনিময়ে মাছ খাবে'],
#  ['rec_10_audio_4.wav', '<>'],
#  ['rec_10_audio_2.wav', '<>'],
#  ['rec_11_audio_5.wav', 'লাচ্ছা সেমাই না'],
#  ['rec_11_small_audio_0.wav', '<>'],
#  ['rec_11_audio_0.wav', 'খেতে যাবি কইতে চাইলাম না'],
#  ['rec_11_big_audio_0.wav', 'আগের দিন'],
#  ['rec_11_audio_4.wav', 'কুয়েটের আপুরা আসবে না'],
#  ['rec_11_audio_1.wav', 'আরে'],
#  ['rec_11_big_audio_2.wav', 'আমার সাথে এমন করতে পারোনা'],
#  ['rec_11_audio_2.wav',
#   'কুয়েতের দারাজ আছে আজকে বরিশালের মধ্যে সিনিয়র থাকবে 016 0'],
#  ['rec_11_audio_3.wav', 'নগদ আছে ভাই'],
#  ['rec_11_audio_10.wav', 'খোকন ভাই কি বিয়ে দিবেন'],
#  ['rec_11_audio_23.wav', 'ইমিডিয়েট'],
#  ['rec_11_audio_19.wav', 'বলোনা'],
#  ['rec_11_audio_24.wav', '<>'],
#  ['rec_11_audio_6.wav', 'মাইয়া কালেকশন বাইক নেই'],
#  ['rec_11_audio_27.wav', 'ভাই আপনি তো খাইতে কইলেন তুই কাজ করবি না'],
#  ['rec_11_audio_7.wav', 'বাবা হন'],
#  ['rec_11_audio_17.wav',
#   'আমি কোন নদীর ভিতর দিয়েই না আমার এলাকা আম্মা নাফিয়া না'],
#  ['rec_11_audio_30.wav', 'দুনিয়ার সব সরকার'],
#  ['rec_11_small_audio_1.wav', 'লিংক থ্রি'],
#  ['rec_11_audio_16.wav', 'হায়েস্ট কোন নদীতে অবস্থিত'],
#  ['rec_11_audio_29.wav', 'মানে'],
#  ['rec_11_small_audio_3.wav', '<>'],
#  ['rec_11_audio_26.wav', 'নিবি নিবি'],
#  ['rec_11_small_audio_2.wav', 'নষ্ট ফলাফল'],
#  ['rec_11_audio_22.wav', '<>'],
#  ['rec_11_audio_25.wav', 'এমন কাহিনী করে সালামুআলাইকুম'],
#  ['rec_11_audio_21.wav', 'পোলাও'],
#  ['rec_11_audio_15.wav', '<>'],
#  ['rec_11_audio_8.wav', 'লোলিতা'],
#  ['rec_11_audio_14.wav', 'কার সাথে আমার সাথে দেখা করি'],
#  ['rec_11_audio_12.wav', 'ট্যাক্স দেওয়া লাগবে না'],
#  ['rec_11_audio_20.wav', '<>'],
#  ['rec_11_audio_13.wav', 'দে দে'],
#  ['rec_11_audio_28.wav', '<>'],
#  ['rec_11_audio_9.wav', 'ডিপ ফ্রিজে কি নেওয়া লাগবে না'],
#  ['rec_11_audio_18.wav', '<>'],
#  ['rec_11_audio_11.wav', 'এখন আগের যারা কবিতা যখন কেউ থাকবো না'],
#  ['rec_11_small_audio_4.wav', '<>'],
#  ['rec_11_audio_48.wav', 'আরে খুবই খুবই অনেক দূরে স্পিক হিন্দি'],
#  ['rec_11_audio_47.wav', 'আমি তো আমি থাকি খুবই মনে খুবই খুবই'],
#  ['rec_11_audio_36.wav', 'আজ আমি জানি না'],
#  ['rec_11_audio_41.wav', 'দুধটা কি বান্ধবী'],
#  ['rec_11_audio_34.wav', 'ইফতারের সময়'],
#  ['rec_11_audio_35.wav', 'মন খারাপ থাকে না রাত্রে থাকা লাগবে'],
#  ['rec_11_audio_32.wav', 'ফুড ব্লগার ম্যাডাম আমি আবার দিস ম্যান ইন বাংলাদেশ'],
#  ['rec_11_audio_43.wav', 'ইফতারি করব আমরা 4-5 জন গেছি বাড়ি চলে যাবে'],
#  ['rec_11_audio_40.wav',
#   'কাশি কাকা কি 10 11 তারিখ না 10 তারিখে 11 তারিখ 8 তারিখ চলে যাবে'],
#  ['rec_11_audio_50.wav', 'জীবনে তোমার মুড অফ কেন বলতে হবে তো'],
#  ['rec_11_audio_42.wav', 'গোলাপ বাগান পর্যন্ত'],
#  ['rec_11_audio_44.wav', 'কল ড্রিঙ্কস পানি পানি আসে না'],
#  ['rec_11_audio_49.wav', 'পালসার দিবেন'],
#  ['rec_11_audio_39.wav', '<>'],
#  ['rec_11_audio_46.wav', 'কি সোনা পাখি'],
#  ['rec_11_audio_38.wav', 'মামা আমাকে লেখাটা সুন্দর না'],
#  ['rec_11_audio_33.wav', '<>'],
#  ['rec_11_audio_31.wav',
#   'কিন্তু এই বছর এতটাই রুলস রেগুলেশন মানে ছাত্রলীগ দি মানা করে দিয়েছি'],
#  ['rec_11_audio_45.wav', 'না আমরা এই থেকে উত্তর রেখেছি'],
#  ['rec_11_audio_37.wav', 'হাহাকার দেখি কাকে পাই না'],
#  ['rec_11_audio_51.wav', 'কন্যাশ্রী কি খাওয়াবো'],
#  ['rec_12_audio_4.wav', '<>'],
#  ['rec_12_audio_2.wav',
#   'বিয়ের পর এই এর গাছে রাম ওর গাছের ডাব চুরি করছি আমি বাদ দিয়ে দিয়েছি'],
#  ['rec_12_audio_6.wav', 'এরপর কি করছি তিনজন ছিলাম মুভি সাওয়াল আসে না'],
#  ['rec_12_audio_9.wav',
#   'মনে কর একটু পরানের মধ্যে ডর ছিল না মুই করমু কি জান এই হালার পো হালারে খাইয়া লামু'],
#  ['rec_12_audio_10.wav',
#   'আফ্রিকা হের ক্ষমা ক্ষমা চাইবে না চুরি তো চুরি এই চুরি করমুই থাকতে'],
#  ['rec_12_audio_1.wav', '<>'],
#  ['rec_12_audio_8.wav', '<>'],
#  ['rec_12_audio_3.wav', 'এক পর্যায় মোর নাম'],
#  ['rec_12_audio_11.wav', 'তখন গাছের গোড়ায় রাখছিলাম গাছে'],
#  ['rec_12_audio_5.wav', 'হ্যাঁ দেবে না ভালো হয়ে গেছি'],
#  ['rec_12_audio_0.wav',
#   'তোর কি ছোট কালের কোন কথা মনে আছে মনে আছে মুই একটা কমু গল্প শুনবি এখন'],
#  ['rec_12_audio_7.wav', 'গেরাম তিনজন ছন্দা খেলা করছি'],
#  ['rec_12_audio_17.wav', 'পাড়তে পারে'],
#  ['rec_12_audio_16.wav',
#   'আম যদি পড়ে যায় তোর মনে কর ওই বাড়ির মানুষ একটাও বাদ থাকবে না মরা কিন্তু রাত্রে চুরি করতে গেছি কিন্তু দিতে পারে সম্ভাবনা আছে'],
#  ['rec_12_audio_29.wav',
#   'এক দৌড়ে বাড়ি দেখাও কাম কিন্তু হবে না হেরা দলে বাড়ি ছিল 20 জন আর মুই ছিলাম আর মোর লগে আর দুই হালার ফালাইছিল হেরা ছিল 3'],
#  ['rec_12_audio_37.wav',
#   'তোর দেখো মনে আছে নাকি শুনবি এটাও কিন্তু রিয়াল কাহিনী'],
#  ['rec_12_audio_26.wav',
#   'তবে ধান ব্যাগ কেটে ফেলেছিল কিন্তু লগে পাট খেতে পারেনা'],
#  ['rec_12_audio_28.wav',
#   'ওগো লাইটের আলোতে আলোতে মরা দৌড়াইতে সুবিধা এখন লাইট মারতে মারতে মনে কর মোরে'],
#  ['rec_12_audio_21.wav',
#   'কি দৌড় দিমু পরান তো মনে করছেন বিচির নিচে চলে এসেছে'],
#  ['rec_12_audio_22.wav',
#   'পরে ওই মনে কর অন্য অফার দিয়ে ঘুরিয়ে আইতে আইতে লোক ছিল 20 জন এর মধ্যে যদি ধরা খাইতাম আল্লাহ না করুক কোন কায়দায় দেখিনা ছোটকালের টাউট'],
#  ['rec_12_audio_23.wav', 'শক্তিগড়'],
#  ['rec_12_audio_19.wav',
#   'যাই হোক চার-পাঁচটা আম পড়ছে দাদু পাহাড় যদি ডল বরাদ্দ দেয়া হয় মারতে ধরতে চোর তখন এক বস্তা'],
#  ['rec_12_audio_36.wav',
#   'তবে হেয়ার আগেই অনেক চুরি বাটপারি করছি তোর কি কিছু মনে নাই তোর ছোটকালের কাহিনী তোর মাথায়'],
#  ['rec_12_audio_25.wav', 'আমের বস্তা হালার পো হালা মানুষ'],
#  ['rec_12_audio_35.wav',
#   'যদিও ছিল সবকিছুই দুয়ার কিন্তু বাপ মারে তো ডরাইতাম বাপ মা ধরাতে হবে বাপ মা মনে করে একদম হোক উরাধুরা মাইর মাইর খাইয়া এই যে সুকু ভালো হয়েছে'],
#  ['rec_12_audio_40.wav', 'কাঁঠাল গো চুরি করলাম সুন্দর একটু খরল করে থুইছি'],
#  ['rec_12_audio_34.wav', 'কই মরা আম চুরি করতে গিয়েছিলাম'],
#  ['rec_12_audio_20.wav', '<>'],
#  ['rec_12_audio_12.wav', 'হেয়ার পর কি উল্টাপাল্টা 2017'],
#  ['rec_12_audio_31.wav',
#   'বাড়িতে যদি কেউ জিগায় আমার বাড়িতে কি কেউ ঢুকছে তুমি কবা কিনা'],
#  ['rec_12_audio_24.wav', 'মুই একটু মনে কর ওই আমের বস্তা ধরে দিয়েছি'],
#  ['rec_12_audio_38.wav', '<>'],
#  ['rec_12_audio_15.wav',
#   'তুই আম ছিড়ে ছিড়ে মুর্দার দিবি মুই থুম যাই হোক বস্তা ভইরা এখন বস্তা ভরে গেল দাদু গাছের ডালে মটমট মটমট করে আমের ভার'],
#  ['rec_12_audio_30.wav',
#   'তুমি বাড়ি এসো তো বেল্লাল দুদুর পোলাও করে কি ছিল ধান ক্ষেতে পাট খেতে রয়েছে লাগে অনেক কিছুই কাঁ'],
#  ['rec_12_audio_13.wav', 'বেশি তো আর দেখা যায় না'],
#  ['rec_12_audio_14.wav', 'ডালে তো বানছি শালা এই এইটা কিন্তু রিয়াল কাহিনী'],
#  ['rec_12_audio_27.wav', 'লাইট'],
#  ['rec_12_audio_32.wav',
#   'মুই মনে করতাছে হেরা মোগো বাড়িতে গেল বিস্তারিয়া গেছে একটু পরে বাইরে দিয়েছি'],
#  ['rec_12_audio_33.wav',
#   'তো তুমি কিছু কইছো তুই কি কোন আকাম কুকাম করে কি মাগো আকাম কিন্তু একটা করে ফেলেছে এখন কি করছো'],
#  ['rec_12_audio_39.wav',
#   'মরা ছোটকালে করছি যাই হোক ছোটকালের কথাটা কই একটু মজা পাইতেছি না'],
#  ['rec_12_audio_18.wav', 'শালা কি'],
#  ['rec_12_audio_46.wav', 'আজকে মনে হয় কপালে শনি আছে হালার পো হালা ভরতে ভরতে'],
#  ['rec_12_audio_41.wav',
#   'তিন দিন পর ওই তিন পাড়ায় গেছি যাইয়া কাঁঠাল গো দেখি'],
#  ['rec_12_audio_47.wav',
#   'তাতে কি আবার মনে করতো না ওই হালার পো হালা খাইতে আছে দাদু সুবল কাকু আসে না হালার পো হালা'],
#  ['rec_12_audio_50.wav', 'জীবনের চুরি একদম শিক্ষা দিয়েছে'],
#  ['rec_12_audio_48.wav',
#   'মুই করছে কি মুই ডাইনের দিন ছিলাম একটু দূরে একটু দূরে ছিলাম মনে করছে'],
#  ['rec_12_audio_49.wav', '<>'],
#  ['rec_12_audio_45.wav', 'হেয়ার পর মনে কর খাওয়া অর্ধেক কইছে রে ভাই'],
#  ['rec_12_audio_44.wav', 'একটা দিঘির কান্নায় ভাই অর্ধেক কেবল খাওয়া হইছে'],
#  ['rec_12_audio_42.wav',
#   'পাটক্ষেতের টা বাইর করিয়া থুইলাম যাতে পাট খেতে মানুষের লান এত দিনে খাওন যাইবে না'],
#  ['rec_12_audio_43.wav',
#   'কি কি রাত কাটালি খামু রাইতে তিনজনে একটা বুদ্ধি করলাম'],
#  ['rec_14_audio_6.wav', '<>'],
#  ['rec_14_audio_7.wav', '<>'],
#  ['rec_14_audio_2.wav', '<>'],
#  ['rec_14_audio_5.wav', '<>'],
#  ['rec_14_audio_3.wav', '<>'],
#  ['rec_14_audio_0.wav', '<>'],
#  ['rec_14_audio_4.wav', '<>'],
#  ['rec_14_audio_1.wav', '<>'],
#  ['rec_14_audio_8.wav', '<>'],
#  ['rec_14_audio_15.wav', 'আগের দিন পোলাপান কয়জন'],
#  ['rec_14_audio_27.wav', '<>'],
#  ['rec_14_audio_16.wav', '<>'],
#  ['rec_14_audio_24.wav', '<>'],
#  ['rec_14_audio_19.wav', '<>'],
#  ['rec_14_audio_26.wav', '<>'],
#  ['rec_14_audio_14.wav', '<>'],
#  ['rec_14_audio_21.wav', '<>'],
#  ['rec_14_audio_17.wav', '<>'],
#  ['rec_14_audio_31.wav', '<>'],
#  ['rec_14_audio_13.wav', '<>'],
#  ['rec_14_audio_25.wav', '<>'],
#  ['rec_14_audio_28.wav', 'গেলাম'],
#  ['rec_14_audio_29.wav', '<>'],
#  ['rec_14_audio_10.wav', '<>'],
#  ['rec_14_audio_30.wav', '<>'],
#  ['rec_14_audio_18.wav', '<>'],
#  ['rec_14_audio_12.wav', '<>'],
#  ['rec_14_audio_22.wav', '<>'],
#  ['rec_14_audio_23.wav', '<>'],
#  ['rec_14_audio_11.wav', '<>'],
#  ['rec_14_audio_20.wav', '<>'],
#  ['rec_15_audio_5.wav', '<>'],
#  ['rec_15_audio_0.wav', '<>'],
#  ['rec_15_audio_1.wav', '<>'],
#  ['rec_15_audio_4.wav', '1 ভরি চারটে ইন্ডিয়া'],
#  ['rec_15_audio_2.wav', 'আড্ডায় একটু বলো দেখি'],
#  ['rec_15_audio_7.wav', '<>'],
#  ['rec_15_small_audio_0.wav', '<>'],
#  ['rec_15_audio_6.wav', 'যাও তুমি খাও আমি খাব না'],
#  ['rec_15_audio_3.wav', '<>'],
#  ['rec_16_big_audio_2.wav', '<>'],
#  ['rec_16_audio_1.wav', '<>'],
#  ['rec_16_big_audio_1.wav', '<>'],
#  ['rec_16_audio_0.wav', '<>'],
#  ['rec_16_audio_13.wav', 'গরমের ছুটি হাগা ভাব'],
#  ['rec_16_audio_4.wav', '<>'],
#  ['rec_16_audio_5.wav', '<>'],
#  ['rec_16_audio_24.wav', 'বুদ্ধিজীবীদের সম্পূর্ণ শহর'],
#  ['rec_16_audio_7.wav', '<>'],
#  ['rec_16_audio_23.wav', 'তাই বুদ্ধিজীবী'],
#  ['rec_16_audio_15.wav', '<>'],
#  ['rec_16_audio_22.wav', '<>'],
#  ['rec_16_audio_20.wav', 'আরসে নেওয়ার ঢং করছে'],
#  ['rec_16_audio_11.wav', '<>'],
#  ['rec_16_audio_25.wav', '<>'],
#  ['rec_16_audio_9.wav', '<>'],
#  ['rec_16_audio_27.wav', 'এবার'],
#  ['rec_16_audio_14.wav', '<>'],
#  ['rec_16_audio_12.wav', 'সর্বদা দেরি আছে'],
#  ['rec_16_audio_3.wav', '<>'],
#  ['rec_16_audio_16.wav', 'দেখ দেখ দেখ দেখ দেখ দেখ দেখ দেখ দেখ দেখ দেখ'],
#  ['rec_16_audio_26.wav', 'না যায় না'],
#  ['rec_16_audio_10.wav', 'পানি দে পানি দে'],
#  ['rec_16_audio_21.wav', '<>'],
#  ['rec_16_audio_2.wav', '<>'],
#  ['rec_16_audio_8.wav', '<>'],
#  ['rec_16_audio_6.wav', 'কাটুন'],
#  ['rec_16_audio_18.wav', 'ভাত খাইছো'],
#  ['rec_16_audio_17.wav', 'করনা প্লিজ'],
#  ['rec_16_audio_19.wav', 'চোখে খাবার পায় না'],
#  ['rec_16_audio_52.wav', 'এটা শেষ করে না'],
#  ['rec_16_audio_47.wav', 'ডাক্তার গোলাম'],
#  ['rec_16_audio_32.wav', '<>'],
#  ['rec_16_audio_38.wav', '<>'],
#  ['rec_16_audio_56.wav', 'তোর পেটে গেছে'],
#  ['rec_16_audio_40.wav', '<>'],
#  ['rec_16_audio_35.wav', '<>'],
#  ['rec_16_audio_29.wav', 'হাহাহাহা'],
#  ['rec_16_audio_37.wav', '<>'],
#  ['rec_16_audio_55.wav', 'তানভি দাস পাঠাইবেন'],
#  ['rec_16_audio_58.wav', '<>'],
#  ['rec_16_audio_46.wav', '<>'],
#  ['rec_16_audio_54.wav', '<>'],
#  ['rec_16_audio_49.wav', '<>'],
#  ['rec_16_audio_43.wav', '<>'],
#  ['rec_16_audio_36.wav', '<>'],
#  ['rec_16_audio_48.wav', 'চুলার বরফ'],
#  ['rec_16_audio_50.wav', '<>'],
#  ['rec_16_audio_41.wav', '<>'],
#  ['rec_16_audio_39.wav', '<>'],
#  ['rec_16_audio_57.wav', 'বাপের নামে চলছে'],
#  ['rec_16_audio_53.wav', '<>'],
#  ['rec_16_audio_59.wav', '<>'],
#  ['rec_16_audio_31.wav', '<>'],
#  ['rec_16_audio_45.wav', '<>'],
#  ['rec_16_audio_42.wav', '<>'],
#  ['rec_16_audio_34.wav', 'কেরা'],
#  ['rec_16_audio_33.wav', 'মামসা'],
#  ['rec_16_audio_28.wav', '<>'],
#  ['rec_16_audio_30.wav', '<>'],
#  ['rec_16_audio_44.wav', '<>'],
#  ['rec_16_audio_51.wav', '<>'],
#  ['rec_16_audio_62.wav', 'ঢাকা বাজারে'],
#  ['rec_16_audio_77.wav', 'ময়মনসিংহ ইউনিভার্সিটি'],
#  ['rec_16_audio_81.wav', 'হবিগঞ্জ সিলেটের মধ্যে সিলেটের মধ্যে পার্থক্য'],
#  ['rec_16_audio_79.wav', 'ময়মনসিং'],
#  ['rec_16_audio_75.wav', '<>'],
#  ['rec_16_audio_65.wav', 'কি জানি'],
#  ['rec_16_audio_69.wav', 'তোর মার'],
#  ['rec_16_audio_61.wav', 'হা হা হা হা হা হা হা তা আছে'],
#  ['rec_16_audio_83.wav', 'ঢাকা শহরে আগে লাগবে'],
#  ['rec_16_audio_72.wav', 'তুমি আমার জন্য একটু যাইতে পারো'],
#  ['rec_16_audio_82.wav', '<>'],
#  ['rec_16_audio_63.wav', '2 তারিখ'],
#  ['rec_16_audio_70.wav', 'আমার মার না'],
#  ['rec_16_audio_66.wav', 'আমারে ফোন দিয়ে জিজ্ঞেস করেছিল'],
#  ['rec_16_audio_80.wav', 'কি করছো'],
#  ['rec_16_audio_67.wav', '<>'],
#  ['rec_16_audio_60.wav', '<>'],
#  ['rec_16_audio_68.wav', 'বড় ভাই'],
#  ['rec_16_audio_64.wav', '<>'],
#  ['rec_16_audio_73.wav', '<>'],
#  ['rec_16_audio_78.wav', '<>'],
#  ['rec_16_audio_71.wav', '<>'],
#  ['rec_16_audio_76.wav', 'ময়মনসিংহ কে'],
#  ['rec_16_audio_74.wav', 'দেখ দেখ'],
#  ['rec_16_audio_87.wav', '<>'],
#  ['rec_16_small_audio_0.wav', 'নাগিনী পেট টা দেন'],
#  ['rec_16_audio_92.wav', 'কাম নেই'],
#  ['rec_16_audio_86.wav', '<>'],
#  ['rec_16_audio_91.wav', '<>'],
#  ['rec_16_audio_89.wav', 'আমি কালকে ঐদিন বলছিলাম'],
#  ['rec_16_audio_93.wav', '<>'],
#  ['rec_16_audio_85.wav', '<>'],
#  ['rec_16_audio_90.wav', '<>'],
#  ['rec_16_audio_84.wav', 'কালকের সংবাদ'],
#  ['rec_16_audio_88.wav', '<>'],
#  ['rec_17_audio_6.wav', '<>'],
#  ['rec_17_audio_11.wav', 'ও একদিন না তোমার গলায় দিয়েছিল'],
#  ['rec_17_audio_1.wav', '<>'],
#  ['rec_17_audio_3.wav', '<>'],
#  ['rec_17_audio_2.wav', '<>'],
#  ['rec_17_audio_4.wav', '<>'],
#  ['rec_17_audio_5.wav', '<>'],
#  ['rec_17_audio_10.wav', '<>'],
#  ['rec_17_audio_8.wav', 'মোবারক পলাশীর বউ আছে এখনো'],
#  ['rec_17_audio_7.wav', '<>'],
#  ['rec_17_audio_0.wav', 'না করি না করি না করি না'],
#  ['rec_17_small_audio_0.wav', 'বড়'],
#  ['rec_17_audio_9.wav', '<>'],
#  ['rec_18_audio_0.wav', '<>'],
#  ['rec_18_audio_13.wav', '<>'],
#  ['rec_18_audio_11.wav', 'আমি জানিনা'],
#  ['rec_18_audio_18.wav', '<>'],
#  ['rec_18_audio_9.wav', '<>'],
#  ['rec_18_audio_16.wav', 'দেখি না'],
#  ['rec_18_audio_17.wav', 'শুরু হয়েছে'],
#  ['rec_18_small_audio_0.wav', '<>'],
#  ['rec_18_audio_14.wav', 'আর এই স্কুলের পিছনে যেখানে'],
#  ['rec_18_audio_12.wav',
#   'একটা মোটামুটি কালা আর একটা আবার শান্তার কথা কও আর একটা আর একটা হল যে ফর্সা ফর্সা হয় না'],
#  ['rec_18_audio_2.wav', '<>'],
#  ['rec_18_audio_1.wav', '<>'],
#  ['rec_18_audio_15.wav', 'স্টেপলার ভিডিও স্কুলের পিছনে হয়'],
#  ['rec_18_audio_3.wav', 'পুলা দিয়ে অটো চালায় আমি কি পড়াশোনা'],
#  ['rec_18_audio_10.wav', 'কেমন আছো'],
#  ['rec_18_audio_5.wav', 'মই কষ্ট করে খাওয়াবো ইস্কুলের যাওয়া লাগবে না'],
#  ['rec_18_audio_6.wav', '<>'],
#  ['rec_18_audio_8.wav', '<>'],
#  ['rec_18_audio_4.wav', 'মুসলমান'],
#  ['rec_18_audio_7.wav', '<>'],
#  ['rec_18_audio_23.wav', 'সারাদিন তোর বিয়ে হয়েছে'],
#  ['rec_18_audio_22.wav', 'ঢাকা গেছিলো তিনদিন পর্যন্ত'],
#  ['rec_18_audio_20.wav', '<>'],
#  ['rec_18_audio_24.wav', 'মানে একদিন গেছে'],
#  ['rec_18_audio_19.wav', '<>'],
#  ['rec_18_audio_21.wav', '<>'],
#  ['rec_19_audio_13.wav', 'মন নাস্তা কি সুন্দর হয়েছে'],
#  ['rec_19_big_audio_0.wav', '<>'],
#  ['rec_19_audio_2.wav', '<>'],
#  ['rec_19_audio_6.wav', '<>'],
#  ['rec_19_audio_12.wav', 'আমি এখানে'],
#  ['rec_19_audio_0.wav', '<>'],
#  ['rec_19_audio_9.wav', 'এ নিজের টাট্টি মূর্তি কথা কইতাছি'],
#  ['rec_19_audio_3.wav', '<>'],
#  ['rec_19_audio_8.wav', '<>'],
#  ['rec_19_audio_7.wav', '<>'],
#  ['rec_19_audio_11.wav', 'আমি এখানে বসে নেই কিন্তু মোর দেওয়া হয়েছে'],
#  ['rec_19_audio_4.wav', '<>'],
#  ['rec_19_audio_1.wav', 'সকালবেলা ঘুম থেকে খাই না'],
#  ['rec_19_audio_5.wav', 'কি দিয়ে খেয়েছি'],
#  ['rec_19_audio_10.wav', '<>'],
#  ['rec_19_audio_23.wav', '<>'],
#  ['rec_19_audio_17.wav', 'ওই পুতলি নিবে না'],
#  ['rec_19_audio_31.wav', '<>'],
#  ['rec_19_audio_32.wav', '<>'],
#  ['rec_19_audio_38.wav', '<>'],
#  ['rec_19_audio_33.wav', 'কার্টুন কার্টুন'],
#  ['rec_19_audio_34.wav', '<>'],
#  ['rec_19_audio_30.wav', 'তমা পূজারী কার্টুন'],
#  ['rec_19_audio_25.wav', 'কিসের ফলাফল'],
#  ['rec_19_audio_19.wav', 'দর্শন'],
#  ['rec_19_audio_22.wav', '<>'],
#  ['rec_19_audio_26.wav', 'ডাল আলু ডাল আলু ডাল কি স্বপ্ন'],
#  ['rec_19_audio_28.wav', 'উপস্থিতি'],
#  ['rec_19_audio_24.wav', 'আগের বারা করস কেন ডাক দিয়েছে'],
#  ['rec_19_audio_21.wav', 'মৃত্যুঞ্জয় কারা ছাড়া কেউ যায় না'],
#  ['rec_19_audio_15.wav', '<>'],
#  ['rec_19_audio_20.wav', '<>'],
#  ['rec_19_audio_35.wav', 'শুক্রবার ছিলো আবহাওয়া'],
#  ['rec_19_audio_37.wav', '<>'],
#  ['rec_19_audio_14.wav', '<>'],
#  ['rec_19_audio_27.wav', '<>'],
#  ['rec_19_audio_18.wav', 'আপনি হয়তো নিতে পারবেন না'],
#  ['rec_19_audio_16.wav', '<>'],
#  ['rec_19_audio_36.wav',
#   'মোবাইলের তুইতো কয়েকজন যায় না আর তুই কস কি কি মাছ একখানা না এক খানে না'],
#  ['rec_19_audio_29.wav', '<>'],
#  ['rec_19_audio_52.wav', '<>'],
#  ['rec_19_audio_51.wav', 'খেলার ফলাফল'],
#  ['rec_19_audio_58.wav', 'ওমা ভূত বলে দেয়'],
#  ['rec_19_audio_45.wav', '<>'],
#  ['rec_19_small_audio_0.wav', '<>'],
#  ['rec_19_audio_63.wav', '<>'],
#  ['rec_19_audio_56.wav', '<>'],
#  ['rec_19_audio_44.wav', '<>'],
#  ['rec_19_audio_57.wav', '<>'],
#  ['rec_19_audio_60.wav', '<>'],
#  ['rec_19_audio_49.wav', 'ডাইনি ডাইনি কার্টুন'],
#  ['rec_19_audio_40.wav', '<>'],
#  ['rec_19_audio_62.wav', 'হোন্ডায় হাওড়া দেখছি না'],
#  ['rec_19_audio_47.wav', 'পোলা হইছে না মাইয়া হইছে'],
#  ['rec_19_audio_42.wav', 'খুশি অনেক না'],
#  ['rec_19_audio_46.wav', 'হে ফটো নাচ'],
#  ['rec_19_audio_54.wav', 'পাতলা পাতলা ডাল হয়ে যাবে'],
#  ['rec_19_audio_39.wav', '<>'],
#  ['rec_19_audio_48.wav', 'মোহিনী'],
#  ['rec_19_audio_41.wav', 'কাজটা বাইরে বের হয়েছে'],
#  ['rec_19_audio_61.wav', 'মশাই কামড়াইছে ও আছে তো আছে আছে'],
#  ['rec_19_audio_43.wav',
#   'ওরে খুশিরে দিস না এই দিলে বলে যাই খুশি থাকলে আমার সবসময় খুশি'],
#  ['rec_19_audio_50.wav', 'তোমার আব্বু গেছে শেষ পরীক্ষা ছিল'],
#  ['rec_19_audio_59.wav', '<>'],
#  ['rec_19_audio_53.wav', 'কি রান্না'],
#  ['rec_19_audio_55.wav',
#   'ভারতে এক কেজি সাতটা হাড়িভাঙ্গা এক কেজি 100 টাকা করে দেবে'],
#  ['rec_19_audio_65.wav',
#   'অবাম একটা পায়ে একটা পারে একটা পাহাড় ব্যবসা ছাড়াও যেগুলো টাকা খরচ করছে'],
#  ['rec_19_audio_76.wav', '<>'],
#  ['rec_19_audio_70.wav', '<>'],
#  ['rec_19_audio_68.wav', 'না'],
#  ['rec_19_audio_69.wav', '<>'],
#  ['rec_19_small_audio_1.wav', '<>'],
#  ['rec_19_audio_67.wav', '<>'],
#  ['rec_19_audio_66.wav', '<>'],
#  ['rec_19_audio_74.wav', '<>'],
#  ['rec_19_audio_73.wav', '<>'],
#  ['rec_19_audio_72.wav', '<>'],
#  ['rec_19_audio_75.wav', '<>'],
#  ['rec_19_audio_64.wav', 'গাছটা পরীক্ষা ছিল'],
#  ['rec_19_audio_77.wav', 'তোমরা কি এই এই আজগার কালকে'],
#  ['rec_19_audio_71.wav', '<>'],
#  ['rec_20_audio_8.wav', 'ডিলিট করার মাইয়ারে দেখলাম'],
#  ['rec_20_audio_7.wav', '<>'],
#  ['rec_20_audio_9.wav', '<>'],
#  ['rec_20_audio_6.wav', '<>'],
#  ['rec_20_audio_1.wav', '<>'],
#  ['rec_20_audio_3.wav', 'শিমুলের বৃহত্তম'],
#  ['rec_20_big_audio_0.wav', '<>'],
#  ['rec_20_audio_10.wav', '<>'],
#  ['rec_20_audio_5.wav', '<>'],
#  ['rec_20_audio_2.wav', 'কিসের হিসাব করেন'],
#  ['rec_20_audio_4.wav', 'বাড়ি'],
#  ['rec_20_audio_0.wav', '<>'],
#  ['rec_20_audio_17.wav', '<>'],
#  ['rec_20_audio_28.wav', '<>'],
#  ['rec_20_audio_19.wav', '<>'],
#  ['rec_20_audio_14.wav', '<>'],
#  ['rec_20_audio_20.wav', '<>'],
#  ['rec_20_audio_24.wav', '<>'],
#  ['rec_20_audio_22.wav', 'কৃষ্ণ কৃষ্ণ রায় না'],
#  ['rec_20_audio_29.wav', '<>'],
#  ['rec_20_audio_26.wav', '<>'],
#  ['rec_20_audio_13.wav', 'না'],
#  ['rec_20_audio_16.wav', '<>'],
#  ['rec_20_audio_23.wav', '<>'],
#  ['rec_20_audio_18.wav', '<>'],
#  ['rec_20_audio_12.wav', 'লিটন মিয়া বিষ্ণু হারা দোয়া করেন'],
#  ['rec_20_audio_15.wav', '<>'],
#  ['rec_20_audio_27.wav', '<>'],
#  ['rec_20_audio_21.wav', 'কানাডার মডেল'],
#  ['rec_20_audio_11.wav', '<>'],
#  ['rec_20_audio_25.wav', '<>'],
#  ['rec_20_audio_53.wav', '<>'],
#  ['rec_20_audio_33.wav', '<>'],
#  ['rec_20_audio_42.wav', 'ফোন করছে'],
#  ['rec_20_audio_36.wav', '<>'],
#  ['rec_20_audio_49.wav', '<>'],
#  ['rec_20_audio_30.wav', '<>'],
#  ['rec_20_audio_48.wav', 'আর বান্ধবী অনেক চালু হয়'],
#  ['rec_20_audio_46.wav', '<>'],
#  ['rec_20_audio_54.wav', 'না ওনাদের মতন লম্বা'],
#  ['rec_20_audio_45.wav', '<>'],
#  ['rec_20_audio_32.wav', '<>'],
#  ['rec_20_audio_41.wav', 'হবে'],
#  ['rec_20_audio_52.wav', '<>'],
#  ['rec_20_audio_44.wav', 'না'],
#  ['rec_20_audio_43.wav', '<>'],
#  ['rec_20_small_audio_0.wav',
#   'প্রশ্ন করবে হেরা হেরে প্রশ্ন করার মতন মাইয়া পোলা বাড়িতে আছে কি'],
#  ['rec_20_audio_47.wav', '<>'],
#  ['rec_20_audio_34.wav', '<>'],
#  ['rec_20_audio_55.wav', '<>'],
#  ['rec_20_audio_50.wav', '<>'],
#  ['rec_20_audio_56.wav', 'পাঁচতলা বিল্ডিং ছাতা মুভি'],
#  ['rec_20_audio_31.wav', '<>'],
#  ['rec_20_audio_40.wav', '<>'],
#  ['rec_20_audio_37.wav', '<>'],
#  ['rec_20_audio_57.wav', '<>'],
#  ['rec_20_audio_35.wav', 'নমো নমো নমো এখনো'],
#  ['rec_20_audio_51.wav', 'সমস্যা কি আজকালকার যুগে জানাবেন'],
#  ['rec_20_audio_38.wav', 'কার্যকর মার্কেট'],
#  ['rec_20_audio_39.wav', '<>'],
#  ['rec_20_small_audio_1.wav', 'পাওয়াটা গেছে ফুল'],
#  ['rec_20_audio_64.wav', 'আনোয়ার শাহ আলম তোমায় দেখেছি'],
#  ['rec_20_audio_58.wav', 'ঝামেলা'],
#  ['rec_20_audio_63.wav', '<>'],
#  ['rec_20_audio_66.wav', 'হেদি কি করতে হবে'],
#  ['rec_20_audio_65.wav', 'এই আগের চেয়ে একটু হয়েছে'],
#  ['rec_20_audio_61.wav', '<>'],
#  ['rec_20_audio_62.wav', '<>'],
#  ['rec_20_audio_59.wav',
#   'এ আমার মামাতো করতে হবে না মানা করতে গেলে তো আমার বান্ধবী বের হতে হবে না'],
#  ['rec_20_audio_60.wav', '<>'],
#  ['rec_21_audio_6.wav', '<>'],
#  ['rec_21_audio_5.wav', '<>'],
#  ['rec_21_audio_13.wav', '<>'],
#  ['rec_21_small_audio_0.wav', '<>'],
#  ['rec_21_audio_8.wav', 'আবার চলে যাবো কি পাইকের দড়ি লাগেনি'],
#  ['rec_21_audio_7.wav', 'মোবাইল'],
#  ['rec_21_audio_10.wav', '<>'],
#  ['rec_21_audio_1.wav', 'আকাশ না কে এত টাকা আছে'],
#  ['rec_21_audio_15.wav', 'কাজ আছে এখন কোনো না থাকলে চলে যেতে পারেন'],
#  ['rec_21_audio_3.wav', 'বাবাই আছে বিল্ডিং এর কন্টাক্ট নাম্বার'],
#  ['rec_21_audio_2.wav', '<>'],
#  ['rec_21_audio_4.wav', 'যেকোনো'],
#  ['rec_21_audio_11.wav', '<>'],
#  ['rec_21_audio_17.wav', 'কি জল আরকি'],
#  ['rec_21_audio_16.wav', 'বাড়ির কাজ'],
#  ['rec_21_audio_12.wav', 'একটু তেল দিমু ঝিক ঝিক ঝিক ঝিক করবে'],
#  ['rec_21_audio_14.wav', 'নামে দুইজন একজন ধাকা'],
#  ['rec_21_audio_0.wav', 'সকাল থেকে কিভাবে একটু অসুস্থ বলেন'],
#  ['rec_21_audio_9.wav', '<>'],
#  ['rec_21_audio_38.wav', 'হাগবি মানুষ ঠান্ডা লেগেছে'],
#  ['rec_21_audio_20.wav',
#   'এ শুয়োরের বাচ্চা তোর এত বড় সাহস মোর ভাইরে দেখতে পারিনা'],
#  ['rec_21_audio_21.wav', 'তুই কটা খাতিয়া বোকাচোদা'],
#  ['rec_21_audio_19.wav', '<>'],
#  ['rec_21_audio_30.wav', 'গুপিদা শাসন অফারের পল্লব রাঃ বাড়ি খাইতেন'],
#  ['rec_21_audio_32.wav', '<>'],
#  ['rec_21_audio_39.wav', 'আজকের ঝড়ের খেলা রাখতে শরীর নাহলে ক্ষতি করে'],
#  ['rec_21_audio_26.wav', 'না ভালো কাপড়ের শাড়ি ডিজাইন করা যায় না'],
#  ['rec_21_audio_27.wav', 'মায়ের বাহেরে দেখান'],
#  ['rec_21_audio_43.wav', 'আরে বৃষ্টি টাকা দিছি'],
#  ['rec_21_audio_34.wav',
#   'একটা ঘুম লাগেনা ব্যাটা ওই গাছটা বানায় একটু কাজ করেন'],
#  ['rec_21_audio_24.wav', 'ভাবিরে টেনে দিবেন'],
#  ['rec_21_audio_23.wav', 'দেখছো ভিডিওটা কাপড় তুলছে তত সুন্দর লাগে'],
#  ['rec_21_audio_41.wav', '<>'],
#  ['rec_21_audio_31.wav', 'কোন কিছু বাদ নাই'],
#  ['rec_21_audio_42.wav', 'শাশুড়ি'],
#  ['rec_21_audio_40.wav', 'ডুবান লাগে না অনেক সময় ডুবাইলে ক্ষতি নেই'],
#  ['rec_21_audio_25.wav',
#   'একখানে গেলাম একটা শাড়ি পড়ে না কতগুলো টাকা দামের শাড়ি দেয় না ভালো করে জানি'],
#  ['rec_21_audio_36.wav', 'তিন গ্যাস তিন গ্যাস সাইকেল দেবে'],
#  ['rec_21_audio_33.wav', '<>'],
#  ['rec_21_audio_35.wav', 'বুবলি দিয়েছে'],
#  ['rec_21_audio_37.wav', 'শাহাদাত না'],
#  ['rec_21_audio_18.wav', 'তাই কি বারে কি হইছে হের পর আমি গালাগালি করছি'],
#  ['rec_21_audio_28.wav', 'একদিন ভাত রান্না খাইতে পারতাম না'],
#  ['rec_21_audio_29.wav', '<>'],
#  ['rec_21_audio_22.wav', 'কি রান্নাবান্না'],
#  ['rec_21_audio_44.wav',
#   'আর 20 টা টাকা দিয়েছে পোলার 20 টাকা খাইয়া আর বৃষ্টি হয়নি'],
#  ['rec_21_audio_50.wav',
#   'আপনি দেখবেন আর এই যতই দুই একটা বড় ধরনের ঘটনা দেখি বড়লোকের ভিতরে হয় মান সম্মান'],
#  ['rec_21_audio_51.wav',
#   'এখন আর ওরে টাকা দিছে বুলেট কলেজে পড়তে ও বিশাল বড় ধরনের একটা ছাত্র হয়েছে সরকার চাকরি দিয়েছে 2 লাখ টাকা বেতন বিয়ে করলে পটুয়াখালী রূপসী মাইয়া পরিচয় দিবি না ওর বাপের তো যাইবে'],
#  ['rec_21_audio_53.wav', '<>'],
#  ['rec_21_audio_45.wav', 'ওই দিয়েছে'],
#  ['rec_21_audio_54.wav', 'মাঝে মাঝে খেতে মারি পানি বানান করতে পারে না'],
#  ['rec_21_audio_48.wav', 'শিক্ষার জন্য কিন্তু কাজে দেয়'],
#  ['rec_21_audio_49.wav',
#   'হ্যালো ছয় পোলা তিন মাইয়া সবাই বড় বড় ছিলেন শিক্ষিতরাই এইগুলান বেশি করে আমি দেখছি'],
#  ['rec_21_audio_47.wav',
#   'মিডিয়া গেছে হেনের মেয়র গেছে নানান প্রশ্ন হে মনে করেন এক লোক চালাইলো হে দেখলাম পাঁচ ছয়জনে অনেক প্রশ্ন আমার ভুল হয়েছে আমি মাফ চাই আমি এরকম কাম আর কোনদিন করবোনা'],
#  ['rec_21_audio_56.wav', 'এমন কোন ডিস্ট্রিকের লোক নাই'],
#  ['rec_21_audio_55.wav',
#   'কত মানুষ জানেন এই গরু নদীর বুকে বাংলাদেশের প্রত্যেকটা জেলার লোক আছে'],
#  ['rec_21_audio_46.wav',
#   'দেখি না চোখে দেখি না চশমা ছাড়া খালি দেখে বসে রয়েছে'],
#  ['rec_21_audio_52.wav',
#   'পরিচয় দিলে বউয়ের পেট নিচে থাকে না হাসে কি করবে উনি উনার বাবারে চিনবে না'],
#  ['rec_22_audio_6.wav', 'কথা বলবেনা'],
#  ['rec_22_audio_7.wav',
#   'একটা করতে কতটুকু ওষুধ থাকে কয় বেলা খাওয়ালে কতটুকু লাগবে'],
#  ['rec_22_audio_5.wav', '<>'],
#  ['rec_22_audio_1.wav', 'তুমি ভাত খাইছো'],
#  ['rec_22_audio_8.wav', '<>'],
#  ['rec_22_audio_2.wav',
#   'এখন আপনার গুলা খাই না খাওয়ানোর চেষ্টা করতে হবে আর আমার এই হোম মিনিস্টার খুব চালু হলো খাবে না'],
#  ['rec_22_audio_9.wav', '<>'],
#  ['rec_22_audio_4.wav', 'মানে কোন মানে ধন্যবাদ'],
#  ['rec_22_audio_0.wav', '<>'],
#  ['rec_22_big_audio_0.wav', '<>'],
#  ['rec_22_audio_3.wav', 'তিন সিরাপ খাইলো একটা আনছি না'],
#  ['rec_22_audio_12.wav', '<>'],
#  ['rec_22_audio_18.wav', 'না খেয়ে থাকুক নাকি করবি'],
#  ['rec_22_audio_21.wav', 'বদনাম না দিদি কত বড় অশান্তির মধ্যে আছি'],
#  ['rec_22_audio_30.wav',
#   'হেয়ার পরমাণু গান শোনেন আমার মাথা গেছে গরম হয়ে গেছে'],
#  ['rec_22_audio_22.wav', 'সাটাম না আপনি জানেন'],
#  ['rec_22_audio_28.wav', '<>'],
#  ['rec_22_audio_20.wav', 'রাত কার লাগে না'],
#  ['rec_22_audio_35.wav', 'বাদ দেন'],
#  ['rec_22_audio_23.wav', 'হইল'],
#  ['rec_22_audio_33.wav',
#   'আপনারে একটা কথা কই দিদি আমি একটা জিনিস বুঝি কোন মানুষ কি চায় যে বউয়ের একটা মানুষের দ্বারা এই কাম করলেন'],
#  ['rec_22_audio_11.wav', '<>'],
#  ['rec_22_audio_31.wav',
#   'গান ছাড়িও করবে ওষুধ খাওয়া লাগে ব্যথার ওষুধ গা ব্যথার খাইয়া খাইয়া এত কষ্ট করে সংসার করি মনে করেন'],
#  ['rec_22_small_audio_1.wav', 'এই বিয়ানে খায় না ভাত খায় না'],
#  ['rec_22_audio_10.wav', 'শাহজাহান ডাক্তার উপকারিতা'],
#  ['rec_22_audio_14.wav', '<>'],
#  ['rec_22_audio_34.wav',
#   'এখন মনে করেন আমি চিনতে পারছি যে ধরেন এই কাম কাজ করিয়া খাইলে ভালো আছি কিন্তু কাম হইবে কি একটা সমস্যা হলে 70 হাজার টাকা গেছে মোর বরিশাল হালাইছে কত ঝামেলার মধ্যে পড়ছিলাম'],
#  ['rec_22_audio_19.wav', '<>'],
#  ['rec_22_audio_24.wav', 'এখন কাকি কয়েকটা গরু পামু দিদি খেয়াল করুন'],
#  ['rec_22_audio_13.wav', '<>'],
#  ['rec_22_audio_32.wav', 'সহ্য করতে পারিনা'],
#  ['rec_22_audio_26.wav', 'মুই তো এখন পারি না'],
#  ['rec_22_audio_27.wav', 'হে গুগল কোন দিদি মনে করেন একটা মিনিট হয়েছে'],
#  ['rec_22_audio_15.wav',
#   'সারাদিন কাজ করে ওর চেয়ে আমার মাইয়ে ভালো সংসার করে'],
#  ['rec_22_small_audio_0.wav', 'আর একবেলা যদি মনে না থাকে'],
#  ['rec_22_audio_25.wav', 'আমার অনেক রিকোয়েস্ট করছে'],
#  ['rec_22_audio_16.wav', 'মিনি মিনি সিরিয়াল'],
#  ['rec_22_audio_36.wav',
#   'গরুর মতন খাটে তাই এই ব্যাটা তো একটা জীবন 5 দিনের 10 দিনের মাথায় যদি একদিন জিরাই নিয়ে বসে থাকলে কচ কচ কচ কচ করতাছি না'],
#  ['rec_22_audio_17.wav', '<>'],
#  ['rec_22_audio_29.wav',
#   'ভাইয়া তো মনে করেন চেয়ারম্যানের বাড়িতে গেছে ওর বাপের বাড়িতে পরিষদে আপনি কি মনে করছেন'],
#  ['rec_22_audio_50.wav', 'কষ্ট করেছে'],
#  ['rec_22_audio_56.wav',
#   'এই যদি সহ্য না করে তাহলে হেরম সমস্যা নাই পরিস্থিতি ওভার রোল করতে হবে'],
#  ['rec_22_audio_54.wav', '<>'],
#  ['rec_22_audio_38.wav', 'তিন দিন খাচ্ছি'],
#  ['rec_22_audio_47.wav',
#   'এই 150 টাকা যদি মোর ফ্যামিলিতে বাসে মোর কাঁচামালের বাজার হয়ে যাবে আমার চ্যালেঞ্জ হয়েছে কোন জায়গায় নেশা আমি মনে করেন একটা'],
#  ['rec_22_audio_42.wav', '<>'],
#  ['rec_22_audio_57.wav',
#   'আমি মনে করেন মানুষ এরকম হতে পারি সাদা কাগজে লিখিত তোমার একটা কথা যদি কেউ ঘুরেই ফালায় একটা কথা মিথ্যা'],
#  ['rec_22_audio_59.wav', 'বউরে আর বউয়ের বদনাম করে না'],
#  ['rec_22_audio_45.wav',
#   'অনেক পোলাপানের লগে চলছি এই পোলা নেশা হইতে শুরু করি এমন কোন তাও রশি নেই যে মুভি পোলা করি নাই আর আমি সব ছাড়িরে ভালোই সংসারী করি মনে করেন আমি যখন পোলাপানের লগে চলছি দৈনিক 50 টাকার 100 টাকার গাজা লাগবো আমার তামাক ছাড়া আমার জীবন চলতো না'],
#  ['rec_22_audio_48.wav',
#   '25 বছর হিসেবে 25 বছরের উপরে আমি বিড়ি খেয়েছি এই হইতে আর আজ পর্যন্ত একটা বিড়িতে আমি দেই না'],
#  ['rec_22_audio_43.wav', '<>'],
#  ['rec_22_audio_40.wav', 'থাকতাম না খাইয়া'],
#  ['rec_22_audio_46.wav',
#   'আর 10 টা সিগারেট খেলে এখন সেই দশটা সিগারেটের দাম 150 টা একদিন আমি মনে করেন এক নিজে নিজে চিন্তা করছি বিয়ের পরে ওই সময় কিন্তু খাই এখন একদিন চিন্তা করলাম যখন আমার প্রথম পোলাটা হইলো একটা জিনিস চিন্তা করলাম দশটা সিগারেট খাই দশটা সিগারেটের দাম 150'],
#  ['rec_22_audio_51.wav',
#   'আমি আমি আমার সিরিয়াস চান নেশা যখন বিয়া শাদী করি নাই রাত্রে একটা সময় কইছি মা বেতাল দিতে ঘুমাইতেছে'],
#  ['rec_22_audio_37.wav',
#   'আরে এখন গরু পালাইতে পারবে না একটা কথা জানবেন যারা পারি'],
#  ['rec_22_audio_53.wav',
#   'এই যে কইছি যে সরস্বতী কোথায় খুঁজে দেওয়া লাগে কথা রাইতে একটার সময় কইছি সেই সময় মায়ের দেশে হেই মাঝে মাঝে ভাবি'],
#  ['rec_22_audio_39.wav',
#   'আপনি বোধন একটা সেকেন্ড খেলায় তিনি ফুটোগুলো না একলা টাইনা নামান না চেহারা কালো হয়ে গেছে'],
#  ['rec_22_audio_41.wav', 'সংসারী করলে কষ্ট করতে দেওয়া লাগবে'],
#  ['rec_22_audio_58.wav',
#   'দেখছি এটা নিজের চোখকে বাস্তব প্রমাণে দেখছি এই জিনিসগুলো ঘটে সংসারে নিজে দেখছি সংসারের ঘটে সামনাসামনি বহুৎ কিছু কর'],
#  ['rec_22_audio_52.wav',
#   'এই একটা সময় মাইটি চা বানিয়ে দিয়েছে খেয়ে ঘুমাইছি আর এই যে এখন লক্ষ্মী আনছি সরস্বতী পাশে থেকে খুঁজে দেয়া লাগে একটু চা বানা ভালো লাগে না ভাত খাইয়া ঘুমাও'],
#  ['rec_22_audio_49.wav', '<>'],
#  ['rec_22_audio_44.wav', 'না আপনি হলেন বোঝেন আমি কিন্তু আমারে দেখেন'],
#  ['rec_22_audio_55.wav', 'মাথার ধারে থেকেই দেন'],
#  ['rec_23_audio_0.wav', '1 করছি'],
#  ['rec_23_audio_2.wav', '<>'],
#  ['rec_23_audio_1.wav', '<>'],
#  ['rec_23_audio_3.wav', 'তন্ময় সব জীবন হালদার দে'],
#  ['rec_24_audio_4.wav', 'এত সোজা কাম না'],
#  ['rec_24_audio_2.wav', '<>'],
#  ['rec_24_audio_0.wav', '<>'],
#  ['rec_24_audio_1.wav', '<>'],
#  ['rec_24_audio_3.wav',
#   'নিয়ে মনে করেন কামের ধারে লোকের বাকারা ঘুমায় না থাকলে আসবে না শুরু করে দি'],
#  ['rec_24_audio_6.wav', 'এমন সময় জায়গাটা উপরে গাছ গলায় দড়ি গেছি'],
#  ['rec_24_audio_21.wav', 'কানে চাপা ছিলাম বাড়িতে মাছ ধরছিলেন সাফ করছি'],
#  ['rec_24_audio_23.wav', 'খানকির পো গাড়ি নেই'],
#  ['rec_24_audio_12.wav', '<>'],
#  ['rec_24_audio_9.wav', 'তার বান্দের অভাব নাই'],
#  ['rec_24_audio_5.wav',
#   'তিন মাস একটানা গতবছর আজকে কাম করছি অনেক কিছু ভালো-মন্দ ডিপেন্ড করে না'],
#  ['rec_24_audio_18.wav', '<>'],
#  ['rec_24_audio_15.wav', '<>'],
#  ['rec_24_audio_13.wav', 'অনেকের দোকান'],
#  ['rec_24_audio_19.wav', 'মোর আসলাম ভাই ঈদের দিন পছন্দ না'],
#  ['rec_24_audio_24.wav', 'একটা মনে করেন কথা কইবে একাধিক গাল দিতে সহজ হবে না'],
#  ['rec_24_audio_7.wav', 'কইরে তুই যে আবার উপরে চোখ রাখবে যে কি করে জানেন'],
#  ['rec_24_audio_26.wav',
#   'কিছু কিছু ছাত্র আছে মাস্টার গুলাইয়া বেলেন্ডার করে গলায় শরবত খায় দেখা করবো না'],
#  ['rec_24_audio_14.wav', 'সেরা ফলাফল'],
#  ['rec_24_audio_16.wav', 'হাইড্রো বিবেকানন্দ ব্যাটা দেখাও ওর কোনো দুঃখ নেই'],
#  ['rec_24_audio_22.wav', '<>'],
#  ['rec_24_audio_27.wav',
#   'এই 11 বছরের সাত বছর ছয় সাত বছর তুরিতে বোবার মতন চলছে'],
#  ['rec_24_audio_8.wav', '<>'],
#  ['rec_24_audio_20.wav', 'আরে আমি কইছি দুই দিন দিন'],
#  ['rec_24_audio_17.wav', 'আমি কি করলাম'],
#  ['rec_24_audio_11.wav', '<>'],
#  ['rec_24_audio_10.wav', 'গত বছর'],
#  ['rec_24_audio_25.wav', '<>'],
#  ['rec_24_audio_45.wav',
#   'ও মনে করেন যে বছর বিয়ে করছে ওই বছর মেট্রিক পরীক্ষা দিয়েছিল আমি আমার ফ্যামিলির মানুষের সব সময় কইতাম'],
#  ['rec_24_audio_49.wav', 'খালি উপকারিতা'],
#  ['rec_24_audio_58.wav', 'পচা নাকি আনছিলাম না'],
#  ['rec_24_audio_48.wav', 'এত টাকা পামু বর্তমান হের পরও পারবে না'],
#  ['rec_24_audio_54.wav', '<>'],
#  ['rec_24_audio_39.wav', 'মোটা হয়েছে'],
#  ['rec_24_audio_41.wav',
#   'তবে মনে করেন কিন্তু সবচেয়ে যদি পোলাপান ভিডিও থেকে একটু খেয়াল রাখতো তাহলে আর মনের কষ্ট মনে করতাম এই গতবছর'],
#  ['rec_24_audio_44.wav', 'মেট্রিক পরীক্ষা'],
#  ['rec_24_audio_38.wav', 'গতবছর ঈদের সময় আব্বারে দিয়েছি'],
#  ['rec_24_audio_43.wav', 'এক কালার'],
#  ['rec_24_audio_32.wav',
#   'যদি দেখো ঘুমিয়ে পড়ছি দরকার হলে পানি মারবে না ঘুম ভাঙ্গে যদি বারোটার সময় এই সময় দেখলাম'],
#  ['rec_24_audio_60.wav', '<>'],
#  ['rec_24_audio_56.wav', '<>'],
#  ['rec_24_audio_35.wav', 'ঈদের 15 রোজার দিন মাহিলারা গেছি বেটা নিজস্ব দোকান'],
#  ['rec_24_audio_50.wav', 'এই এখন মনে করেন'],
#  ['rec_24_audio_37.wav', '<>'],
#  ['rec_24_audio_36.wav', '2150'],
#  ['rec_24_audio_59.wav', '<>'],
#  ['rec_24_audio_51.wav', '365 দিন'],
#  ['rec_24_audio_40.wav', 'না আমার মার কথা কইছে'],
#  ['rec_24_audio_28.wav', '<>'],
#  ['rec_24_audio_55.wav', '<>'],
#  ['rec_24_audio_53.wav', 'ধরে না'],
#  ['rec_24_audio_52.wav',
#   '100 দিনে যা ঘুমায় হেইয়া মুই 365 দিনে ঘুমাইতে পারিনা'],
#  ['rec_24_audio_30.wav', 'সারাদিন পর যাইবে তাই জিনিসটা দেয় না'],
#  ['rec_24_audio_57.wav', '<>'],
#  ['rec_24_audio_34.wav', 'এত কষ্ট করা লাগবে না'],
#  ['rec_24_audio_42.wav',
#   'যেখানে কাম করছি কামের পর 5 মিনিট খাইনি গোসল করে লক লাগবে তিন ঘন্টা 4 ঘন্টা পড়তে হবে'],
#  ['rec_24_audio_31.wav',
#   'এই এই যে গাছের কাম করি এমন দিন আছে শরীর এমন অসুস্থ লাগে বাসায় যদি লক লক একটুখানি খাইতেই টুক করে ঘুমিয়ে ঘুমিয়ে যাই বুঝছো একদিন কইছি যে'],
#  ['rec_24_audio_47.wav',
#   'তারপরও ফায়ার সার্ভিসে ঢুকতে পারতাম সার্টিফিকেট দিয়ে টাকা 10 লাখ দেওয়া লাগবে পারিনি'],
#  ['rec_24_audio_46.wav', '<>'],
#  ['rec_24_audio_33.wav', 'কিন্তু অন্যের বেলায় মোটেও না আর ও যদি মনে করেন'],
#  ['rec_24_audio_29.wav', '<>'],
#  ['rec_24_audio_76.wav', 'ইচ্ছামত মনে করে দিয়েছে'],
#  ['rec_24_audio_73.wav',
#   'তা হোক আমার তোমার 10000 টাকা বকশিস হইতো এমন এমন দিন আছে বার্থডে ফোন দিছি যে ভাই আমার তো'],
#  ['rec_24_audio_77.wav', 'সমস্যা আছে'],
#  ['rec_24_audio_67.wav', '<>'],
#  ['rec_24_audio_80.wav',
#   'একটা বিল্ডিং করছে বাড়িতে চাকরি করে দেখলে বিশ্বাস করবেন না'],
#  ['rec_24_audio_63.wav', '<>'],
#  ['rec_24_audio_68.wav', 'একটা কোম্পানি'],
#  ['rec_24_audio_71.wav', 'কোরবানির'],
#  ['rec_24_audio_69.wav',
#   'ওয়াশিং মেশিন মাইক্রোওভেন কালার টিভি মানে অনেক এমন কোন মাল নাই যে স্কয়ারের ওই প্রোডাক্টটা নাই একটা ফ্যামিলির হ্যান্ডেল চরিত্রে'],
#  ['rec_24_audio_64.wav', '<>'],
#  ['rec_24_audio_74.wav', 'সন্দেহ করছে'],
#  ['rec_24_audio_78.wav', '<>'],
#  ['rec_24_audio_66.wav', 'হা হা হা হা হা আমরা করলাম'],
#  ['rec_24_audio_84.wav', '<>'],
#  ['rec_24_audio_83.wav', 'ব্যবসা কিভাবে সম্ভব'],
#  ['rec_24_audio_61.wav',
#   'বড় কষ্টের দিন করছি একটা লোক ঢাকা শহর খাইয়া লইয়া মোর এককালে বাড়িতে 20 হাজার টাকা দিতে পার'],
#  ['rec_24_audio_75.wav', 'নাম্বারে দিছে ফোন আর ফোনের ব্যবহার করছে'],
#  ['rec_24_audio_65.wav',
#   'কিসমিস পরে এমন ভাবে চলতাম কোন মানুষের বুঝতে পারতো না ধরতে পারি না'],
#  ['rec_24_audio_79.wav', 'বঙ্গবন্ধুর জীবন কাহিনী'],
#  ['rec_24_audio_82.wav', 'গতবছর গৌরনদীতে কাম করছে'],
#  ['rec_24_audio_62.wav', 'এসি ফ্রিজ ওয়াশিং মেশিন'],
#  ['rec_24_audio_81.wav', 'এখন একটু কম করি'],
#  ['rec_24_audio_70.wav', '<>'],
#  ['rec_24_audio_72.wav', '<>'],
#  ['rec_24_audio_95.wav', 'ক্যাঙ্গারু বানিয়ে ফেলেছেন'],
#  ['rec_24_audio_96.wav', 'খাওয়ানের চেষ্টা করবে'],
#  ['rec_24_audio_94.wav', 'খায়না'],
#  ['rec_24_audio_89.wav', '<>'],
#  ['rec_24_audio_87.wav', 'মরা মনে করেন'],
#  ['rec_24_audio_91.wav',
#   'আন্তর্জাতিক খালি কও যে খায় না খায় না পোলাপানে খাইতেই হবে না এটা চেষ্টা করতে হবে মোর ছোট ভাইয়ের পাঠালে'],
#  ['rec_24_audio_86.wav', '<>'],
#  ['rec_24_audio_93.wav', 'খামু না'],
#  ['rec_24_audio_88.wav', 'এমনটা দেবে'],
#  ['rec_24_audio_92.wav', 'সুর'],
#  ['rec_24_audio_90.wav',
#   'কি করো এখন পাঁচটা জিনিস একটু একটু করে খাওয়াবি ওর পেটের ভিতরে যাওয়ার পর'],
#  ['rec_24_audio_85.wav', 'এদিক ওদিক আরো আছে গান আছে না আছে এখন আর কটা আছে'],
#  ['rec_24_small_audio_0.wav', 'আই'],
#  ['rec_25_audio_8.wav', 'মারামারি হয়েছে মারামারি'],
#  ['rec_25_audio_7.wav', 'এত সমস্যা হইতে পারে না'],
#  ['rec_25_audio_1.wav', '<>'],
#  ['rec_25_audio_0.wav', '<>'],
#  ['rec_25_audio_4.wav', '<>'],
#  ['rec_25_audio_9.wav', '<>'],
#  ['rec_25_audio_11.wav', '<>'],
#  ['rec_25_audio_2.wav', '<>'],
#  ['rec_25_audio_12.wav', '<>'],
#  ['rec_25_audio_5.wav', '<>'],
#  ['rec_25_small_audio_0.wav', '<>'],
#  ['rec_25_audio_10.wav', '<>'],
#  ['rec_25_audio_6.wav', '<>'],
#  ['rec_25_audio_3.wav', '<>'],
#  ['rec_26_audio_2.wav', 'হোয়াট ইউ ডুইং দিয়ে কি করবেন'],
#  ['rec_26_audio_0.wav', 'স্লামালাইকুম'],
#  ['rec_26_audio_3.wav', 'কালোটা জমবে'],
#  ['rec_26_audio_4.wav',
#   'জুমার পরে আবার পানি দিমু পানি দিয়ে গলায় থুয়ে দিমু আবার পানি এলাম দিয়ে বের করবো'],
#  ['rec_26_audio_5.wav', 'এরপর বন্ধ করুন আপনি ছোট সময় কি'],
#  ['rec_26_audio_1.wav', 'কি করেন আপনি বাসা কোথায় আপনি কি কাজ করেন'],
#  ['rec_26_audio_6.wav',
#   'কি খেলে যে পছন্দ ছিল ছোটবেলায় তো খেলছি তারপর শিবপুরী খেলছি এই কত পদের খেলা নিয়মটা কি'],
#  ['rec_26_audio_10.wav', 'এরপরে খেলা খেলতাম খেলা আবার যাইতাম সবার খেলা খেলা'],
#  ['rec_26_audio_9.wav', 'কত ধরনের খেলা আগের খেলা'],
#  ['rec_26_audio_8.wav', '<>'],
#  ['rec_26_audio_7.wav', 'এরপর আবার আরেকজন'],
#  ['rec_06_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_05_big_audio_2_chunk_0.wav', '<>'],
#  ['rec_05_big_audio_2_chunk_2.wav', '<>'],
#  ['rec_05_big_audio_2_chunk_1.wav', '<>'],
#  ['rec_14_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_11_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_16_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_14_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_16_big_audio_0_chunk_0.wav', '<>'],
#  ['rec_16_big_audio_3_chunk_0.wav', '<>'],
#  ['rec_16_big_audio_3_chunk_1.wav', '<>'],
#  ['rec_11_big_audio_1_chunk_1.wav', '<>'],
#  ['rec_06_big_audio_0_chunk_1.wav', '<>'],
#  ['rec_20_big_audio_1_chunk_0.wav', '<>'],
#  ['rec_04_audio_63_chunk_1.wav', '<>'],
#  ['rec_14_audio_9_chunk_1.wav', '<>'],
#  ['rec_04_audio_63_chunk_0.wav', '<>'],
#  ['rec_14_audio_9_chunk_0.wav', '<>'],
#  ...]

# %%
len(info)
# Out:
# 1062

# %%
df = pd.DataFrame(columns = ["External_ID", "Contents"])
df
# Out:
# Empty DataFrame
# Columns: [External_ID, Contents]
# Index: []

# %%
aud = []
content = []

for i in info:
    aud.append(i[0])
    content.append(i[1])


# print(len(aud))
# print(len(content))

# %%
df["External_ID"] = aud
df["contents"] = content

# %%
df
# Out:
#               External_ID Contents  \
# 0     rec_01_audio_59.wav      NaN
# 1     rec_01_audio_70.wav      NaN
# 2     rec_01_audio_66.wav      NaN
# 3     rec_01_audio_62.wav      NaN
# 4     rec_01_audio_68.wav      NaN
# ...                   ...      ...
# 1057  rec_01_audio_57.wav      NaN
# 1058  rec_01_audio_63.wav      NaN
# 1059  rec_01_audio_67.wav      NaN
# 1060  rec_01_audio_58.wav      NaN
# 1061  rec_01_audio_65.wav      NaN
#
#                                                contents
# 0                              আমি মনে হয় তোকে বলছিলাম
# 1     সর্বশেষে সব মিলিয়ে যোগ করলে দেখা যায় আমারও আ...
# 2     যে এই ছেলেটার রেজাল্ট খারাপ বা এই ছেলেটা স্কিল...
# 3     আসলে কাজ কি আমি কিভাবে করলে যাইতে পারবো কে কিভ...
# 4     সবদিক দিয়ে মনে করো এখন 100 মানে কি হয়তো আমি ...
# ...                                                 ...
# 1057         তথ্যটা এক্সপেরিয়েন্স আমার তো একটা ছিল নাই
# 1058  ওয়াটার কাস্টার মানে সময়টা প্রডাক্টিভিটি কাজে...
# 1059  আল্লাহতালা সব মানুষকে সবদিক দিয়ে 100 করে পাঠি...
# 1060  ইচ্ছা আছে দেখি আমি জানিনা কালকেও কি আমার কথা হ...
# 1061  আমি যদি টাইম দিই তাহলে আমি পারবো সময় নষ্ট না ...
#
# [1062 rows x 3 columns]

# %%
len(df)
# Out:
# 1062

# %%
df.to_excel("1.8: /content/drive/MyDrive/local_speech/others/benchmarks_codes_and_models/1. google-asr-inferences/barishal-google-asr-testing.xlsx")

# %%
print(list(info.keys()).index("rec_03_audio_13.wav"))
print(list(info.values()).index("আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে"))
# Out:
# 2084
# 2085

# %%
df["Clip No."] = info.keys()
df["Transcription"] = info.values()


df
# Out:
#                  Clip No.                                      Transcription
# 0     rec_28_audio_20.wav                           কেক বই থেকে বানানা দেখাও
# 1      rec_28_audio_0.wav  আলহামদুলিল্লাহ ভালো হইছে হাইব্রিড করছি না অন্য...
# 2      rec_28_audio_6.wav                           শোল মাছ হোতা হে বলে আসেন
# 3     rec_28_audio_37.wav                                                 <>
# 4     rec_28_audio_23.wav                        ভাত খাওয়া দাওয়া ভাত খাইছো
# ...                   ...                                                ...
# 2081  rec_03_audio_12.wav          অবস্থা কি হয়েছে ভাই খুব সমস্যা ইনকাম নেই
# 2082  rec_03_audio_18.wav                                                 <>
# 2083  rec_03_audio_27.wav                                           মুছে দেন
# 2084  rec_03_audio_13.wav                                      ভুট্টার বাজার
# 2085   rec_03_audio_1.wav       আপনার পরিবারের হালচাল একদম খালি খারাপ হয়েছে
#
# [2086 rows x 2 columns]

# %%
df = pd.DataFrame()

for i, j in info.items():
    # df["Clip No."] = i
    # df["Transcription"] = j

    print(i,"==========",j)

df

# %%
audInfo = []
aud = data = f"{data1}{d[-1]}"
audInfo.append(aud)
pred=infer(aud)
audInfo.append(pred)


info.append(audInfo)

# %%
# Out:
# [['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_0.wav',
#   'একটা সুন্দর আছে তো ভাই'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_4.wav',
#   'ছেলেটা ছেড়ে দিয়েছে'],
#  ['/content/drive/MyDrive/local_speech/others/testing_audios/rec_01_audio_2.wav',
#   'কামালের জিজ্ঞেস করবে']]

# %%
# Out:
# 'rec_01_audio_0.wav'

# %%
info
# Out:
# [['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই'],
#  ['rec_01_audio_4.wav', 'ছেলেটা ছেড়ে দিয়েছে'],
#  ['rec_01_audio_2.wav', 'কামালের জিজ্ঞেস করবে'],
#  ['rec_01_audio_1.wav', '<>'],
#  ['rec_01_audio_3.wav', '<>'],
#  ['podcast.wav',
#   'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি'],
#  ['natok_short.wav',
#   'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা']]

# %%
info[0]
# Out:
# ['rec_01_audio_0.wav', 'একটা সুন্দর আছে তো ভাই']

# %%
for wav in tqdm(glob(os.path.join(data1, "*.*"))):
    if wav[-4:] == ".wav":
        pred=infer(wav)
        print(pred)
        print("=======================")
        print()
# Out:
#   0%|          | 1/1000 [00:05<1:35:55,  5.76s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338659, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
# =======================
#   0%|          | 1/1000 [00:07<2:12:05,  7.93s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/1132394388.py in <module>
#       1 for wav in tqdm(glob(os.path.join(data1, "*.*"))):
#       2     if wav[-4:] == ".wav":
# ----> 3         pred=infer(wav)
#       4         print(pred)
#       5         print("=======================")
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
#df["prediction"]=df["path"].progress_apply(lambda x:infer(x))
preds=[]
for idx in tqdm(glob(os.path.join(data1, "*.*"))):

    #print(idx[34:])
    pred=infer(idx)
    print(pred)


    #_path=df.iloc[idx,0]



#     try:
#         pred=infer(_path)
#         preds.append(pred)
#     except Exception as e:
#         preds.append(None)
#         print(_path)
#         print(e)
# Out:
#   0%|          | 1/1000 [00:05<1:34:17,  5.66s/it]
# result2:
# {   'alternative': [   {'confidence': 0.65338248, 'transcript': 'সারাদিন'},
#                        {'transcript': 'সাদা দিস না'},
#                        {'transcript': 'সারাদেশ'},
#                        {'transcript': 'সাদা দিস'}],
#     'final': True}
# সারাদিন
#   0%|          | 1/1000 [00:07<2:08:12,  7.70s/it]
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /tmp/ipykernel_28/4080879346.py in <module>
#       4
#       5     #print(idx[34:])
# ----> 6     pred=infer(idx)
#       7     print(pred)
#       8
#
# /tmp/ipykernel_28/2588987697.py in infer(AUDIO_FILE)
#       4     with sr.AudioFile(AUDIO_FILE) as source:
#       5         audio = r.record(source)  # read the entire audio file
# ----> 6     text = r.recognize_google(audio, language ='bn-BD')
#       7     text = str(text)
#       8     return text
#
# /opt/conda/lib/python3.7/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917         print('result2:')
#     918         pprint(actual_result, indent=4)
# --> 919         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     920
#     921         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
df=pd.read_csv("/kaggle/input/random/Kishoreganj_Data.csv")
#df["path"]=df["path"].progress_apply(lambda x: os.path.join("/kaggle/input/randomshit/DLSprintTestDataset/validated/",x))

# %%
aud = "/kaggle/input/kishoreganj-proto-1/rec_01_audio_0.wav"
pred=infer(aud)
pred
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.77698362,
#                            'transcript': 'একটা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছে তো ভাই'},
#                        {'transcript': 'ঠাট্টা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছেতো'},
#                        {'transcript': 'একটা সুন্দর আছে তো'}],
#     'final': True}
# 'একটা সুন্দর আছে তো ভাই'

# %%
df["predition"]=preds

# %%
df

# %%
df.to_csv("google_test.csv",index=False)

# %%
x_dir = '/content/drive/MyDrive/local_speech/others/testing_audios/'

x = os.listdir(x_dir)

print(x)
# Out:
# ['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav']

# %%
df = pd.DataFrame(columns = ["Clip No.", "Transcription"])
df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []

# %%
info = {}

for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred=infer(aud)
        info[i] = pred
    except Exception as e:
        info[i] = "<>"
        #print(e)

# %%
info.keys()
# Out:
# dict_keys(['rec_01_audio_0.wav', 'rec_01_audio_4.wav', 'rec_01_audio_2.wav', 'rec_01_audio_1.wav', 'rec_01_audio_3.wav', 'podcast.wav', 'natok_short.wav'])

# %%
info.values()
# Out:
# dict_values(['একটা সুন্দর আছে তো ভাই', 'ছেলেটা ছেড়ে দিয়েছে', 'কামালের জিজ্ঞেস করবে', '<>', '<>', 'এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড্রাইভে গিয়েছি আমরা গান শুনছি এই গানের যে শব্দটা বা গানটা আমি যেহেতু দেখছি না এবং শুধু শুনছি দি', 'ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়ির মুখোমুখি তে দুজনের মৃত্যু ঘটে শোনা'])

# %%
df[["Clip No.", "Transcription"]] = info.keys(), info.values()

# %%
df
# Out:
#              Clip No.                                      Transcription
# 0  rec_01_audio_0.wav                             একটা সুন্দর আছে তো ভাই
# 1  rec_01_audio_4.wav                               ছেলেটা ছেড়ে দিয়েছে
# 2  rec_01_audio_2.wav                               কামালের জিজ্ঞেস করবে
# 3  rec_01_audio_1.wav                                                 <>
# 4  rec_01_audio_3.wav                                                 <>
# 5         podcast.wav  এমন ধরা যেতে পারে যে আমরা কেউ গাড়ি নিয়ে লং ড...
# 6     natok_short.wav  ব্যারাকপুর একটা গাড়ি এক্সিডেন্ট ট্রাক আর গাড়...

# %%
for i in x:
    aud =  f"{x_dir}{i}"

    try:
        pred = infer(aud)
        df[["Clip No.", "Transcription"]] = i, pred

    except Exception as e:
        df[["Clip No.", "Transcription"]] = i, "<>"

        #print(e)

df
# Out:
# Empty DataFrame
# Columns: [Clip No., Transcription]
# Index: []
