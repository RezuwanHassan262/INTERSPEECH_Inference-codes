# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install audiosegment
import audiosegment
# Out:
# Collecting audiosegment
#   Downloading audiosegment-0.23.0-py3-none-any.whl (34 kB)
# Collecting pydub (from audiosegment)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting webrtcvad (from audiosegment)
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiosegment) (1.25.2)
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73463 sha256=269b913ee7b83ddf5b66523a219b4f5bf6f7165d612a7460109f92300b08fb84
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built webrtcvad
# Installing collected packages: webrtcvad, pydub, audiosegment
# Successfully installed audiosegment-0.23.0 pydub-0.25.1 webrtcvad-2.0.10

# %%
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()

# %%
data_dir = '/content/drive/MyDrive/local_speech/others/for_now/tangail/'

# %%
all_audio_data = os.listdir(data_dir)
all_audio_data
# Out:
# 1321

# %%
len(all_audio_data)
# Out:
# 1321

# %% [markdown]
# # Bangla Wav2Vec2-large

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/auditi41/wav2vec2-large-xlsr-53-Bangla"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# %%
external_id = []
contents = []
errors = []
c = 0
#c&i = []

def once(output,i):

    external_id.append(i)

    if len(output['text']) == 0:
        contents.append("<>")
    else:
        contents.append(output['text'])


def again(audio,i):

    global c

    try:
        output = query(audio)

        if 'error' in output.keys():
            if c != 5:
                c += 1
                again(audio)
            else:
                c = 0
                external_id.append(i)
                contents.append("<>")
                pass
        else:
            once(output,i)


    except Exception as e:
        again(audio,i)


for i in all_audio_data:

    audio = f"{data_dir}{i}"


    try:
        output = query(audio,i)
        once(output)

    except:
        again(audio,i)

# %%
print(errors)
print()
print(len(errors))
# Out:
# []
#
# 0

# %%
print(external_id)
print()
print(len(external_id))
print()
print("=======================")
print()
print(contents)
print()
print(len(contents))
# Out:
# ['rec_07_audio_20.wav', 'rec_06_small_audio_8.wav', 'rec_07_audio_25.wav', 'rec_08_audio_8.wav', 'rec_10_audio_10.wav', 'rec_10_audio_18.wav', 'rec_08_audio_7.wav', 'rec_08_small_audio_2.wav', 'rec_08_audio_16.wav', 'rec_10_audio_13.wav', 'rec_08_audio_5.wav', 'rec_08_audio_11.wav', 'rec_08_audio_14.wav', 'rec_10_audio_17.wav', 'rec_10_audio_15.wav', 'rec_10_audio_16.wav', 'rec_08_small_audio_0.wav', 'rec_08_audio_4.wav', 'rec_10_audio_0.wav', 'rec_08_audio_2.wav', 'rec_09_audio_2.wav', 'rec_07_audio_9.wav', 'rec_08_audio_9.wav', 'rec_08_audio_18.wav', 'rec_10_audio_3.wav', 'rec_08_audio_3.wav', 'rec_09_audio_1.wav', 'rec_10_audio_1.wav', 'rec_08_audio_19.wav', 'rec_09_audio_0.wav', 'rec_08_audio_0.wav', 'rec_08_small_audio_1.wav', 'rec_10_audio_11.wav', 'rec_10_audio_14.wav', 'rec_08_audio_1.wav', 'rec_08_audio_12.wav', 'rec_08_audio_6.wav', 'rec_08_audio_17.wav', 'rec_10_audio_4.wav', 'rec_07_small_audio_0.wav', 'rec_08_audio_10.wav', 'rec_08_audio_13.wav', 'rec_10_audio_12.wav', 'rec_08_audio_15.wav', 'rec_10_audio_2.wav', 'rec_11_audio_16.wav', 'rec_11_big_audio_1_chunk_1.wav', 'rec_11_audio_4.wav', 'rec_10_audio_5.wav', 'rec_11_audio_3.wav', 'rec_11_audio_7.wav', 'rec_12_audio_1.wav', 'rec_10_audio_9.wav', 'rec_11_audio_20.wav', 'rec_11_audio_13.wav', 'rec_11_audio_2.wav', 'rec_11_audio_1.wav', 'rec_11_audio_12.wav', 'rec_10_audio_8.wav', 'rec_11_audio_9.wav', 'rec_11_audio_15.wav', 'rec_11_big_audio_0.wav', 'rec_11_audio_0.wav', 'rec_10_audio_7.wav', 'rec_11_audio_19.wav', 'rec_11_small_audio_0.wav', 'rec_12_audio_10.wav', 'rec_11_audio_11.wav', 'rec_11_audio_5.wav', 'rec_11_audio_14.wav', 'rec_11_audio_17.wav', 'rec_10_audio_6.wav', 'rec_11_small_audio_1.wav', 'rec_11_big_audio_1_chunk_0.wav', 'rec_11_audio_6.wav', 'rec_11_small_audio_2.wav', 'rec_12_audio_0.wav', 'rec_11_audio_8.wav', 'rec_11_audio_18.wav', 'rec_11_audio_10.wav', 'rec_12_audio_24.wav', 'rec_12_audio_15.wav', 'rec_12_audio_2.wav', 'rec_12_audio_43.wav', 'rec_12_audio_28.wav', 'rec_12_audio_16.wav', 'rec_12_audio_45.wav', 'rec_12_audio_14.wav', 'rec_12_audio_19.wav', 'rec_12_audio_37.wav', 'rec_12_audio_36.wav', 'rec_12_audio_4.wav', 'rec_12_audio_11.wav', 'rec_12_audio_40.wav', 'rec_12_audio_42.wav', 'rec_12_audio_23.wav', 'rec_12_audio_12.wav', 'rec_12_audio_17.wav', 'rec_12_audio_27.wav', 'rec_12_audio_38.wav', 'rec_12_audio_35.wav', 'rec_12_audio_29.wav', 'rec_12_audio_22.wav', 'rec_12_audio_26.wav', 'rec_12_audio_44.wav', 'rec_12_audio_33.wav', 'rec_12_audio_41.wav', 'rec_12_audio_25.wav', 'rec_12_audio_13.wav', 'rec_12_audio_18.wav', 'rec_12_audio_30.wav', 'rec_12_audio_21.wav', 'rec_12_audio_20.wav', 'rec_12_audio_34.wav', 'rec_12_audio_31.wav', 'rec_12_audio_3.wav', 'rec_12_audio_32.wav', 'rec_12_audio_39.wav', 'rec_12_audio_53.wav', 'rec_12_audio_9.wav', 'rec_12_audio_71_chunk_1.wav', 'rec_12_audio_47.wav', 'rec_12_audio_67.wav', 'rec_12_audio_69.wav', 'rec_12_audio_46.wav', 'rec_12_audio_70.wav', 'rec_12_audio_49.wav', 'rec_12_audio_8.wav', 'rec_12_audio_66.wav', 'rec_12_audio_71_chunk_0.wav', 'rec_12_audio_51.wav', 'rec_12_audio_68.wav', 'rec_12_audio_5.wav', 'rec_12_audio_58.wav', 'rec_12_big_audio_0.wav', 'rec_12_audio_56.wav', 'rec_12_audio_60.wav', 'rec_12_audio_64.wav', 'rec_12_audio_6.wav', 'rec_12_audio_50.wav', 'rec_12_audio_62.wav', 'rec_12_audio_61.wav', 'rec_12_audio_63.wav', 'rec_12_audio_65.wav', 'rec_12_audio_48.wav', 'rec_12_audio_59.wav', 'rec_12_audio_57.wav', 'rec_12_audio_52.wav', 'rec_12_audio_7.wav', 'rec_12_audio_54.wav', 'rec_12_audio_55.wav', 'rec_13_audio_17.wav', 'rec_13_audio_1.wav', 'rec_13_audio_4.wav', 'rec_13_audio_9.wav', 'rec_13_audio_15.wav', 'rec_13_audio_0.wav', 'rec_13_audio_5.wav', 'rec_13_audio_10.wav', 'rec_13_audio_16.wav', 'rec_13_big_audio_0_chunk_0.wav', 'rec_13_audio_13.wav', 'rec_13_audio_6.wav', 'rec_12_small_audio_2.wav', 'rec_13_audio_8.wav', 'rec_13_audio_14.wav', 'rec_12_small_audio_0.wav', 'rec_13_audio_11.wav', 'rec_12_small_audio_5.wav', 'rec_12_small_audio_1.wav', 'rec_12_big_audio_2.wav', ...
#
# 1321
#
# =======================
#
# ['<>', 'তুনু কীমনে অনু বক্কার বাহিতোমার খুটি ভুরিটার মালী বেদে ছে কার তেয় নানা দীযয়ে গীতুমানু দেখার বেরা গায়িত শয়ে।', 'কুল উপুস্তি নিয়াই দিতি ে মুহম মিবেষটি অচ্ত চরতে লা লিনয়া তরের ব্লেপায় লোপড়ো বিলা সববচ্থার ফলতাপরি করেট', 'তৌৎস্বযামী তাকাইলাম মাহি যে ট রামী ধিকে যে তে সনেমনো লুদ্ধতত তামের স্বাথেরে থেকে তাকে আলম্দেরন জেকি সরিমেয়ত তার্মাধ্যে সামনে কালীবাড়ি পরে মায়ের নামেকে সিককালী়তারাগ প্রসিমা়গালি দায়ী প্রসি আর পরে বেওয়েসর।', 'চিন মা নামকিরকি হ্যা কয়েটাইতাপরহ্য টিয়েতিএ আকা কিন্তু দেখতাসপোর চলে হাগুলাকি বি ছিডি মি ফুলিন লে খর হোরকেনলা ্া েন্লে ফর্ম।', 'তানাখেলতায়ে ফণ্ঢকে না ক্রিকডেশ এত ক্ষুমুপর্প মঈনকর্থেন সৃষ।', 'তেও তার ভরমাফিল্ব লান যেতোমার বেজির মত্য কিজেন একটা ধূরে অনেক কিছুরেক্টা বেজির মতো বা বিলায়ার় বন্তুকি স্রােকতে দৌরাই এছে খঞ্যে  অনে দ্রুত আই আমাদেশ দোকানের ঐজাথীকে সূজগরের আশ্রভ ের পাশাক টিকে অনিরী্ভমণংটা ত্রীগনতা উজ্দেস্ছে।', 'পাংলা য অভা় ব্যববাদের জার্নানদারী চিলগগার।', 'কমতত', 'অৌত এই এ সব মজে দ্বারা ব্যবসাগচ্থেথাৈদলো বেশি ভ্াকমানুগরো ঢাকার দিকতারিটিব্যামপক জুলরিসুরগরএই ডাহয়োদাবার্ত মারে ইযাডিয়াদেসে তোম টাকাদিয়ে বিস্বায়িকতআযজেন।', 'গেস্তীয় চেয়া গডার দিকে হেমারটিক্যালায়ে থেকে জনির্বেক্া হেরজন্তার াট গাণ ক্যাব কেরাটারকএকটারে কলের মছা় ফারার তরাতোমারউচ্ছে চাবিরা কি আমার কাসতেযাওয়া নিশররসমপান্তলেযা শাবিলয়ে খিলে।', 'ত ঐ তির িতে এপালাইগোস্তীগতকলে রাপের প্রথমজঙগে বয়  এইটসাবী র সেথবার চোগকি লিয়ে কেম।', 'দে যতৈরগের দুগজে ধরথােরতয দিমকারেনের ফিলে তে যেহে সেতে করে তােমূলোে উনিনেদে ডয়ক্থাগেকালকেরাতে পরে রূমিয়ে সি রুমে এসে জামআমলো খুলে রাখি ক্যালকে ও সব জাংলা আটকাইরিসে আটকায় দিয়া পডে সীফরীমানা ইুরোগম চিল্নাম ্নাইতেস লোয়ার ঘুম ধুরতে ছিল।', 'আমদু আন্ডাইর রুম্গউ কল িটিুস্থাই হ় সেটে লোকাল ীতি পেখাবে উদেশ রামযের হাপে নিল ভাউকালার পুরকু নার্মন করাযে এহনি জোদে মারি সাট্টাতুম গেক্ষম ট অজেমনির অংসং আইরমযােই  অন্য রপন্যাথ করকে কাজ করততে তিনি দুলঞাসুয়ে পুরার নয়।', 'মবমএটা ছবিতের জের কোনছুন্দলয় পুসফের বাস্ত্রন মিরোতা যা তোটার ফুন্দর না হএডেই সব শাইর জন্যমানো এর পেস থিকারনিতে সাইলেমি ছবি কালী হনা কেতেমর একটজশ ছুলিউটাে ক্েযামেরারটু ছেলের  দাপুর এবর এডি তনিগিট ক্রিয়াও কড়েনমার।', 'তমারনদীযতজমীর ফুমবুর্লসেডাই বশে জন্মঋত পশ্ছেযে এ সব জাওয়া ধেনমানে জলেজা নিইয়া মরা কাছনিলার ভাল্লা ধ্গান্নাভুলযতার জন্নেই তার জনুবলতা সিজুফুনিয়ে সামনে থিকানতি এঐ সাড্ডা ফটদেম ইটোহনেমোঐ মানে ই রকমের মধ্যে টিগেছা এতোমার জেটে দেখতের দযেটের লেখে পেশিভার লালিখান্স দুই কেযর্মগিরুস্রমের ভয়ই কোল ইজমাল।', 'মাঝা হযেএর জন্ধ নআয়লা আতে হন ন হয়দার ইভেন গুমানহা।', 'স্টেশনা মিস্টিসিখারভারা সহহপেলামাই ফলার পোরশে পানিডালিযার ইউনানিকাহি ও কালগীযাতে একোময়াসিয় বাউর্টার দিকে বাল্টার দিকে যায়িত সি গান মযঙমর দিয়াস অব্যমান্পটড বঙ্গ কাচরা জীব এবং মুবয়ের রাসেহে।', 'ফিটা এ ডাওয়ার ভিচ্ছের বাইয়ে বলতততকিপুনাএরাজা এ ব্যবসা করে এগারে গাছে চেইমালটা থাকেকভাতে নিয়েয় ব্যবসা করত শ্রেনকন রয়েছ।', 'তটিএ হনিট য়যয়েছেকে র দেটি হয়েসপেচিরা আনহার এগররভণনে থিকে এর সূৎকলপন ভিন পার্তে হার করনাথ তলবের স্সলেলে উপনাথ প্রেসাইরিয় গডা ছি হনসূম স্পিি ফারেলান্জাযীকা গ্যাপে তার ঐতারাতে মূল এলেদে দোঙ্গার মত যোগতা সুব্রযাপং রার্লোকে কিছু বিলাঙের বন্ডড।', 'তা রাখানেলোমানা হকুটফত রয়েবে ও কান্দ মহরয়েে সাগেঅমরা ফযার নেলাই সপেয়েছেনা জালা আওয়ার হয়ে দলবে যাওয়া কেছুলে গযূদ সন্তার পুপ্ররাসপুরে তায়িকি একা ফল রয়ে দাকদা লুলেতে মারুত হর্ত।', 'বটসমা গ্রহণ ঢাপেপ্ছম বযাটার জন্দভায় তে হনবর লাল হয়েছেকামেয়এটময়়ার্মনো হডমার পুমগুনেয়া হয়ে কেয়েএজাশ্রনা ন সি ফুল জায় কে লা় সুর হয়িৎচালন করে ।', 'নিয্াসে ডায়র এক মুখন উর্করিয়া জ্বলা়ল জলায়স্বব্যাপরে গেটেবিতরে ডিকে রাষ্ট্র সেে কেেফিরিরে এগেজান ে রিয়ে থালে  লি এ গেছ হজ তেহা বিরিকর রিয়য়ে পড়েছিলএপরজেলাযই থেকে উত্তা কেরোডোকরে পনাথ ভাউডো অর্বেন সতর দয়ে বরেট খুল্নলি শন্দই হালা ্না।', 'আলী দের একটা বিলাই ডেক্সিবিলাইটো থাকটি ইঠাবের।', 'ফুলাপ গাঙার নাটীবানেত অনেক মাল আছে উপেযে কনোমাল্লা বেশি ভাল লাগ প্রাসিক্টমডার কাছ্টা কোনো ফিনি সিংডা অনেকশনি ছবিতবিধে প্যবা দৈরী করে।', 'তততেই একা রাকালিগবার উততাহল হরেআছাড়ামি দমরে কালপে রাদের কতা উলি হায়বিল কাউতি রাতে তোমার হচ্ছে আমি  তার কাউর্ড বিফোরতার ভরে রবেআমারে তি।', 'রতাদ্রে বিয় বিভিন্ন রহওয় যগধাা লাথে নিয়েথনরাজারাছ থাকিস কয়েল ভিয়াবিতরে আমা দাধির া তেউদার বিয়াহিথি হখেএটে  টাসমে ময়।', 'ক ...
#
# 1321

# %%
num = x.index("rec_19_audio_40.wav")
num
# Out:
# 324

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'text': 'আল অথএ নম বয়েল েলা গেম খেলার সেই মনসপ্র্যময়টি পাঁচ জালন অবায় হহেলতম তবুরীজে দেক নাম ির ইয়া ফেসউুগের ধি ছিলা বিডিও ইংলিজ েএদেন কিকিবুজাইলে থেগেলাম।'}

# %%
num = x.index("rec_19_audio_31.wav")
num
# Out:
# 314

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)

# %%
quick_transcription = query(audio_path)
quick_transcription

# %% [markdown]
# # Making Dataframes

# %%
import pandas as pd

df = pd.DataFrame(list(zip(external_id, contents)), columns =['External_ID', 'Contents'])
df.head()
# Out:
#                 External_ID                                           Contents
# 0       rec_07_audio_20.wav                                                 <>
# 1  rec_06_small_audio_8.wav  তুনু কীমনে অনু বক্কার বাহিতোমার খুটি ভুরিটার ম...
# 2       rec_07_audio_25.wav  কুল উপুস্তি নিয়াই দিতি ে মুহম মিবেষটি অচ্ত চর...
# 3        rec_08_audio_8.wav  তৌৎস্বযামী তাকাইলাম মাহি যে ট রামী ধিকে যে তে ...
# 4       rec_10_audio_10.wav  চিন মা নামকিরকি হ্যা কয়েটাইতাপরহ্য টিয়েতিএ আক...

# %%
df
# Out:
#                     External_ID  \
# 0           rec_07_audio_20.wav
# 1      rec_06_small_audio_8.wav
# 2           rec_07_audio_25.wav
# 3            rec_08_audio_8.wav
# 4           rec_10_audio_10.wav
# ...                         ...
# 1316         rec_07_audio_1.wav
# 1317         rec_07_audio_0.wav
# 1318  rec_06_small_audio_16.wav
# 1319        rec_07_audio_13.wav
# 1320         rec_07_audio_8.wav
#
#                                                Contents
# 0                                                    <>
# 1     তুনু কীমনে অনু বক্কার বাহিতোমার খুটি ভুরিটার ম...
# 2     কুল উপুস্তি নিয়াই দিতি ে মুহম মিবেষটি অচ্ত চর...
# 3     তৌৎস্বযামী তাকাইলাম মাহি যে ট রামী ধিকে যে তে ...
# 4     চিন মা নামকিরকি হ্যা কয়েটাইতাপরহ্য টিয়েতিএ আক...
# ...                                                 ...
# 1316  প্রি অনবনতযের ক্যার ক্যাশ হটঅর্মী রহনী টি এবু ...
# 1317  ম ভাইস কিন কিন্দ্ না বানামডা তি থিটিয়েোদবর্তী...
# 1318  না়গুলোতানেতে আমরাত্তমনো অম্মহত্যবিত্তকে জর্মন...
# 1319  হল ভান্ডেটওয়াসে নয়লেখটি নিজ লাল উন্ুদ্দাহ ধপ...
# 1320  লাভ পাচতে তাকে তরমাণে পুরণ্ড বাইচ্া আাসর এটে ল...
#
# [1321 rows x 2 columns]

# %%
df.to_excel("/content/drive/MyDrive/local_speech/others/benchmarks_codes_and_models/4. bangla-wav2vec2-large-inference/4.6: Bangla-wav2vec2-tangail-inference.xlsx")
