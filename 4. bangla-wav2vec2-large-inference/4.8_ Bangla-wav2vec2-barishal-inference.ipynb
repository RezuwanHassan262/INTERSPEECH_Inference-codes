# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data_dir = '/content/drive/MyDrive/local_speech/Barishal/chunks/all/'

# %%
# !pip install audiosegment
import audiosegment
# Out:
# Collecting audiosegment
#   Downloading audiosegment-0.23.0-py3-none-any.whl (34 kB)
# Collecting pydub (from audiosegment)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting webrtcvad (from audiosegment)
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiosegment) (1.25.2)
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73472 sha256=9b5d5deeabc859dd6ea30e1c3c1385561d39bcf2c236cb9afb5f6a35a0ab790d
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built webrtcvad
# Installing collected packages: webrtcvad, pydub, audiosegment
# Successfully installed audiosegment-0.23.0 pydub-0.25.1 webrtcvad-2.0.10

# %%
import pandas as pd
from tqdm import tqdm
from glob import glob
import os
import librosa
tqdm.pandas()

# %%
x = os.listdir(data_dir)
x
# Out:
# ['rec_01_audio_59.wav',
#  'rec_01_audio_70.wav',
#  'rec_01_audio_66.wav',
#  'rec_01_audio_62.wav',
#  'rec_01_audio_68.wav',
#  'rec_01_audio_73.wav',
#  'rec_01_audio_71.wav',
#  'rec_01_audio_69.wav',
#  'rec_01_audio_60.wav',
#  'rec_01_audio_72.wav',
#  'rec_01_audio_61.wav',
#  'rec_01_audio_64.wav',
#  'rec_01_audio_75.wav',
#  'rec_01_audio_84.wav',
#  'rec_01_audio_77.wav',
#  'rec_01_audio_88.wav',
#  'rec_01_audio_82.wav',
#  'rec_01_audio_85.wav',
#  'rec_01_audio_80.wav',
#  'rec_01_audio_87.wav',
#  'rec_01_audio_78.wav',
#  'rec_01_audio_83.wav',
#  'rec_01_audio_81.wav',
#  'rec_01_audio_74.wav',
#  'rec_01_audio_89.wav',
#  'rec_01_audio_76.wav',
#  'rec_01_audio_79.wav',
#  'rec_01_audio_86.wav',
#  'rec_01_audio_92.wav',
#  'rec_01_audio_96.wav',
#  'rec_01_audio_94.wav',
#  'rec_01_audio_95.wav',
#  'rec_01_small_audio_0.wav',
#  'rec_01_audio_91.wav',
#  'rec_01_audio_98.wav',
#  'rec_01_audio_99.wav',
#  'rec_01_audio_93.wav',
#  'rec_01_audio_90.wav',
#  'rec_01_audio_97.wav',
#  'rec_02_audio_1.wav',
#  'rec_02_audio_2.wav',
#  'rec_02_audio_5.wav',
#  'rec_02_audio_3.wav',
#  'rec_02_audio_4.wav',
#  'rec_02_audio_0.wav',
#  'rec_02_audio_19.wav',
#  'rec_02_audio_14.wav',
#  'rec_02_audio_17.wav',
#  'rec_02_audio_10.wav',
#  'rec_02_audio_15.wav',
#  'rec_02_audio_13.wav',
#  'rec_02_audio_22.wav',
#  'rec_02_audio_8.wav',
#  'rec_02_audio_16.wav',
#  'rec_02_audio_20.wav',
#  'rec_02_audio_9.wav',
#  'rec_02_audio_7.wav',
#  'rec_02_audio_12.wav',
#  'rec_02_audio_11.wav',
#  'rec_02_audio_6.wav',
#  'rec_02_audio_18.wav',
#  'rec_02_audio_21.wav',
#  'rec_02_audio_30.wav',
#  'rec_02_audio_27.wav',
#  'rec_02_audio_23.wav',
#  'rec_02_audio_28.wav',
#  'rec_02_audio_26.wav',
#  'rec_02_audio_31.wav',
#  'rec_02_audio_29.wav',
#  'rec_02_audio_34.wav',
#  'rec_02_audio_36.wav',
#  'rec_02_audio_25.wav',
#  'rec_02_audio_24.wav',
#  'rec_02_audio_32.wav',
#  'rec_02_audio_35.wav',
#  'rec_02_audio_33.wav',
#  'rec_02_audio_37.wav',
#  'rec_03_small_audio_0.wav',
#  'rec_03_audio_5.wav',
#  'rec_03_audio_6.wav',
#  'rec_03_small_audio_1.wav',
#  'rec_03_audio_4.wav',
#  'rec_03_audio_2.wav',
#  'rec_03_audio_0.wav',
#  'rec_03_audio_1.wav',
#  'rec_03_big_audio_1.wav',
#  'rec_03_audio_3.wav',
#  'rec_03_big_audio_0.wav',
#  'rec_03_audio_13.wav',
#  'rec_03_audio_10.wav',
#  'rec_03_audio_9.wav',
#  'rec_03_audio_12.wav',
#  'rec_03_audio_18.wav',
#  'rec_03_audio_20.wav',
#  'rec_03_audio_19.wav',
#  'rec_03_audio_21.wav',
#  'rec_03_small_audio_2.wav',
#  'rec_03_audio_16.wav',
#  'rec_03_audio_17.wav',
#  'rec_03_audio_22.wav',
#  'rec_03_audio_7.wav',
#  'rec_03_audio_23.wav',
#  'rec_03_audio_14.wav',
#  'rec_03_audio_15.wav',
#  'rec_03_audio_8.wav',
#  'rec_03_audio_11.wav',
#  'rec_03_audio_35.wav',
#  'rec_03_audio_32.wav',
#  'rec_03_audio_34.wav',
#  'rec_03_audio_29.wav',
#  'rec_03_audio_27.wav',
#  'rec_03_audio_30.wav',
#  'rec_03_audio_38.wav',
#  'rec_03_audio_37.wav',
#  'rec_03_audio_26.wav',
#  'rec_03_audio_31.wav',
#  'rec_03_audio_39.wav',
#  'rec_03_audio_25.wav',
#  'rec_03_audio_40.wav',
#  'rec_03_audio_33.wav',
#  'rec_03_audio_36.wav',
#  'rec_03_audio_24.wav',
#  'rec_03_audio_28.wav',
#  'rec_03_audio_46.wav',
#  'rec_03_audio_51.wav',
#  'rec_03_audio_42.wav',
#  'rec_03_audio_44.wav',
#  'rec_03_audio_41.wav',
#  'rec_03_audio_47.wav',
#  'rec_03_audio_50.wav',
#  'rec_03_audio_48.wav',
#  'rec_03_audio_53.wav',
#  'rec_03_audio_52.wav',
#  'rec_03_audio_45.wav',
#  'rec_03_audio_43.wav',
#  'rec_03_small_audio_3.wav',
#  'rec_03_audio_49.wav',
#  'rec_03_audio_60.wav',
#  'rec_03_audio_58.wav',
#  'rec_03_audio_57.wav',
#  'rec_03_audio_61.wav',
#  'rec_03_audio_55.wav',
#  'rec_03_audio_62.wav',
#  'rec_03_audio_56.wav',
#  'rec_03_audio_54.wav',
#  'rec_03_audio_59.wav',
#  'rec_03_small_audio_4.wav',
#  'rec_03_audio_63.wav',
#  'rec_04_audio_6.wav',
#  'rec_04_audio_3.wav',
#  'rec_04_audio_12.wav',
#  'rec_04_audio_0.wav',
#  'rec_04_audio_9.wav',
#  'rec_04_audio_11.wav',
#  'rec_04_audio_5.wav',
#  'rec_04_audio_7.wav',
#  'rec_04_audio_4.wav',
#  'rec_04_audio_8.wav',
#  'rec_04_audio_13.wav',
#  'rec_04_audio_1.wav',
#  'rec_04_audio_10.wav',
#  'rec_04_audio_2.wav',
#  'rec_04_audio_36.wav',
#  'rec_04_audio_19.wav',
#  'rec_04_audio_33.wav',
#  'rec_04_audio_30.wav',
#  'rec_04_audio_34.wav',
#  'rec_04_audio_17.wav',
#  'rec_04_audio_28.wav',
#  'rec_04_audio_29.wav',
#  'rec_04_audio_23.wav',
#  'rec_04_audio_31.wav',
#  'rec_04_audio_32.wav',
#  'rec_04_audio_37.wav',
#  'rec_04_audio_14.wav',
#  'rec_04_audio_25.wav',
#  'rec_04_audio_16.wav',
#  'rec_04_audio_35.wav',
#  'rec_04_audio_21.wav',
#  'rec_04_audio_22.wav',
#  'rec_04_audio_20.wav',
#  'rec_04_audio_18.wav',
#  'rec_04_audio_26.wav',
#  'rec_04_audio_24.wav',
#  'rec_04_audio_15.wav',
#  'rec_04_audio_27.wav',
#  'rec_04_small_audio_0.wav',
#  'rec_04_audio_54.wav',
#  'rec_04_audio_51.wav',
#  'rec_04_audio_48.wav',
#  'rec_04_audio_57.wav',
#  'rec_04_audio_41.wav',
#  'rec_04_audio_44.wav',
#  'rec_04_audio_53.wav',
#  'rec_04_audio_40.wav',
#  'rec_04_audio_39.wav',
#  'rec_04_audio_56.wav',
#  'rec_04_audio_46.wav',
#  'rec_04_audio_38.wav',
#  'rec_04_audio_55.wav',
#  'rec_04_small_audio_1.wav',
#  'rec_04_audio_43.wav',
#  'rec_04_audio_52.wav',
#  'rec_04_audio_45.wav',
#  'rec_04_audio_49.wav',
#  'rec_04_audio_47.wav',
#  'rec_04_audio_50.wav',
#  'rec_04_audio_42.wav',
#  'rec_04_audio_62.wav',
#  'rec_04_audio_60.wav',
#  'rec_04_small_audio_3.wav',
#  'rec_04_audio_67.wav',
#  'rec_04_audio_58.wav',
#  'rec_04_audio_65.wav',
#  'rec_04_audio_59.wav',
#  'rec_04_small_audio_4.wav',
#  'rec_04_audio_64.wav',
#  'rec_04_audio_66.wav',
#  'rec_04_small_audio_2.wav',
#  'rec_04_audio_61.wav',
#  'rec_04_audio_78.wav',
#  'rec_04_audio_77.wav',
#  'rec_04_audio_70.wav',
#  'rec_04_audio_76.wav',
#  'rec_04_audio_71.wav',
#  'rec_04_audio_72.wav',
#  'rec_04_audio_75.wav',
#  'rec_04_audio_74.wav',
#  'rec_04_audio_73.wav',
#  'rec_04_audio_69.wav',
#  'rec_04_audio_79.wav',
#  'rec_04_audio_68.wav',
#  'rec_05_audio_3.wav',
#  'rec_05_audio_5.wav',
#  'rec_05_small_audio_0.wav',
#  'rec_05_audio_6.wav',
#  'rec_05_audio_10.wav',
#  'rec_05_audio_2.wav',
#  'rec_05_audio_7.wav',
#  'rec_05_audio_0.wav',
#  'rec_05_audio_9.wav',
#  'rec_05_audio_1.wav',
#  'rec_05_audio_4.wav',
#  'rec_05_audio_8.wav',
#  'rec_05_big_audio_1.wav',
#  'rec_05_big_audio_0.wav',
#  'rec_05_small_audio_3.wav',
#  'rec_05_audio_18.wav',
#  'rec_05_audio_16.wav',
#  'rec_05_audio_24.wav',
#  'rec_05_audio_25.wav',
#  'rec_05_small_audio_2.wav',
#  'rec_05_audio_14.wav',
#  'rec_05_audio_21.wav',
#  'rec_05_audio_13.wav',
#  'rec_05_audio_23.wav',
#  'rec_05_audio_20.wav',
#  'rec_05_small_audio_1.wav',
#  'rec_05_audio_26.wav',
#  'rec_05_audio_15.wav',
#  'rec_05_audio_11.wav',
#  'rec_05_audio_17.wav',
#  'rec_05_audio_19.wav',
#  'rec_05_audio_22.wav',
#  'rec_05_audio_12.wav',
#  'rec_06_audio_5.wav',
#  'rec_06_audio_3.wav',
#  'rec_06_audio_4.wav',
#  'rec_06_audio_0.wav',
#  'rec_06_audio_1.wav',
#  'rec_06_small_audio_1.wav',
#  'rec_06_audio_2.wav',
#  'rec_06_small_audio_0.wav',
#  'rec_06_audio_6.wav',
#  'rec_06_audio_7.wav',
#  'rec_07_audio_6.wav',
#  'rec_07_audio_7.wav',
#  'rec_07_audio_3.wav',
#  'rec_07_audio_5.wav',
#  'rec_07_audio_2.wav',
#  'rec_07_audio_0.wav',
#  'rec_07_audio_4.wav',
#  'rec_07_audio_9.wav',
#  'rec_07_audio_11.wav',
#  'rec_07_audio_10.wav',
#  'rec_07_audio_8.wav',
#  'rec_07_audio_1.wav',
#  'rec_08_small_audio_0.wav',
#  'rec_10_small_audio_0.wav',
#  'rec_10_audio_5.wav',
#  'rec_10_audio_6.wav',
#  'rec_10_audio_0.wav',
#  'rec_10_audio_1.wav',
#  'rec_10_audio_3.wav',
#  'rec_10_big_audio_0.wav',
#  'rec_10_audio_4.wav',
#  'rec_10_audio_2.wav',
#  'rec_11_audio_5.wav',
#  'rec_11_small_audio_0.wav',
#  'rec_11_audio_0.wav',
#  'rec_11_big_audio_0.wav',
#  'rec_11_audio_4.wav',
#  'rec_11_audio_1.wav',
#  'rec_11_big_audio_2.wav',
#  'rec_11_audio_2.wav',
#  'rec_11_audio_3.wav',
#  'rec_11_audio_10.wav',
#  'rec_11_audio_23.wav',
#  'rec_11_audio_19.wav',
#  'rec_11_audio_24.wav',
#  'rec_11_audio_6.wav',
#  'rec_11_audio_27.wav',
#  'rec_11_audio_7.wav',
#  'rec_11_audio_17.wav',
#  'rec_11_audio_30.wav',
#  'rec_11_small_audio_1.wav',
#  'rec_11_audio_16.wav',
#  'rec_11_audio_29.wav',
#  'rec_11_small_audio_3.wav',
#  'rec_11_audio_26.wav',
#  'rec_11_small_audio_2.wav',
#  'rec_11_audio_22.wav',
#  'rec_11_audio_25.wav',
#  'rec_11_audio_21.wav',
#  'rec_11_audio_15.wav',
#  'rec_11_audio_8.wav',
#  'rec_11_audio_14.wav',
#  'rec_11_audio_12.wav',
#  'rec_11_audio_20.wav',
#  'rec_11_audio_13.wav',
#  'rec_11_audio_28.wav',
#  'rec_11_audio_9.wav',
#  'rec_11_audio_18.wav',
#  'rec_11_audio_11.wav',
#  'rec_11_small_audio_4.wav',
#  'rec_11_audio_48.wav',
#  'rec_11_audio_47.wav',
#  'rec_11_audio_36.wav',
#  'rec_11_audio_41.wav',
#  'rec_11_audio_34.wav',
#  'rec_11_audio_35.wav',
#  'rec_11_audio_32.wav',
#  'rec_11_audio_43.wav',
#  'rec_11_audio_40.wav',
#  'rec_11_audio_50.wav',
#  'rec_11_audio_42.wav',
#  'rec_11_audio_44.wav',
#  'rec_11_audio_49.wav',
#  'rec_11_audio_39.wav',
#  'rec_11_audio_46.wav',
#  'rec_11_audio_38.wav',
#  'rec_11_audio_33.wav',
#  'rec_11_audio_31.wav',
#  'rec_11_audio_45.wav',
#  'rec_11_audio_37.wav',
#  'rec_11_audio_51.wav',
#  'rec_12_audio_4.wav',
#  'rec_12_audio_2.wav',
#  'rec_12_audio_6.wav',
#  'rec_12_audio_9.wav',
#  'rec_12_audio_10.wav',
#  'rec_12_audio_1.wav',
#  'rec_12_audio_8.wav',
#  'rec_12_audio_3.wav',
#  'rec_12_audio_11.wav',
#  'rec_12_audio_5.wav',
#  'rec_12_audio_0.wav',
#  'rec_12_audio_7.wav',
#  'rec_12_audio_17.wav',
#  'rec_12_audio_16.wav',
#  'rec_12_audio_29.wav',
#  'rec_12_audio_37.wav',
#  'rec_12_audio_26.wav',
#  'rec_12_audio_28.wav',
#  'rec_12_audio_21.wav',
#  'rec_12_audio_22.wav',
#  'rec_12_audio_23.wav',
#  'rec_12_audio_19.wav',
#  'rec_12_audio_36.wav',
#  'rec_12_audio_25.wav',
#  'rec_12_audio_35.wav',
#  'rec_12_audio_40.wav',
#  'rec_12_audio_34.wav',
#  'rec_12_audio_20.wav',
#  'rec_12_audio_12.wav',
#  'rec_12_audio_31.wav',
#  'rec_12_audio_24.wav',
#  'rec_12_audio_38.wav',
#  'rec_12_audio_15.wav',
#  'rec_12_audio_30.wav',
#  'rec_12_audio_13.wav',
#  'rec_12_audio_14.wav',
#  'rec_12_audio_27.wav',
#  'rec_12_audio_32.wav',
#  'rec_12_audio_33.wav',
#  'rec_12_audio_39.wav',
#  'rec_12_audio_18.wav',
#  'rec_12_audio_46.wav',
#  'rec_12_audio_41.wav',
#  'rec_12_audio_47.wav',
#  'rec_12_audio_50.wav',
#  'rec_12_audio_48.wav',
#  'rec_12_audio_49.wav',
#  'rec_12_audio_45.wav',
#  'rec_12_audio_44.wav',
#  'rec_12_audio_42.wav',
#  'rec_12_audio_43.wav',
#  'rec_14_audio_6.wav',
#  'rec_14_audio_7.wav',
#  'rec_14_audio_2.wav',
#  'rec_14_audio_5.wav',
#  'rec_14_audio_3.wav',
#  'rec_14_audio_0.wav',
#  'rec_14_audio_4.wav',
#  'rec_14_audio_1.wav',
#  'rec_14_audio_8.wav',
#  'rec_14_audio_15.wav',
#  'rec_14_audio_27.wav',
#  'rec_14_audio_16.wav',
#  'rec_14_audio_24.wav',
#  'rec_14_audio_19.wav',
#  'rec_14_audio_26.wav',
#  'rec_14_audio_14.wav',
#  'rec_14_audio_21.wav',
#  'rec_14_audio_17.wav',
#  'rec_14_audio_31.wav',
#  'rec_14_audio_13.wav',
#  'rec_14_audio_25.wav',
#  'rec_14_audio_28.wav',
#  'rec_14_audio_29.wav',
#  'rec_14_audio_10.wav',
#  'rec_14_audio_30.wav',
#  'rec_14_audio_18.wav',
#  'rec_14_audio_12.wav',
#  'rec_14_audio_22.wav',
#  'rec_14_audio_23.wav',
#  'rec_14_audio_11.wav',
#  'rec_14_audio_20.wav',
#  'rec_15_audio_5.wav',
#  'rec_15_audio_0.wav',
#  'rec_15_audio_1.wav',
#  'rec_15_audio_4.wav',
#  'rec_15_audio_2.wav',
#  'rec_15_audio_7.wav',
#  'rec_15_small_audio_0.wav',
#  'rec_15_audio_6.wav',
#  'rec_15_audio_3.wav',
#  'rec_16_big_audio_2.wav',
#  'rec_16_audio_1.wav',
#  'rec_16_big_audio_1.wav',
#  'rec_16_audio_0.wav',
#  'rec_16_audio_13.wav',
#  'rec_16_audio_4.wav',
#  'rec_16_audio_5.wav',
#  'rec_16_audio_24.wav',
#  'rec_16_audio_7.wav',
#  'rec_16_audio_23.wav',
#  'rec_16_audio_15.wav',
#  'rec_16_audio_22.wav',
#  'rec_16_audio_20.wav',
#  'rec_16_audio_11.wav',
#  'rec_16_audio_25.wav',
#  'rec_16_audio_9.wav',
#  'rec_16_audio_27.wav',
#  'rec_16_audio_14.wav',
#  'rec_16_audio_12.wav',
#  'rec_16_audio_3.wav',
#  'rec_16_audio_16.wav',
#  'rec_16_audio_26.wav',
#  'rec_16_audio_10.wav',
#  'rec_16_audio_21.wav',
#  'rec_16_audio_2.wav',
#  'rec_16_audio_8.wav',
#  'rec_16_audio_6.wav',
#  'rec_16_audio_18.wav',
#  'rec_16_audio_17.wav',
#  'rec_16_audio_19.wav',
#  'rec_16_audio_52.wav',
#  'rec_16_audio_47.wav',
#  'rec_16_audio_32.wav',
#  'rec_16_audio_38.wav',
#  'rec_16_audio_56.wav',
#  'rec_16_audio_40.wav',
#  'rec_16_audio_35.wav',
#  'rec_16_audio_29.wav',
#  'rec_16_audio_37.wav',
#  'rec_16_audio_55.wav',
#  'rec_16_audio_58.wav',
#  'rec_16_audio_46.wav',
#  'rec_16_audio_54.wav',
#  'rec_16_audio_49.wav',
#  'rec_16_audio_43.wav',
#  'rec_16_audio_36.wav',
#  'rec_16_audio_48.wav',
#  'rec_16_audio_50.wav',
#  'rec_16_audio_41.wav',
#  'rec_16_audio_39.wav',
#  'rec_16_audio_57.wav',
#  'rec_16_audio_53.wav',
#  'rec_16_audio_59.wav',
#  'rec_16_audio_31.wav',
#  'rec_16_audio_45.wav',
#  'rec_16_audio_42.wav',
#  'rec_16_audio_34.wav',
#  'rec_16_audio_33.wav',
#  'rec_16_audio_28.wav',
#  'rec_16_audio_30.wav',
#  'rec_16_audio_44.wav',
#  'rec_16_audio_51.wav',
#  'rec_16_audio_62.wav',
#  'rec_16_audio_77.wav',
#  'rec_16_audio_81.wav',
#  'rec_16_audio_79.wav',
#  'rec_16_audio_75.wav',
#  'rec_16_audio_65.wav',
#  'rec_16_audio_69.wav',
#  'rec_16_audio_61.wav',
#  'rec_16_audio_83.wav',
#  'rec_16_audio_72.wav',
#  'rec_16_audio_82.wav',
#  'rec_16_audio_63.wav',
#  'rec_16_audio_70.wav',
#  'rec_16_audio_66.wav',
#  'rec_16_audio_80.wav',
#  'rec_16_audio_67.wav',
#  'rec_16_audio_60.wav',
#  'rec_16_audio_68.wav',
#  'rec_16_audio_64.wav',
#  'rec_16_audio_73.wav',
#  'rec_16_audio_78.wav',
#  'rec_16_audio_71.wav',
#  'rec_16_audio_76.wav',
#  'rec_16_audio_74.wav',
#  'rec_16_audio_87.wav',
#  'rec_16_small_audio_0.wav',
#  'rec_16_audio_92.wav',
#  'rec_16_audio_86.wav',
#  'rec_16_audio_91.wav',
#  'rec_16_audio_89.wav',
#  'rec_16_audio_93.wav',
#  'rec_16_audio_85.wav',
#  'rec_16_audio_90.wav',
#  'rec_16_audio_84.wav',
#  'rec_16_audio_88.wav',
#  'rec_17_audio_6.wav',
#  'rec_17_audio_11.wav',
#  'rec_17_audio_1.wav',
#  'rec_17_audio_3.wav',
#  'rec_17_audio_2.wav',
#  'rec_17_audio_4.wav',
#  'rec_17_audio_5.wav',
#  'rec_17_audio_10.wav',
#  'rec_17_audio_8.wav',
#  'rec_17_audio_7.wav',
#  'rec_17_audio_0.wav',
#  'rec_17_small_audio_0.wav',
#  'rec_17_audio_9.wav',
#  'rec_18_audio_0.wav',
#  'rec_18_audio_13.wav',
#  'rec_18_audio_11.wav',
#  'rec_18_audio_18.wav',
#  'rec_18_audio_9.wav',
#  'rec_18_audio_16.wav',
#  'rec_18_audio_17.wav',
#  'rec_18_small_audio_0.wav',
#  'rec_18_audio_14.wav',
#  'rec_18_audio_12.wav',
#  'rec_18_audio_2.wav',
#  'rec_18_audio_1.wav',
#  'rec_18_audio_15.wav',
#  'rec_18_audio_3.wav',
#  'rec_18_audio_10.wav',
#  'rec_18_audio_5.wav',
#  'rec_18_audio_6.wav',
#  'rec_18_audio_8.wav',
#  'rec_18_audio_4.wav',
#  'rec_18_audio_7.wav',
#  'rec_18_audio_23.wav',
#  'rec_18_audio_22.wav',
#  'rec_18_audio_20.wav',
#  'rec_18_audio_24.wav',
#  'rec_18_audio_19.wav',
#  'rec_18_audio_21.wav',
#  'rec_19_audio_13.wav',
#  'rec_19_big_audio_0.wav',
#  'rec_19_audio_2.wav',
#  'rec_19_audio_6.wav',
#  'rec_19_audio_12.wav',
#  'rec_19_audio_0.wav',
#  'rec_19_audio_9.wav',
#  'rec_19_audio_3.wav',
#  'rec_19_audio_8.wav',
#  'rec_19_audio_7.wav',
#  'rec_19_audio_11.wav',
#  'rec_19_audio_4.wav',
#  'rec_19_audio_1.wav',
#  'rec_19_audio_5.wav',
#  'rec_19_audio_10.wav',
#  'rec_19_audio_23.wav',
#  'rec_19_audio_17.wav',
#  'rec_19_audio_31.wav',
#  'rec_19_audio_32.wav',
#  'rec_19_audio_38.wav',
#  'rec_19_audio_33.wav',
#  'rec_19_audio_34.wav',
#  'rec_19_audio_30.wav',
#  'rec_19_audio_25.wav',
#  'rec_19_audio_19.wav',
#  'rec_19_audio_22.wav',
#  'rec_19_audio_26.wav',
#  'rec_19_audio_28.wav',
#  'rec_19_audio_24.wav',
#  'rec_19_audio_21.wav',
#  'rec_19_audio_15.wav',
#  'rec_19_audio_20.wav',
#  'rec_19_audio_35.wav',
#  'rec_19_audio_37.wav',
#  'rec_19_audio_14.wav',
#  'rec_19_audio_27.wav',
#  'rec_19_audio_18.wav',
#  'rec_19_audio_16.wav',
#  'rec_19_audio_36.wav',
#  'rec_19_audio_29.wav',
#  'rec_19_audio_52.wav',
#  'rec_19_audio_51.wav',
#  'rec_19_audio_58.wav',
#  'rec_19_audio_45.wav',
#  'rec_19_small_audio_0.wav',
#  'rec_19_audio_63.wav',
#  'rec_19_audio_56.wav',
#  'rec_19_audio_44.wav',
#  'rec_19_audio_57.wav',
#  'rec_19_audio_60.wav',
#  'rec_19_audio_49.wav',
#  'rec_19_audio_40.wav',
#  'rec_19_audio_62.wav',
#  'rec_19_audio_47.wav',
#  'rec_19_audio_42.wav',
#  'rec_19_audio_46.wav',
#  'rec_19_audio_54.wav',
#  'rec_19_audio_39.wav',
#  'rec_19_audio_48.wav',
#  'rec_19_audio_41.wav',
#  'rec_19_audio_61.wav',
#  'rec_19_audio_43.wav',
#  'rec_19_audio_50.wav',
#  'rec_19_audio_59.wav',
#  'rec_19_audio_53.wav',
#  'rec_19_audio_55.wav',
#  'rec_19_audio_65.wav',
#  'rec_19_audio_76.wav',
#  'rec_19_audio_70.wav',
#  'rec_19_audio_68.wav',
#  'rec_19_audio_69.wav',
#  'rec_19_small_audio_1.wav',
#  'rec_19_audio_67.wav',
#  'rec_19_audio_66.wav',
#  'rec_19_audio_74.wav',
#  'rec_19_audio_73.wav',
#  'rec_19_audio_72.wav',
#  'rec_19_audio_75.wav',
#  'rec_19_audio_64.wav',
#  'rec_19_audio_77.wav',
#  'rec_19_audio_71.wav',
#  'rec_20_audio_8.wav',
#  'rec_20_audio_7.wav',
#  'rec_20_audio_9.wav',
#  'rec_20_audio_6.wav',
#  'rec_20_audio_1.wav',
#  'rec_20_audio_3.wav',
#  'rec_20_big_audio_0.wav',
#  'rec_20_audio_10.wav',
#  'rec_20_audio_5.wav',
#  'rec_20_audio_2.wav',
#  'rec_20_audio_4.wav',
#  'rec_20_audio_0.wav',
#  'rec_20_audio_17.wav',
#  'rec_20_audio_28.wav',
#  'rec_20_audio_19.wav',
#  'rec_20_audio_14.wav',
#  'rec_20_audio_20.wav',
#  'rec_20_audio_24.wav',
#  'rec_20_audio_22.wav',
#  'rec_20_audio_29.wav',
#  'rec_20_audio_26.wav',
#  'rec_20_audio_13.wav',
#  'rec_20_audio_16.wav',
#  'rec_20_audio_23.wav',
#  'rec_20_audio_18.wav',
#  'rec_20_audio_12.wav',
#  'rec_20_audio_15.wav',
#  'rec_20_audio_27.wav',
#  'rec_20_audio_21.wav',
#  'rec_20_audio_11.wav',
#  'rec_20_audio_25.wav',
#  'rec_20_audio_53.wav',
#  'rec_20_audio_33.wav',
#  'rec_20_audio_42.wav',
#  'rec_20_audio_36.wav',
#  'rec_20_audio_49.wav',
#  'rec_20_audio_30.wav',
#  'rec_20_audio_48.wav',
#  'rec_20_audio_46.wav',
#  'rec_20_audio_54.wav',
#  'rec_20_audio_45.wav',
#  'rec_20_audio_32.wav',
#  'rec_20_audio_41.wav',
#  'rec_20_audio_52.wav',
#  'rec_20_audio_44.wav',
#  'rec_20_audio_43.wav',
#  'rec_20_small_audio_0.wav',
#  'rec_20_audio_47.wav',
#  'rec_20_audio_34.wav',
#  'rec_20_audio_55.wav',
#  'rec_20_audio_50.wav',
#  'rec_20_audio_56.wav',
#  'rec_20_audio_31.wav',
#  'rec_20_audio_40.wav',
#  'rec_20_audio_37.wav',
#  'rec_20_audio_57.wav',
#  'rec_20_audio_35.wav',
#  'rec_20_audio_51.wav',
#  'rec_20_audio_38.wav',
#  'rec_20_audio_39.wav',
#  'rec_20_small_audio_1.wav',
#  'rec_20_audio_64.wav',
#  'rec_20_audio_58.wav',
#  'rec_20_audio_63.wav',
#  'rec_20_audio_66.wav',
#  'rec_20_audio_65.wav',
#  'rec_20_audio_61.wav',
#  'rec_20_audio_62.wav',
#  'rec_20_audio_59.wav',
#  'rec_20_audio_60.wav',
#  'rec_21_audio_6.wav',
#  'rec_21_audio_5.wav',
#  'rec_21_audio_13.wav',
#  'rec_21_small_audio_0.wav',
#  'rec_21_audio_8.wav',
#  'rec_21_audio_7.wav',
#  'rec_21_audio_10.wav',
#  'rec_21_audio_1.wav',
#  'rec_21_audio_15.wav',
#  'rec_21_audio_3.wav',
#  'rec_21_audio_2.wav',
#  'rec_21_audio_4.wav',
#  'rec_21_audio_11.wav',
#  'rec_21_audio_17.wav',
#  'rec_21_audio_16.wav',
#  'rec_21_audio_12.wav',
#  'rec_21_audio_14.wav',
#  'rec_21_audio_0.wav',
#  'rec_21_audio_9.wav',
#  'rec_21_audio_38.wav',
#  'rec_21_audio_20.wav',
#  'rec_21_audio_21.wav',
#  'rec_21_audio_19.wav',
#  'rec_21_audio_30.wav',
#  'rec_21_audio_32.wav',
#  'rec_21_audio_39.wav',
#  'rec_21_audio_26.wav',
#  'rec_21_audio_27.wav',
#  'rec_21_audio_43.wav',
#  'rec_21_audio_34.wav',
#  'rec_21_audio_24.wav',
#  'rec_21_audio_23.wav',
#  'rec_21_audio_41.wav',
#  'rec_21_audio_31.wav',
#  'rec_21_audio_42.wav',
#  'rec_21_audio_40.wav',
#  'rec_21_audio_25.wav',
#  'rec_21_audio_36.wav',
#  'rec_21_audio_33.wav',
#  'rec_21_audio_35.wav',
#  'rec_21_audio_37.wav',
#  'rec_21_audio_18.wav',
#  'rec_21_audio_28.wav',
#  'rec_21_audio_29.wav',
#  'rec_21_audio_22.wav',
#  'rec_21_audio_44.wav',
#  'rec_21_audio_50.wav',
#  'rec_21_audio_51.wav',
#  'rec_21_audio_53.wav',
#  'rec_21_audio_45.wav',
#  'rec_21_audio_54.wav',
#  'rec_21_audio_48.wav',
#  'rec_21_audio_49.wav',
#  'rec_21_audio_47.wav',
#  'rec_21_audio_56.wav',
#  'rec_21_audio_55.wav',
#  'rec_21_audio_46.wav',
#  'rec_21_audio_52.wav',
#  'rec_22_audio_6.wav',
#  'rec_22_audio_7.wav',
#  'rec_22_audio_5.wav',
#  'rec_22_audio_1.wav',
#  'rec_22_audio_8.wav',
#  'rec_22_audio_2.wav',
#  'rec_22_audio_9.wav',
#  'rec_22_audio_4.wav',
#  'rec_22_audio_0.wav',
#  'rec_22_big_audio_0.wav',
#  'rec_22_audio_3.wav',
#  'rec_22_audio_12.wav',
#  'rec_22_audio_18.wav',
#  'rec_22_audio_21.wav',
#  'rec_22_audio_30.wav',
#  'rec_22_audio_22.wav',
#  'rec_22_audio_28.wav',
#  'rec_22_audio_20.wav',
#  'rec_22_audio_35.wav',
#  'rec_22_audio_23.wav',
#  'rec_22_audio_33.wav',
#  'rec_22_audio_11.wav',
#  'rec_22_audio_31.wav',
#  'rec_22_small_audio_1.wav',
#  'rec_22_audio_10.wav',
#  'rec_22_audio_14.wav',
#  'rec_22_audio_34.wav',
#  'rec_22_audio_19.wav',
#  'rec_22_audio_24.wav',
#  'rec_22_audio_13.wav',
#  'rec_22_audio_32.wav',
#  'rec_22_audio_26.wav',
#  'rec_22_audio_27.wav',
#  'rec_22_audio_15.wav',
#  'rec_22_small_audio_0.wav',
#  'rec_22_audio_25.wav',
#  'rec_22_audio_16.wav',
#  'rec_22_audio_36.wav',
#  'rec_22_audio_17.wav',
#  'rec_22_audio_29.wav',
#  'rec_22_audio_50.wav',
#  'rec_22_audio_56.wav',
#  'rec_22_audio_54.wav',
#  'rec_22_audio_38.wav',
#  'rec_22_audio_47.wav',
#  'rec_22_audio_42.wav',
#  'rec_22_audio_57.wav',
#  'rec_22_audio_59.wav',
#  'rec_22_audio_45.wav',
#  'rec_22_audio_48.wav',
#  'rec_22_audio_43.wav',
#  'rec_22_audio_40.wav',
#  'rec_22_audio_46.wav',
#  'rec_22_audio_51.wav',
#  'rec_22_audio_37.wav',
#  'rec_22_audio_53.wav',
#  'rec_22_audio_39.wav',
#  'rec_22_audio_41.wav',
#  'rec_22_audio_58.wav',
#  'rec_22_audio_52.wav',
#  'rec_22_audio_49.wav',
#  'rec_22_audio_44.wav',
#  'rec_22_audio_55.wav',
#  'rec_23_audio_0.wav',
#  'rec_23_audio_2.wav',
#  'rec_23_audio_1.wav',
#  'rec_23_audio_3.wav',
#  'rec_24_audio_4.wav',
#  'rec_24_audio_2.wav',
#  'rec_24_audio_0.wav',
#  'rec_24_audio_1.wav',
#  'rec_24_audio_3.wav',
#  'rec_24_audio_6.wav',
#  'rec_24_audio_21.wav',
#  'rec_24_audio_23.wav',
#  'rec_24_audio_12.wav',
#  'rec_24_audio_9.wav',
#  'rec_24_audio_5.wav',
#  'rec_24_audio_18.wav',
#  'rec_24_audio_15.wav',
#  'rec_24_audio_13.wav',
#  'rec_24_audio_19.wav',
#  'rec_24_audio_24.wav',
#  'rec_24_audio_7.wav',
#  'rec_24_audio_26.wav',
#  'rec_24_audio_14.wav',
#  'rec_24_audio_16.wav',
#  'rec_24_audio_22.wav',
#  'rec_24_audio_27.wav',
#  'rec_24_audio_8.wav',
#  'rec_24_audio_20.wav',
#  'rec_24_audio_17.wav',
#  'rec_24_audio_11.wav',
#  'rec_24_audio_10.wav',
#  'rec_24_audio_25.wav',
#  'rec_24_audio_45.wav',
#  'rec_24_audio_49.wav',
#  'rec_24_audio_58.wav',
#  'rec_24_audio_48.wav',
#  'rec_24_audio_54.wav',
#  'rec_24_audio_39.wav',
#  'rec_24_audio_41.wav',
#  'rec_24_audio_44.wav',
#  'rec_24_audio_38.wav',
#  'rec_24_audio_43.wav',
#  'rec_24_audio_32.wav',
#  'rec_24_audio_60.wav',
#  'rec_24_audio_56.wav',
#  'rec_24_audio_35.wav',
#  'rec_24_audio_50.wav',
#  'rec_24_audio_37.wav',
#  'rec_24_audio_36.wav',
#  'rec_24_audio_59.wav',
#  'rec_24_audio_51.wav',
#  'rec_24_audio_40.wav',
#  'rec_24_audio_28.wav',
#  'rec_24_audio_55.wav',
#  'rec_24_audio_53.wav',
#  'rec_24_audio_52.wav',
#  'rec_24_audio_30.wav',
#  'rec_24_audio_57.wav',
#  'rec_24_audio_34.wav',
#  'rec_24_audio_42.wav',
#  'rec_24_audio_31.wav',
#  'rec_24_audio_47.wav',
#  'rec_24_audio_46.wav',
#  'rec_24_audio_33.wav',
#  'rec_24_audio_29.wav',
#  'rec_24_audio_76.wav',
#  'rec_24_audio_73.wav',
#  'rec_24_audio_77.wav',
#  'rec_24_audio_67.wav',
#  'rec_24_audio_80.wav',
#  'rec_24_audio_63.wav',
#  'rec_24_audio_68.wav',
#  'rec_24_audio_71.wav',
#  'rec_24_audio_69.wav',
#  'rec_24_audio_64.wav',
#  'rec_24_audio_74.wav',
#  'rec_24_audio_78.wav',
#  'rec_24_audio_66.wav',
#  'rec_24_audio_84.wav',
#  'rec_24_audio_83.wav',
#  'rec_24_audio_61.wav',
#  'rec_24_audio_75.wav',
#  'rec_24_audio_65.wav',
#  'rec_24_audio_79.wav',
#  'rec_24_audio_82.wav',
#  'rec_24_audio_62.wav',
#  'rec_24_audio_81.wav',
#  'rec_24_audio_70.wav',
#  'rec_24_audio_72.wav',
#  'rec_24_audio_95.wav',
#  'rec_24_audio_96.wav',
#  'rec_24_audio_94.wav',
#  'rec_24_audio_89.wav',
#  'rec_24_audio_87.wav',
#  'rec_24_audio_91.wav',
#  'rec_24_audio_86.wav',
#  'rec_24_audio_93.wav',
#  'rec_24_audio_88.wav',
#  'rec_24_audio_92.wav',
#  'rec_24_audio_90.wav',
#  'rec_24_audio_85.wav',
#  'rec_24_small_audio_0.wav',
#  'rec_25_audio_8.wav',
#  'rec_25_audio_7.wav',
#  'rec_25_audio_1.wav',
#  'rec_25_audio_0.wav',
#  'rec_25_audio_4.wav',
#  'rec_25_audio_9.wav',
#  'rec_25_audio_11.wav',
#  'rec_25_audio_2.wav',
#  'rec_25_audio_12.wav',
#  'rec_25_audio_5.wav',
#  'rec_25_small_audio_0.wav',
#  'rec_25_audio_10.wav',
#  'rec_25_audio_6.wav',
#  'rec_25_audio_3.wav',
#  'rec_26_audio_2.wav',
#  'rec_26_audio_0.wav',
#  'rec_26_audio_3.wav',
#  'rec_26_audio_4.wav',
#  'rec_26_audio_5.wav',
#  'rec_26_audio_1.wav',
#  'rec_26_audio_6.wav',
#  'rec_26_audio_10.wav',
#  'rec_26_audio_9.wav',
#  'rec_26_audio_8.wav',
#  'rec_26_audio_7.wav',
#  'rec_06_big_audio_0_chunk_0.wav',
#  'rec_05_big_audio_2_chunk_0.wav',
#  'rec_05_big_audio_2_chunk_2.wav',
#  'rec_05_big_audio_2_chunk_1.wav',
#  'rec_14_big_audio_0_chunk_1.wav',
#  'rec_11_big_audio_1_chunk_0.wav',
#  'rec_16_big_audio_0_chunk_1.wav',
#  'rec_14_big_audio_0_chunk_0.wav',
#  'rec_16_big_audio_0_chunk_0.wav',
#  'rec_16_big_audio_3_chunk_0.wav',
#  'rec_16_big_audio_3_chunk_1.wav',
#  'rec_11_big_audio_1_chunk_1.wav',
#  'rec_06_big_audio_0_chunk_1.wav',
#  'rec_20_big_audio_1_chunk_0.wav',
#  'rec_04_audio_63_chunk_1.wav',
#  'rec_14_audio_9_chunk_1.wav',
#  'rec_04_audio_63_chunk_0.wav',
#  'rec_14_audio_9_chunk_0.wav',
#  ...]

# %%
len(x)
# Out:
# 1062

# %%
aud = x.index("rec_01_audio_0.wav")
aud
# Out:
# 1004

# %%
audio_path = f"{data_dir}{x[aud]}"
audio_path
# Out:
# '/content/drive/MyDrive/local_speech/Barishal/chunks/all/rec_01_audio_0.wav'

# %% [markdown]
# # Bangla Wav2Vec2-large

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/auditi41/wav2vec2-large-xlsr-53-Bangla"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# %%
external_id = []
contents = []
errors = []
c = 0
#c&i = []

def once(output,i):

    external_id.append(i)

    if len(output['text']) == 0:
        contents.append("<>")
    else:
        contents.append(output['text'])


def again(audio,i):

    global c

    try:
        output = query(audio)

        if 'error' in output.keys():
            if c != 5:
                c += 1
                again(audio)
            else:
                c = 0
                external_id.append(i)
                contents.append("<>")
                pass
        else:
            once(output,i)


    except Exception as e:
        again(audio,i)


for i in x:

    audio = f"{data_dir}{i}"


    try:
        output = query(audio,i)
        once(output)

    except:
        again(audio,i)

# %%
print(errors)
print()
print(len(errors))
# Out:
# []
#
# 0

# %%
print(external_id)
print()
print(len(external_id))
print()
print("=======================")
print()
print(contents)
print()
print(len(contents))
# Out:
# ['rec_01_audio_59.wav', 'rec_01_audio_70.wav', 'rec_01_audio_66.wav', 'rec_01_audio_62.wav', 'rec_01_audio_68.wav', 'rec_01_audio_73.wav', 'rec_01_audio_71.wav', 'rec_01_audio_69.wav', 'rec_01_audio_60.wav', 'rec_01_audio_72.wav', 'rec_01_audio_61.wav', 'rec_01_audio_64.wav', 'rec_01_audio_75.wav', 'rec_01_audio_84.wav', 'rec_01_audio_77.wav', 'rec_01_audio_88.wav', 'rec_01_audio_82.wav', 'rec_01_audio_85.wav', 'rec_01_audio_80.wav', 'rec_01_audio_87.wav', 'rec_01_audio_78.wav', 'rec_01_audio_83.wav', 'rec_01_audio_81.wav', 'rec_01_audio_74.wav', 'rec_01_audio_89.wav', 'rec_01_audio_76.wav', 'rec_01_audio_79.wav', 'rec_01_audio_86.wav', 'rec_01_audio_92.wav', 'rec_01_audio_96.wav', 'rec_01_audio_94.wav', 'rec_01_audio_95.wav', 'rec_01_small_audio_0.wav', 'rec_01_audio_91.wav', 'rec_01_audio_98.wav', 'rec_01_audio_99.wav', 'rec_01_audio_93.wav', 'rec_01_audio_90.wav', 'rec_01_audio_97.wav', 'rec_02_audio_1.wav', 'rec_02_audio_2.wav', 'rec_02_audio_5.wav', 'rec_02_audio_3.wav', 'rec_02_audio_4.wav', 'rec_02_audio_0.wav', 'rec_02_audio_19.wav', 'rec_02_audio_14.wav', 'rec_02_audio_17.wav', 'rec_02_audio_10.wav', 'rec_02_audio_15.wav', 'rec_02_audio_13.wav', 'rec_02_audio_22.wav', 'rec_02_audio_8.wav', 'rec_02_audio_16.wav', 'rec_02_audio_20.wav', 'rec_02_audio_9.wav', 'rec_02_audio_7.wav', 'rec_02_audio_12.wav', 'rec_02_audio_11.wav', 'rec_02_audio_6.wav', 'rec_02_audio_18.wav', 'rec_02_audio_21.wav', 'rec_02_audio_30.wav', 'rec_02_audio_27.wav', 'rec_02_audio_23.wav', 'rec_02_audio_28.wav', 'rec_02_audio_26.wav', 'rec_02_audio_31.wav', 'rec_02_audio_29.wav', 'rec_02_audio_34.wav', 'rec_02_audio_36.wav', 'rec_02_audio_25.wav', 'rec_02_audio_24.wav', 'rec_02_audio_32.wav', 'rec_02_audio_35.wav', 'rec_02_audio_33.wav', 'rec_02_audio_37.wav', 'rec_03_small_audio_0.wav', 'rec_03_audio_5.wav', 'rec_03_audio_6.wav', 'rec_03_small_audio_1.wav', 'rec_03_audio_4.wav', 'rec_03_audio_2.wav', 'rec_03_audio_0.wav', 'rec_03_audio_1.wav', 'rec_03_big_audio_1.wav', 'rec_03_audio_3.wav', 'rec_03_big_audio_0.wav', 'rec_03_audio_13.wav', 'rec_03_audio_10.wav', 'rec_03_audio_9.wav', 'rec_03_audio_12.wav', 'rec_03_audio_18.wav', 'rec_03_audio_20.wav', 'rec_03_audio_19.wav', 'rec_03_audio_21.wav', 'rec_03_small_audio_2.wav', 'rec_03_audio_16.wav', 'rec_03_audio_17.wav', 'rec_03_audio_22.wav', 'rec_03_audio_7.wav', 'rec_03_audio_23.wav', 'rec_03_audio_14.wav', 'rec_03_audio_15.wav', 'rec_03_audio_8.wav', 'rec_03_audio_11.wav', 'rec_03_audio_35.wav', 'rec_03_audio_32.wav', 'rec_03_audio_34.wav', 'rec_03_audio_29.wav', 'rec_03_audio_27.wav', 'rec_03_audio_30.wav', 'rec_03_audio_38.wav', 'rec_03_audio_37.wav', 'rec_03_audio_26.wav', 'rec_03_audio_31.wav', 'rec_03_audio_39.wav', 'rec_03_audio_25.wav', 'rec_03_audio_40.wav', 'rec_03_audio_33.wav', 'rec_03_audio_36.wav', 'rec_03_audio_24.wav', 'rec_03_audio_28.wav', 'rec_03_audio_46.wav', 'rec_03_audio_51.wav', 'rec_03_audio_42.wav', 'rec_03_audio_44.wav', 'rec_03_audio_41.wav', 'rec_03_audio_47.wav', 'rec_03_audio_50.wav', 'rec_03_audio_48.wav', 'rec_03_audio_53.wav', 'rec_03_audio_52.wav', 'rec_03_audio_45.wav', 'rec_03_audio_43.wav', 'rec_03_small_audio_3.wav', 'rec_03_audio_49.wav', 'rec_03_audio_60.wav', 'rec_03_audio_58.wav', 'rec_03_audio_57.wav', 'rec_03_audio_61.wav', 'rec_03_audio_55.wav', 'rec_03_audio_62.wav', 'rec_03_audio_56.wav', 'rec_03_audio_54.wav', 'rec_03_audio_59.wav', 'rec_03_small_audio_4.wav', 'rec_03_audio_63.wav', 'rec_04_audio_6.wav', 'rec_04_audio_3.wav', 'rec_04_audio_12.wav', 'rec_04_audio_0.wav', 'rec_04_audio_9.wav', 'rec_04_audio_11.wav', 'rec_04_audio_5.wav', 'rec_04_audio_7.wav', 'rec_04_audio_4.wav', 'rec_04_audio_8.wav', 'rec_04_audio_13.wav', 'rec_04_audio_1.wav', 'rec_04_audio_10.wav', 'rec_04_audio_2.wav', 'rec_04_audio_36.wav', 'rec_04_audio_19.wav', 'rec_04_audio_33.wav', 'rec_04_audio_30.wav', 'rec_04_audio_34.wav', 'rec_04_audio_17.wav', 'rec_04_audio_28.wav', 'rec_04_audio_29.wav', 'rec_04_audio_23.wav', 'rec_04_audio_31.wav', 'rec_04_audio_32.wav', 'rec_04_audio_ ...
#
# 1062
#
# =======================
#
# ['<>', '<>', '<>', '<>', '<>', '<>', 'কঠট আমার জায়া আছে আমি দিকে ভালোপার ধীরে শিক্তেবার্ধ রারমান ইন্চেশ চাখি দিটে কাশিনুসে অনু হয়ে সামনা চললে আমি ভালোজাগার় য়তবার মানুষেও কি আসে নাই ওদিকচামারণটা দেতু হরোনাম আমার জা আছে সেট আমা দে আাছে উটে ভলো কর জিদে অনে নাচচার করেন।', 'তার উপা কার্ধীনে করিটিসগুলো গুমকরলে ত্যারাদেশের স যোগষলা তার আকশে হয় আরা আমীধিতে আমার কলচিতগুলো গুমিকুরকার  যোগখরিতে ত্যালদের একশ কিন্তু পার্থকো পন্যে কার তার দিকে একা এটা আমান আমাজিট এছে তারও জালিআমাদের শবেরে ক্োম্বেশি থাকবেধি বেসে কম্বেশি থাত বে় বাল য়এদে।', 'নিজের কাছ খােলা পোলার ছিল বা আগে এখনার পুন ও খারাবলা গেলায্ে ওয়েকটা ভাবযারাজে আছে হযওয়েরটটাধি ঘাডোযয়়া পরেসে আল্লা উকে একটা ইধিনে এই উপুলার খালাতালা উকে ভালচারাআইনসেইদেন টি সব্তেয় সুযামে চিন্দেভাবনার করি বার।', 'ন্নে ধোলাদাধীতে ভালতকার মে মানের সংবাগামে ম্বলো চর্চফোরণ উঁচলগী করে ক্যালিডা এটা ফুন্ ধররেরভালো কলে ফর হবে ভাবো রোজর বহর মানু শেট্রদেখ্ছ দিতে হনে আশাহল্যানের কান দি তার ফুল ফল ঢেকে ট্রাম দীয়ে তালাতা আতারলেতে আমারার।', 'এখন দি জিনিৎ্টা দিপ্রেণ করে ফলায়সিযে আমি সবসয নিজের দিকটা দেশে এখনা মানুষের মারস কিনি রাবিন আগে একটা সনায় এ ভার্চৃতিতব উঁকে অনে ইবাঘে এমা বামমানুষ কেনের মাথ ভিনাতামে আমারখী ন হয়াভাবে আমি ভাবেযে সং্ধ্ধা নিয় ্যমানে।', 'হথেওথে এটিআমার কষেতআমারঘেতে আমি কারওয় ছোথো নিজিকে ছোট দেখি নিকেন দেয়ে করথা যসেবা সে তাইন দিসে সেে কষ্টযকর্থে ষবে ভাল লেখোর পারছে আমি দেইিংয়ে আমি করেনি আগ্রা অন্যগূসীন হিকয়ার আমি আমি পারিনে এই টেই গথা এখন আমনুযোদী পরি।', 'ৎপুরছিলানআমার এই হিসকিলে যেক্লা আম্রা এখন করতেন সিসিক্লাস ক্লা যা বা জাইআসে ওয়েবের সাথে এটে সম্পর করে একটু ডিফ রান্ট এবং চ্োল বইরে সি এগুলো য্যটি নাপর ক্রি অনাসে অল্পতি তৈডে আাকে আয়ততুউনেক পরে নিতিবার বিভয়বে ওয়েবে মূলতসিকি আনী বোলি।', 'আমি পরে আর ইজিনহএর জন্য আইজ খ্লিতা এই জেলায়ীয়ে সিটা কমপ্লিক করতেভাবে এট্টাল্যেঙ্গস ভালোয়াযা ক্ষম্পিটফরে তাপড় উইল্যান্ডে সহার ক্রোপূলম স্ভীন কর্থাপ্রতি্যতাব প্ররলেন্ সলবিন কর্বে তর্মাথে তাতল লোজিক বিল ধবে রঅজিগহিল ঢ বে।', 'দেগুলির দিতে এগুলা বুস্তে পারে তাদে হযাক কট্মা পারের স্বেহা যাোক্লাভ করত্বা পার কক্তিজিত এগুলো সমকার ভালো গ্ঞান থাকে এডও সেইলের উকহাথানে কি ভূম চোগতে পারে কল থোঠিং কণ দ্যার আঠ রাত্মা পারে মানে় ভিভার ত ইঞ্জিনিয়ারই কে এইগুয়া দিয়ে প্রেয়াটটার ও েকসাইড বানা বেঠেকি রাখে।', 'আমরা একটা কাছে কতটা ইফিিয়ান ভাবে করতে র্ কতটা সযোভাবে করতে পরব এটাল তবমা মূল লক্ষফর কঠিনকোকৃ কিভাবে অ্যাক সিস্টেমিডি ওে মেয়াটড কমশনয়ে করতে পর্ব ইফশিয়ানভাবে করতে পরবেহা আমাঘাথে এটেই ফ্রামস লাগে ছেন্দেল অনে কি।', 'রিএকত যথম তুনি শিপট কল্লা তখনচীন তুমি ফান্টেন ডেপলবার হয়েও তুমি আস্রাস্ছে কিন্তু ফুলস্কার্ট ড্যাপ্লবারের ভিত্রে তুমি চলে যাতে মার্তেত্যেআস্তাস এজন চুন্জয় ফোকাজ করতে পারত  এবং জাবাইচ ক্িপ্ের়ে ত ন্তুমার ই এস ক্রিকজেটা আবদেড ভার্ষমেয়ঈত শিকলেতুমারযোেছিল।', 'ভূঐতততন্াথে আরওত বেশি আরও স্ট্রেই মর্কগুলো ঘুর্বে তার বেশি পুরুবে  আমিরওপরের তিন জিনের ইংররে দেযায় কারণ মার আমার আমাচাছের খ্যাংসে লাখা তল যা ইসেবে জন্যঅমলকেখুন নজি উচখে জীবনধবন সল সৌল সহাজ করার জন্য।', 'ঐটার ও পর একটা সপ্টার তোমার ন্ দুই জীবি নিয়ে নেয়দুই দীবিন্া ঘাটান এ একইন পূজন সেন জিনিষ্টিযাজদি তমি আরু ইদিলী এবং আরও স্পীট দুটি ভালোচালমানেই তি সীন ধরমেনএই হ্যার থোমিকা যী দআড় ভালকেশিক্নাতাালা এখন আমরা ওয়েক যদি পড়ে যুদি।', 'হালরয় নমুসে জ্ীবনজাপুন আত সৌজ বেলহট এ লেহের অলবরণ এখনিয়ে কাশ করে এযডিলনে রবরীতন চছেয়াগামাদ আমারমেন্টকারণে থেবে মানুর রপেষেরার টা কাছকে মানুষের এই দামলাধি বুনিয়ায় রাস করে এখানেন।', 'তিনি থাইবর্তীগ্ঘটী প্রয়ো যাবে তাখণ এইগুলোই তুই আওয়া ভাংবি ভাঙ্গে দেখ বিজে এটাবিত্যে কোণ ভুল আছে ক্যামে এট ভূ বুল্টা ভারকারের কিভাবের প্রৈটাইনটিরাগ করতে পারে নাইরীন্চেশনদের অনেক দিকে পুরস্থেলামনে যানভালো মা সে ভালতে হাথযয়ার হিতে পরে যেযয়ে যেে।', 'অনুইক্যতুম সামনে জেরে লেঙগুজগুবনা অনেক ততোমা কভার পর্বে অনেকচাহিরভাবেআমি অচ ুল এত রুপ ভা় অ্যথকোছু ভালোকোছু জানেনে বার আমাদইচ্সাছে তিনি ছয়মাস টাইন্ডোর ছয়মাস টাইন্দিয়া দেখী দিনিসিগী হয়ের কারন হিস্কিল ছুল আমার হুতেইউলের আমার সব দরনের প্রগ্রাণিংলেঙগে গ্লাস বে।', 'ডগলুডোগল প্রেসপুক লেখিে যুদি আমারে করেই আমলা ট্রেম শ্রেম রগুলআতে নি স্ক্ি সবগুল আমরা পেয়ে দাট্ি ওয়েএমএ এখন ওয়েব সাড়া কিন্তু বিকল্পক কিছুমি নাই কুমি যুদি একবন উয়রে পর ও ঢালোয়ওয়এবাহ়েব ধিরিফ ফয়েনজীবনায় ভারসন তবি ময়াঙ্গি প্রােমলিম্পা পর ...
#
# 1062

# %%
num = x.index("rec_19_audio_40.wav")
num

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_40.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_40.wav
# /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_40.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 19.292s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}

# %%
num = x.index("rec_19_audio_31.wav")
num
# Out:
# 742

# %%
audio_path = f"{data_dir}{x[num]}"
audio_path
# Out:
# '/content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_31.wav'

# %%
import audiosegment

print(f"File name :",audio_path)
audiosegment.from_file(audio_path)
# Out:
# File name : /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_31.wav
# /content/drive/MyDrive/local_speech/Rangpur/chunks/rangpur_all/rec_19_audio_31.wav: 1 channels, 16 bit, sampled @ 16.0 kHz, 15.264s long

# %%
quick_transcription = query(audio_path)
quick_transcription
# Out:
# {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}

# %% [markdown]
# # Making Dataframes

# %%
import pandas as pd

df = pd.DataFrame(list(zip(external_id, contents)), columns =['External_ID', 'Contents'])
df.head()
# Out:
#            External_ID Contents
# 0  rec_01_audio_59.wav       <>
# 1  rec_01_audio_70.wav       <>
# 2  rec_01_audio_66.wav       <>
# 3  rec_01_audio_62.wav       <>
# 4  rec_01_audio_68.wav       <>

# %%
df
# Out:
#               External_ID                                           Contents
# 0     rec_01_audio_59.wav                                                 <>
# 1     rec_01_audio_70.wav                                                 <>
# 2     rec_01_audio_66.wav                                                 <>
# 3     rec_01_audio_62.wav                                                 <>
# 4     rec_01_audio_68.wav                                                 <>
# ...                   ...                                                ...
# 1057  rec_01_audio_57.wav  ততটা স্প্রিয়ন্ত তেরমাথাশেই পুরোম আমার তার টা ...
# 1058  rec_01_audio_63.wav  ওয়ারকটার কাছ্রামানো সীমেটা পুটার্টে বিটিকা কা...
# 1059  rec_01_audio_67.wav  আল্লাতা অরত অহিয়া হং দিকেইপুরফিলভাবে এহ় ওহহু...
# 1060  rec_01_audio_58.wav  ঈচ্ছে আছে দেখে আললাওয়ার মিন্গা আ্চাযয়আমি জানি...
# 1061  rec_01_audio_65.wav  মমিযুদির ট্াহন্দেি তিন আমি পারলআমারদেশে সমানসই...
#
# [1062 rows x 2 columns]

# %%
df.to_excel("/content/drive/MyDrive/local_speech/others/benchmarks_codes_and_models/4. bangla-wav2vec2-large-inference/4.8: Bangla-wav2vec2-barishal-inference.xlsx")

# %% [markdown]
# # Experimental Zone

# %%
a = output['text']

# %%
b = "আমিত সলে আসলাম তোমারে এমনে করজায়ের মধ্যে কালকেদে তোমারা ফরন্ধি লান্তমি কলে যা আফ তিনিপরে আসলের হয়েদিনি মলে মনেছিলযা জামলা গেসিন়েরাশনকরমিি সাপ্তনে আশরার অজবনটা বলা হিসেবন সমন সাপ্তে দে দিলানা টাউনিয় নিটতত কলেছিল।"

# %%
a == b
# Out:
# True

# %%
output = query(f"{data_dir}{x[1025]}")

output
# Out:
# {'text': "শৈদিকতেঅনে তুইজুরী চিট্যে দেলে নয়েদেহাসেতানতে ভাল কেলাস্র রীমনের লোলইমনজের লাষ্ট্রে ডিয়ের স হলে দেয়েরা খিটিকে এটি কে আছে নাখি গেছে।'হহমাপরে আরাক্টা কণ্য ন সেটে আছে মেয়ে ঐছে।"}

# %%
output = query(f"{data_dir}{x[1025]}")

output
# Out:
# {'text': "শৈদিকতেঅনে তুইজুরী চিট্যে দেলে নয়েদেহাসেতানতে ভাল কেলাস্র রীমনের লোলইমনজের লাষ্ট্রে ডিয়ের স হলে দেয়েরা খিটিকে এটি কে আছে নাখি গেছে।'হহমাপরে আরাক্টা কণ্য ন সেটে আছে মেয়ে ঐছে।"}

# %%
output = query(f"{data_dir}{x[1027]}")

output
# Out:
# {'text': 'তুলদে দিযয়ে আমারা দেনে আইটিহাসে সারওই ও কয়ানেজয় জুল আছালকি ডার কোয়আনেতন বাজন্দার সালকরা য়েগা দিঘী জামিতান্ত তুইহাশ লীগী তাকে তা তরে বাদ্যে জননে দখকে রখা ময় েমাকনিষরা নিযয়ে সাথমানের মার ম্তকস্কিক়ম্যে ও কারিনি  সাপটিমকেকুটকা আমস্ নাবে নি।'}

# %%
len(output)
# Out:
# 1

# %%
output = query(f"{data_dir}{x[1030]}")

output['text']
# Out:
# 'মম্জে দিনি হয়ফাল্তেযিনি স্টাশলের থিগি এ মরমন্তি ওওপা় ও সতকৃচিতফবকারী দে ই এগ দিগিজে ঢে়ছেকিন্তু তার বাবভিনি তার অনকর্ঞতি নরঅরযোজের পরিমাণ হতাশ হয়ে গেছে।'

# %%
output.keys()
# Out:
# dict_keys(['text'])

# %%
'text' in output.keys()
# Out:
# True

# %%
'error' in output.keys()
# Out:
# False

# %%
output = query(f"{data_dir}{x[1281]}")

output
# Out:
# {'text': 'তব চাকরি না উভাপ্রযোজনতর েবর্তে ়না থাককেকাযিতট্য এদিও রাা আটই় জিনে আজি পুর্ডরাজইততৌধরভ আগে রাজবীলে বিয়েহা দি করী রে করত্র তারে এট কাজাগা দুইডিও কৃষুরে সেতেচাকটই প্রথম।'}
